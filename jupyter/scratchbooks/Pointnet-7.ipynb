# %% [markdown]
# # **POINTNET WITH K-FOLD**

# %%
# necessary imports
import os
import numpy
import pandas
import random
import trimesh
import logging
import itertools
import tensorflow
from matplotlib import pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import models, layers, regularizers, optimizers
from sklearn.model_selection import train_test_split, StratifiedKFold
from tensorflow.keras.layers import Dense, Activation, Flatten, Dropout, BatchNormalization
from tensorflow.keras.layers import Conv1D, MaxPooling1D, GlobalMaxPooling1D, Conv2D, MaxPooling2D

# increase matplotlib plots font size
plt.rcParams.update({'font.size': 15})

# The below is necessary for reproducible results of certain Python hash-based operations.
os.environ["PYTHONHASHSEED"] = "0"

# The below is necessary for starting Numpy generated random numbers in a well-defined initial state.
numpy.random.seed(31)

# The below is necessary for starting core Python generated random numbers in a well-defined state.
random.seed(14)

# The below tf.random.set_seed will make random number generation in TensorFlow have a well-defined initial state.
tensorflow.random.set_seed(1234)

# dataset root path
DATASET_ROOT = '/run/media/rr/M2/DevOps/jupyter-lab/CIDL/dataset/'

# final preprocessed dataset directory path
DATASET_PATH = os.path.join(DATASET_ROOT, 'Preprocessed')

# directory where to save the best model for each fold
images_models_save_dir = 'saved_models/images'
pointclouds_models_save_dir = 'saved_models/pointclouds'

# needed to create pointclouds dataset
class_labels_dict = {'table':0, 'chair':1, 'lamp':2, 'dresser':3, 'sofa':4}

# utility function
def get_model_name(model_name, fold_counter):
    return model_name + '-fold-' + str(fold_counter) + '.h5'

# utility function to augment pointclouds data
def augment(points, label):
    # jitter points
    points += tensorflow.random.uniform(points.shape, -0.005, 0.005, dtype=tensorflow.float64)
    # shuffle points
    points = tensorflow.random.shuffle(points)
    return points, label

# plot loss and acuracy for each epoch
def plot_train_loss_accuracy(save_path, train_loss, train_accuracy, val_loss, val_accuracy):
    #print('Training Set Loss: ', train_loss)
    #print('Validation Set Loss: ', val_loss)
    plt.figure(figsize=(10, 10))
    plt.plot(train_loss,'o-g', label="Training Set")
    plt.plot(val_loss,'o-r', label="Validation Set")
    plt.title('Training and Validation Sets Loss')
    plt.legend(loc="upper right")
    plt.savefig(save_path + '-train-val-loss.jpg', dpi=200)
    plt.show()
    #print('Training Set Accuracy: ', train_accuracy)
    #print('Validation Set Accuracy: ', val_accuracy)
    plt.figure(figsize=(10, 10))
    plt.plot(train_accuracy,'o-g', label="Training Set")
    plt.plot(val_accuracy,'o-r', label="Validation Set")
    plt.title('Training and Validation Sets Accuracy')
    plt.legend(loc="lower right")
    plt.savefig(save_path + '-train-val-accuracy.jpg', dpi=200)
    plt.show()

def plot_confusion_matrix(cm, classes, save_path, normalize=True, title='Confusion matrix', cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.figure(figsize=(10,10))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()

    tick_marks = numpy.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, numpy.newaxis]
        cm = numpy.around(cm, decimals=2)
        cm[numpy.isnan(cm)] = 0.0
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')
    
    thresh = cm.max() / 2.

    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j], horizontalalignment="center", color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.savefig(save_path + '-confusion-matrix.jpg', bbox_inches='tight', dpi=200)
    plt.show()

# %%
# only log critical messages
logger = logging.getLogger()
logger.setLevel(logging.CRITICAL)

# %%
# load images csv file
images_data = pandas.read_csv(os.path.join(DATASET_PATH, 'images.csv'))

# extract images path and class labels
images_X = images_data[['filename']]
images_Y = images_data[['class_label']]

# load pointclouds csv file
pointclouds_data = pandas.read_csv(os.path.join(DATASET_PATH, 'pointclouds.csv'))

# extract images path and class labels
pointclouds_X = pointclouds_data[['filename']]
pointclouds_Y = pointclouds_data[['class_label']]

# %% [markdown]
# ## **Stratified K-Fold Cross Validation for pointclouds**

# %%
def pointclouds_kfold_validation(model_name, n_splits, test_size, shuffle, layers, learning_rate, decay, target_size, epochs, batch_size, resample_data=0):
    global pointclouds_data
    global pointclouds_X
    global pointclouds_Y
    if resample_data > 0:
        pointclouds_data = pointclouds_data.groupby('class_label', group_keys=False).apply(lambda x: x.sample(min(len(x), resample_data), random_state=42))
        pointclouds_X = pointclouds_data[['filename']]
        pointclouds_Y = pointclouds_data[['class_label']]

    # fold counter
    fold_counter = 1
    
    # arrays to store test set loss and accuracy scores for each fold
    TEST_LOSS = []
    TEST_ACCURACY = []
    
    # split train and test dataset
    pointclouds_train, pointclouds_test = train_test_split(pointclouds_data, test_size=test_size, stratify=pointclouds_Y, random_state=42)
    pointclouds_train_X = pointclouds_train[['filename']]
    pointclouds_train_Y = pointclouds_train[['class_label']]

    # define stratified k fold cross validation parameters
    stratified_kfold = StratifiedKFold(n_splits=n_splits, random_state=7, shuffle=shuffle)

    # test data arrays
    test_pointclouds = []
    test_labels = []
    test_string_labels = {}

    # test split ready
    for index, test_data_row in pointclouds_test.iterrows():
        test_pointclouds.append(trimesh.load(test_data_row['filename'], force='mesh').sample(target_size))
        test_labels.append(class_labels_dict[test_data_row['class_label']])
        test_string_labels[index] = test_data_row['class_label']
    
    # convert to numpy array
    test_pointclouds = numpy.array(test_pointclouds)
    test_labels = numpy.array(test_labels)

    # create test tf.data.Dataset
    test_dataset = tensorflow.data.Dataset.from_tensor_slices((test_pointclouds, test_labels))
    test_dataset = test_dataset.shuffle(len(test_pointclouds)).batch(batch_size)
    print("Found " + str(len(pointclouds_test)) + " validated pointcloud filenames belonging to " + str(len(pointclouds_test['class_label'].unique())) + " classes.")


    # generate train and validation folds
    for train_index, validation_index in stratified_kfold.split(pointclouds_train_X, pointclouds_train_Y):
        print("\n-------- STARTING FOLD: " + str(fold_counter) + " --------")

        # best model save path
        if not os.path.isdir(os.path.join(pointclouds_models_save_dir, model_name)):
            os.mkdir(os.path.join(pointclouds_models_save_dir, model_name))
        pointclouds_model_save_path = os.path.join(pointclouds_models_save_dir, model_name, get_model_name(model_name, fold_counter))

        # train and validation data arrays
        train_pointclouds = []
        train_labels = []
        train_string_labels = {}
        validation_pointclouds = []
        validation_labels = []
        validation_string_labels = {}

        # training and test folds indices
        training_data = pointclouds_train.iloc[train_index]
        validation_data = pointclouds_train.iloc[validation_index]

        for index, training_data_row in training_data.iterrows():
            train_pointclouds.append(trimesh.load(training_data_row['filename'], force='mesh').sample(target_size))
            train_labels.append(class_labels_dict[training_data_row['class_label']])
            train_string_labels[index] = training_data_row['class_label']

        # convert to numpy array
        train_pointclouds = numpy.array(train_pointclouds)
        train_labels = numpy.array(train_labels)

        # create train tf.data.Dataset
        train_dataset = tensorflow.data.Dataset.from_tensor_slices((train_pointclouds, train_labels))
        train_dataset = train_dataset.shuffle(len(train_pointclouds)).map(augment).batch(batch_size)
        print("Found " + str(len(training_data)) + " validated pointcloud filenames belonging to " + str(len(training_data['class_label'].unique())) + " classes.")

        for index, validation_data_row in validation_data.iterrows():
            validation_pointclouds.append(trimesh.load(validation_data_row['filename'], force='mesh').sample(target_size))
            validation_labels.append(class_labels_dict[validation_data_row['class_label']])
            validation_string_labels[index] = validation_data_row['class_label']

        # convert to numpy array
        validation_pointclouds = numpy.array(validation_pointclouds)
        validation_labels = numpy.array(validation_labels)

        # create train tf.data.Dataset
        validation_dataset = tensorflow.data.Dataset.from_tensor_slices((validation_pointclouds, validation_labels))
        validation_dataset = validation_dataset.shuffle(len(validation_pointclouds)).map(augment).batch(batch_size)
        print("Found " + str(len(validation_data)) + " validated pointcloud filenames belonging to " + str(len(validation_data['class_label'].unique())) + " classes.")

        # create best model checkpoint
        best_model_checkpoint = tensorflow.keras.callbacks.ModelCheckpoint(pointclouds_model_save_path, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
        callbacks_list = [best_model_checkpoint]

        # define model to be trained and tested
        model = models.Sequential(name=model_name + "-" + str(fold_counter))
        for layer in layers:
            model.add(layer)
        model.summary()
        model.compile(optimizer=tensorflow.keras.optimizers.RMSprop(learning_rate=learning_rate, decay=decay), loss="sparse_categorical_crossentropy", metrics=["sparse_categorical_accuracy"])

        # train model
        history = model.fit(train_dataset,
                            epochs=epochs,
                            callbacks=callbacks_list,
                            validation_data=validation_dataset)

        # plot loss and acuracy for each training/validation fold
        plot_train_loss_accuracy(pointclouds_model_save_path, history.history["loss"], history.history["sparse_categorical_accuracy"],
                                 history.history["val_loss"], history.history["val_sparse_categorical_accuracy"])

        # LOAD BEST MODEL to evaluate the performance of the model on the test set
        model.load_weights(pointclouds_model_save_path)

        # evaluate the model on the test set
        test_loss, test_accuracy = model.evaluate(test_dataset, batch_size=batch_size)
        print("Best model Test Loss: " + str(test_loss))
        print("Best model Test Accuracy: " + str(test_accuracy))
        
        # store test set loss and accuracy scores for each fold
        TEST_LOSS.append(test_loss)
        TEST_ACCURACY.append(test_accuracy)

        # Confution Matrix 
        Y_pred = model.predict(test_dataset)
        y_pred = numpy.argmax(Y_pred, axis=1)
        print('Confusion Matrix')
        cm = confusion_matrix(test_labels, y_pred)
        plot_confusion_matrix(cm, class_labels_dict.keys(), pointclouds_model_save_path, title='Confusion Matrix')

        # print Classification Report
        print('Classification Report')
        print(classification_report(test_labels, y_pred, target_names=class_labels_dict.keys()))

        # clean up before next fold
        del model
        tensorflow.keras.backend.clear_session()
        fold_counter += 1

# %% [markdown]
# #### **Developer harness test for Stratified K-Fold Cross Validation for pointclouds**

# %%
# testing
layers = [
    Conv1D(32, 3, padding='same', input_shape=(2048, 3)),
    BatchNormalization(momentum=0.0),
    Activation('relu'),
    Conv1D(64, 3, padding='same', input_shape=(2048, 3)),
    BatchNormalization(momentum=0.0),
    Activation('relu'),
    Conv1D(512, 3, padding='same', input_shape=(2048, 3)),
    BatchNormalization(momentum=0.0),
    Activation('relu'),
    GlobalMaxPooling1D(),
    Dense(512),
    BatchNormalization(momentum=0.0),
    Flatten(),
    Dense(1024),
    Activation('relu'),
    Dense(5, activation='softmax')
]

# train, validate and test
pointclouds_kfold_validation("testing", 3, 0.20, True, layers, 0.001, 1e-6, 2048, 50, 32)
# Out:
# 2022-02-06 21:19:52.957356: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-06 21:19:52.975552: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-06 21:19:52.975720: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-06 21:19:52.976457: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-02-06 21:19:52.977289: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-06 21:19:52.977450: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-06 21:19:52.977586: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-06 21:19:53.223645: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-06 21:19:53.223787: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-06 21:19:53.223898: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-06 21:19:53.224008: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 21951 MB memory:  -> device: 0, name: NVIDIA RTX A5000, pci bus id: 0000:0b:00.0, compute capability: 8.6
# Found 787 validated pointcloud filenames belonging to 5 classes.
#
# -------- STARTING FOLD: 1 --------
# Found 2096 validated pointcloud filenames belonging to 5 classes.
# Found 1048 validated pointcloud filenames belonging to 5 classes.
# Model: "testing-1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 2048, 32)          320
#
#  batch_normalization (BatchN  (None, 2048, 32)         128
#  ormalization)
#
#  activation (Activation)     (None, 2048, 32)          0
#
#  conv1d_1 (Conv1D)           (None, 2048, 64)          6208
#
#  batch_normalization_1 (Batc  (None, 2048, 64)         256
#  hNormalization)
#
#  activation_1 (Activation)   (None, 2048, 64)          0
#
#  conv1d_2 (Conv1D)           (None, 2048, 512)         98816
#
#  batch_normalization_2 (Batc  (None, 2048, 512)        2048
#  hNormalization)
#
#  activation_2 (Activation)   (None, 2048, 512)         0
#
#  global_max_pooling1d (Globa  (None, 512)              0
#  lMaxPooling1D)
#
#  dense (Dense)               (None, 512)               262656
#
#  batch_normalization_3 (Batc  (None, 512)              2048
#  hNormalization)
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 1024)              525312
#
#  activation_3 (Activation)   (None, 1024)              0
#
#  dense_2 (Dense)             (None, 5)                 5125
#
# =================================================================
# Total params: 902,917
# Trainable params: 900,677
# Non-trainable params: 2,240
# _________________________________________________________________
# Epoch 1/50
# 2022-02-06 21:22:13.657019: I tensorflow/stream_executor/cuda/cuda_dnn.cc:366] Loaded cuDNN version 8300
#  1/66 [..............................] - ETA: 2:11 - loss: 1.7248 - sparse_categorical_accuracy: 0.2812
# 2022-02-06 21:22:14.324873: I tensorflow/stream_executor/cuda/cuda_blas.cc:1774] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 66/66 [==============================] - ETA: 0s - loss: 2.5526 - sparse_categorical_accuracy: 0.2882
# Epoch 00001: val_loss improved from inf to 6.44475, saving model to saved_models/pointclouds/testing/testing-fold-1.h5
# 66/66 [==============================] - 4s 27ms/step - loss: 2.5526 - sparse_categorical_accuracy: 0.2882 - val_loss: 6.4447 - val_sparse_categorical_accuracy: 0.2376
# Epoch 2/50
# 64/66 [============================>.] - ETA: 0s - loss: 1.8961 - sparse_categorical_accuracy: 0.3374
# Epoch 00002: val_loss improved from 6.44475 to 2.32181, saving model to saved_models/pointclouds/testing/testing-fold-1.h5
# 66/66 [==============================] - 2s 25ms/step - loss: 1.9073 - sparse_categorical_accuracy: 0.3359 - val_loss: 2.3218 - val_sparse_categorical_accuracy: 0.2490
# Epoch 3/50
# 64/66 [============================>.] - ETA: 0s - loss: 1.6959 - sparse_categorical_accuracy: 0.3726
# Epoch 00003: val_loss did not improve from 2.32181
# 66/66 [==============================] - 2s 24ms/step - loss: 1.6977 - sparse_categorical_accuracy: 0.3736 - val_loss: 6.4676 - val_sparse_categorical_accuracy: 0.2691
# Epoch 4/50
# 64/66 [============================>.] - ETA: 0s - loss: 1.5393 - sparse_categorical_accuracy: 0.4116
# Epoch 00004: val_loss did not improve from 2.32181
# 66/66 [==============================] - 2s 24ms/step - loss: 1.5373 - sparse_categorical_accuracy: 0.4127 - val_loss: 3.1643 - val_sparse_categorical_accuracy: 0.2595
# Epoch 5/50
# 64/66 [============================>.] - ETA: 0s - loss: 1.4487 - sparse_categorical_accuracy: 0.4346
# Epoch 00005: val_loss did not improve from 2.32181
# 66/66 [==============================] - 2s 24ms/step - loss: 1.4438 - sparse_categorical_accuracy: 0.4389 - val_loss: 5.7286 - val_sparse_categorical_accuracy: 0.4838
# Epoch 6/50
# 64/66 [============================>.] - ETA: 0s - loss: 1.3409 - sparse_categorical_accuracy: 0.4517
# Epoch 00006: val_loss did not improve from 2.32181
# 66/66 [==============================] - 2s 24ms/step - loss: 1.3415 - sparse_categorical_accuracy: 0.4513 - val_loss: 3.4725 - val_sparse_categorical_accuracy: 0.3922
# Epoch 7/50
# 64/66 [============================>.] - ETA: 0s - loss: 1.3112 - sparse_categorical_accuracy: 0.4731
# Epoch 00007: val_loss improved from 2.32181 to 1.58276, saving model to saved_models/pointclouds/testing/testing-fold-1.h5
# 66/66 [==============================] - 2s 24ms/step - loss: 1.3182 - sparse_categorical_accuracy: 0.4704 - val_loss: 1.5828 - val_sparse_categorical_accuracy: 0.3292
# Epoch 8/50
# 64/66 [============================>.] - ETA: 0s - loss: 1.2456 - sparse_categorical_accuracy: 0.5127
# Epoch 00008: val_loss did not improve from 1.58276
# 66/66 [==============================] - 2s 24ms/step - loss: 1.2421 - sparse_categorical_accuracy: 0.5148 - val_loss: 33.9520 - val_sparse_categorical_accuracy: 0.6011
# Epoch 9/50
# 64/66 [============================>.] - ETA: 0s - loss: 1.1867 - sparse_categorical_accuracy: 0.5308
# Epoch 00009: val_loss did not improve from 1.58276
# 66/66 [==============================] - 2s 24ms/step - loss: 1.1825 - sparse_categorical_accuracy: 0.5358 - val_loss: 2.9845 - val_sparse_categorical_accuracy: 0.4590
# Epoch 10/50
# 64/66 [============================>.] - ETA: 0s - loss: 1.1801 - sparse_categorical_accuracy: 0.5376
# Epoch 00010: val_loss did not improve from 1.58276
# 66/66 [==============================] - 2s 24ms/step - loss: 1.1864 - sparse_categorical_accuracy: 0.5329 - val_loss: 5.6158 - val_sparse_categorical_accuracy: 0.6842
# Epoch 11/50
# 64/66 [============================>.] - ETA: 0s - loss: 1.0715 - sparse_categorical_accuracy: 0.5806
# Epoch 00011: val_loss did not improve from 1.58276
# 66/66 [==============================] - 2s 24ms/step - loss: 1.0717 - sparse_categorical_accuracy: 0.5797 - val_loss: 1.6382 - val_sparse_categorical_accuracy: 0.4790
# Epoch 12/50
# 64/66 [============================>.] - ETA: 0s - loss: 1.0526 - sparse_categorical_accuracy: 0.5913
# Epoch 00012: val_loss did not improve from 1.58276
# 66/66 [==============================] - 2s 24ms/step - loss: 1.0531 - sparse_categorical_accuracy: 0.5930 - val_loss: 38.0534 - val_sparse_categorical_accuracy: 0.6288
# Epoch 13/50
# 64/66 [============================>.] - ETA: 0s - loss: 1.0579 - sparse_categorical_accuracy: 0.5859
# Epoch 00013: val_loss did not improve from 1.58276
# 66/66 [==============================] - 2s 24ms/step - loss: 1.0624 - sparse_categorical_accuracy: 0.5830 - val_loss: 13.2062 - val_sparse_categorical_accuracy: 0.5649
# Epoch 14/50
# 64/66 [============================>.] - ETA: 0s - loss: 1.0609 - sparse_categorical_accuracy: 0.5933
# Epoch 00014: val_loss did not improve from 1.58276
# 66/66 [==============================] - 2s 24ms/step - loss: 1.0624 - sparse_categorical_accuracy: 0.5921 - val_loss: 23.4452 - val_sparse_categorical_accuracy: 0.5582
# Epoch 15/50
# 64/66 [============================>.] - ETA: 0s - loss: 1.0001 - sparse_categorical_accuracy: 0.6030
# Epoch 00015: val_loss did not improve from 1.58276
# 66/66 [==============================] - 2s 24ms/step - loss: 0.9968 - sparse_categorical_accuracy: 0.6054 - val_loss: 12.1867 - val_sparse_categorical_accuracy: 0.7481
# Epoch 16/50
# 64/66 [============================>.] - ETA: 0s - loss: 0.9923 - sparse_categorical_accuracy: 0.6255
# Epoch 00016: val_loss did not improve from 1.58276
# 66/66 [==============================] - 2s 24ms/step - loss: 0.9902 - sparse_categorical_accuracy: 0.6283 - val_loss: 13.5105 - val_sparse_categorical_accuracy: 0.4962
# Epoch 17/50
# 64/66 [============================>.] - ETA: 0s - loss: 0.9703 - sparse_categorical_accuracy: 0.6167
# Epoch 00017: val_loss did not improve from 1.58276
# 66/66 [==============================] - 2s 24ms/step - loss: 0.9609 - sparse_categorical_accuracy: 0.6212 - val_loss: 75.7813 - val_sparse_categorical_accuracy: 0.5048
# Epoch 18/50
# 64/66 [============================>.] - ETA: 0s - loss: 0.9798 - sparse_categorical_accuracy: 0.6421
# Epoch 00018: val_loss improved from 1.58276 to 1.52817, saving model to saved_models/pointclouds/testing/testing-fold-1.h5
# 66/66 [==============================] - 2s 25ms/step - loss: 0.9775 - sparse_categorical_accuracy: 0.6407 - val_loss: 1.5282 - val_sparse_categorical_accuracy: 0.4714
# Epoch 19/50
# 64/66 [============================>.] - ETA: 0s - loss: 0.9713 - sparse_categorical_accuracy: 0.6455
# Epoch 00019: val_loss did not improve from 1.52817
# 66/66 [==============================] - 2s 24ms/step - loss: 0.9663 - sparse_categorical_accuracy: 0.6489 - val_loss: 16.8084 - val_sparse_categorical_accuracy: 0.7128
# Epoch 20/50
# 64/66 [============================>.] - ETA: 0s - loss: 0.9029 - sparse_categorical_accuracy: 0.6587
# Epoch 00020: val_loss did not improve from 1.52817
# 66/66 [==============================] - 2s 24ms/step - loss: 0.9048 - sparse_categorical_accuracy: 0.6594 - val_loss: 11.2197 - val_sparse_categorical_accuracy: 0.7052
# Epoch 21/50
# 64/66 [============================>.] - ETA: 0s - loss: 0.9249 - sparse_categorical_accuracy: 0.6465
# Epoch 00021: val_loss did not improve from 1.52817
# 66/66 [==============================] - 2s 25ms/step - loss: 0.9229 - sparse_categorical_accuracy: 0.6489 - val_loss: 19.9662 - val_sparse_categorical_accuracy: 0.7118
# Epoch 22/50
# 64/66 [============================>.] - ETA: 0s - loss: 0.8895 - sparse_categorical_accuracy: 0.6738
# Epoch 00022: val_loss did not improve from 1.52817
# 66/66 [==============================] - 2s 25ms/step - loss: 0.8878 - sparse_categorical_accuracy: 0.6722 - val_loss: 1.6203 - val_sparse_categorical_accuracy: 0.4389
# Epoch 23/50
# 64/66 [============================>.] - ETA: 0s - loss: 0.8845 - sparse_categorical_accuracy: 0.6709
# Epoch 00023: val_loss did not improve from 1.52817
# 66/66 [==============================] - 2s 24ms/step - loss: 0.8880 - sparse_categorical_accuracy: 0.6718 - val_loss: 13.7914 - val_sparse_categorical_accuracy: 0.6584
# Epoch 24/50
# 64/66 [============================>.] - ETA: 0s - loss: 0.8803 - sparse_categorical_accuracy: 0.6738
# Epoch 00024: val_loss did not improve from 1.52817
# 66/66 [==============================] - 2s 25ms/step - loss: 0.8744 - sparse_categorical_accuracy: 0.6760 - val_loss: 2.6474 - val_sparse_categorical_accuracy: 0.7233
# Epoch 25/50
# 64/66 [============================>.] - ETA: 0s - loss: 0.8818 - sparse_categorical_accuracy: 0.6748
# Epoch 00025: val_loss did not improve from 1.52817
# 66/66 [==============================] - 2s 25ms/step - loss: 0.8863 - sparse_categorical_accuracy: 0.6746 - val_loss: 2.0732 - val_sparse_categorical_accuracy: 0.3912
# Epoch 26/50
# 64/66 [============================>.] - ETA: 0s - loss: 0.8514 - sparse_categorical_accuracy: 0.6792
# Epoch 00026: val_loss did not improve from 1.52817
# 66/66 [==============================] - 2s 25ms/step - loss: 0.8474 - sparse_categorical_accuracy: 0.6823 - val_loss: 2.9217 - val_sparse_categorical_accuracy: 0.6966
# Epoch 27/50
# 64/66 [============================>.] - ETA: 0s - loss: 0.8595 - sparse_categorical_accuracy: 0.6880
# Epoch 00027: val_loss did not improve from 1.52817
# 66/66 [==============================] - 2s 25ms/step - loss: 0.8512 - sparse_categorical_accuracy: 0.6899 - val_loss: 6.1058 - val_sparse_categorical_accuracy: 0.7605
# Epoch 28/50
# 64/66 [============================>.] - ETA: 0s - loss: 0.8222 - sparse_categorical_accuracy: 0.7080
# Epoch 00028: val_loss did not improve from 1.52817
# 66/66 [==============================] - 2s 25ms/step - loss: 0.8252 - sparse_categorical_accuracy: 0.7071 - val_loss: 81.9232 - val_sparse_categorical_accuracy: 0.5792
# Epoch 29/50
# 64/66 [============================>.] - ETA: 0s - loss: 0.8150 - sparse_categorical_accuracy: 0.7070
# Epoch 00029: val_loss did not improve from 1.52817
# 66/66 [==============================] - 2s 24ms/step - loss: 0.8138 - sparse_categorical_accuracy: 0.7099 - val_loss: 401.6677 - val_sparse_categorical_accuracy: 0.4885
# Epoch 30/50
# 64/66 [============================>.] - ETA: 0s - loss: 0.8108 - sparse_categorical_accuracy: 0.7134
# Epoch 00030: val_loss did not improve from 1.52817
# 66/66 [==============================] - 2s 24ms/step - loss: 0.8138 - sparse_categorical_accuracy: 0.7128 - val_loss: 66.8976 - val_sparse_categorical_accuracy: 0.7357
# Epoch 31/50
# 64/66 [============================>.] - ETA: 0s - loss: 0.8027 - sparse_categorical_accuracy: 0.7046
# Epoch 00031: val_loss did not improve from 1.52817
# 66/66 [==============================] - 2s 24ms/step - loss: 0.8061 - sparse_categorical_accuracy: 0.7032 - val_loss: 6.7116 - val_sparse_categorical_accuracy: 0.6460
# Epoch 32/50
# 64/66 [============================>.] - ETA: 0s - loss: 0.8385 - sparse_categorical_accuracy: 0.6929
# Epoch 00032: val_loss did not improve from 1.52817
# 66/66 [==============================] - 2s 24ms/step - loss: 0.8385 - sparse_categorical_accuracy: 0.6937 - val_loss: 7.4813 - val_sparse_categorical_accuracy: 0.7748
# Epoch 33/50
# 64/66 [============================>.] - ETA: 0s - loss: 0.8081 - sparse_categorical_accuracy: 0.6953
# Epoch 00033: val_loss did not improve from 1.52817
# 66/66 [==============================] - 2s 24ms/step - loss: 0.8158 - sparse_categorical_accuracy: 0.6937 - val_loss: 7.7009 - val_sparse_categorical_accuracy: 0.7223
# Epoch 34/50
# 64/66 [============================>.] - ETA: 0s - loss: 0.7772 - sparse_categorical_accuracy: 0.7188
# Epoch 00034: val_loss did not improve from 1.52817
# 66/66 [==============================] - 2s 24ms/step - loss: 0.7758 - sparse_categorical_accuracy: 0.7185 - val_loss: 3.1508 - val_sparse_categorical_accuracy: 0.8025
# Epoch 35/50
# 64/66 [============================>.] - ETA: 0s - loss: 0.7624 - sparse_categorical_accuracy: 0.7275
# Epoch 00035: val_loss did not improve from 1.52817
# 66/66 [==============================] - 2s 24ms/step - loss: 0.7594 - sparse_categorical_accuracy: 0.7285 - val_loss: 36.9474 - val_sparse_categorical_accuracy: 0.7281
# Epoch 36/50
# 64/66 [============================>.] - ETA: 0s - loss: 0.8224 - sparse_categorical_accuracy: 0.7007
# Epoch 00036: val_loss did not improve from 1.52817
# 66/66 [==============================] - 2s 24ms/step - loss: 0.8138 - sparse_categorical_accuracy: 0.7042 - val_loss: 8.2786 - val_sparse_categorical_accuracy: 0.7118
# Epoch 37/50
# 64/66 [============================>.] - ETA: 0s - loss: 0.7861 - sparse_categorical_accuracy: 0.7139
# Epoch 00037: val_loss did not improve from 1.52817
# 66/66 [==============================] - 2s 24ms/step - loss: 0.7914 - sparse_categorical_accuracy: 0.7133 - val_loss: 7.0073 - val_sparse_categorical_accuracy: 0.4008
# Epoch 38/50
# 64/66 [============================>.] - ETA: 0s - loss: 0.7779 - sparse_categorical_accuracy: 0.7290
# Epoch 00038: val_loss improved from 1.52817 to 0.81456, saving model to saved_models/pointclouds/testing/testing-fold-1.h5
# 66/66 [==============================] - 2s 25ms/step - loss: 0.7805 - sparse_categorical_accuracy: 0.7285 - val_loss: 0.8146 - val_sparse_categorical_accuracy: 0.7739
# Epoch 39/50
# 64/66 [============================>.] - ETA: 0s - loss: 0.7747 - sparse_categorical_accuracy: 0.7163
# Epoch 00039: val_loss did not improve from 0.81456
# 66/66 [==============================] - 2s 25ms/step - loss: 0.7714 - sparse_categorical_accuracy: 0.7176 - val_loss: 73.1746 - val_sparse_categorical_accuracy: 0.7529
# Epoch 40/50
# 64/66 [============================>.] - ETA: 0s - loss: 0.7552 - sparse_categorical_accuracy: 0.7241
# Epoch 00040: val_loss did not improve from 0.81456
# 66/66 [==============================] - 2s 25ms/step - loss: 0.7565 - sparse_categorical_accuracy: 0.7242 - val_loss: 1.3019 - val_sparse_categorical_accuracy: 0.4857
# Epoch 41/50
# 64/66 [============================>.] - ETA: 0s - loss: 0.7456 - sparse_categorical_accuracy: 0.7388
# Epoch 00041: val_loss did not improve from 0.81456
# 66/66 [==============================] - 2s 24ms/step - loss: 0.7480 - sparse_categorical_accuracy: 0.7390 - val_loss: 53.1397 - val_sparse_categorical_accuracy: 0.7385
# Epoch 42/50
# 64/66 [============================>.] - ETA: 0s - loss: 0.7493 - sparse_categorical_accuracy: 0.7222
# Epoch 00042: val_loss did not improve from 0.81456
# 66/66 [==============================] - 2s 25ms/step - loss: 0.7450 - sparse_categorical_accuracy: 0.7228 - val_loss: 7.6915 - val_sparse_categorical_accuracy: 0.7338
# Epoch 43/50
# 64/66 [============================>.] - ETA: 0s - loss: 0.7623 - sparse_categorical_accuracy: 0.7256
# Epoch 00043: val_loss did not improve from 0.81456
# 66/66 [==============================] - 2s 24ms/step - loss: 0.7654 - sparse_categorical_accuracy: 0.7247 - val_loss: 1.0540 - val_sparse_categorical_accuracy: 0.7137
# Epoch 44/50
# 64/66 [============================>.] - ETA: 0s - loss: 0.7201 - sparse_categorical_accuracy: 0.7256
# Epoch 00044: val_loss did not improve from 0.81456
# 66/66 [==============================] - 2s 24ms/step - loss: 0.7251 - sparse_categorical_accuracy: 0.7242 - val_loss: 105.8829 - val_sparse_categorical_accuracy: 0.7099
# Epoch 45/50
# 64/66 [============================>.] - ETA: 0s - loss: 0.7672 - sparse_categorical_accuracy: 0.7173
# Epoch 00045: val_loss did not improve from 0.81456
# 66/66 [==============================] - 2s 24ms/step - loss: 0.7623 - sparse_categorical_accuracy: 0.7195 - val_loss: 1.6006 - val_sparse_categorical_accuracy: 0.6880
# Epoch 46/50
# 64/66 [============================>.] - ETA: 0s - loss: 0.7513 - sparse_categorical_accuracy: 0.7148
# Epoch 00046: val_loss did not improve from 0.81456
# 66/66 [==============================] - 2s 25ms/step - loss: 0.7521 - sparse_categorical_accuracy: 0.7142 - val_loss: 28.0733 - val_sparse_categorical_accuracy: 0.5906
# Epoch 47/50
# 64/66 [============================>.] - ETA: 0s - loss: 0.7162 - sparse_categorical_accuracy: 0.7393
# Epoch 00047: val_loss did not improve from 0.81456
# 66/66 [==============================] - 2s 25ms/step - loss: 0.7071 - sparse_categorical_accuracy: 0.7419 - val_loss: 10.7628 - val_sparse_categorical_accuracy: 0.7233
# Epoch 48/50
# 64/66 [============================>.] - ETA: 0s - loss: 0.7173 - sparse_categorical_accuracy: 0.7554
# Epoch 00048: val_loss did not improve from 0.81456
# 66/66 [==============================] - 2s 25ms/step - loss: 0.7198 - sparse_categorical_accuracy: 0.7552 - val_loss: 1.0521 - val_sparse_categorical_accuracy: 0.6431
# Epoch 49/50
# 64/66 [============================>.] - ETA: 0s - loss: 0.7097 - sparse_categorical_accuracy: 0.7373
# Epoch 00049: val_loss did not improve from 0.81456
# 66/66 [==============================] - 2s 25ms/step - loss: 0.7065 - sparse_categorical_accuracy: 0.7390 - val_loss: 8.9689 - val_sparse_categorical_accuracy: 0.6021
# Epoch 50/50
# 64/66 [============================>.] - ETA: 0s - loss: 0.7068 - sparse_categorical_accuracy: 0.7368
# Epoch 00050: val_loss did not improve from 0.81456
# 66/66 [==============================] - 2s 25ms/step - loss: 0.7048 - sparse_categorical_accuracy: 0.7381 - val_loss: 52.3705 - val_sparse_categorical_accuracy: 0.7443
# 25/25 [==============================] - 0s 6ms/step - loss: 0.8065 - sparse_categorical_accuracy: 0.7560
# Best model Test Loss: 0.8064618706703186
# Best model Test Accuracy: 0.756035566329956
# Confusion Matrix
# Normalized confusion matrix
# Classification Report
#               precision    recall  f1-score   support
#
#        table       0.20      0.16      0.18       158
#        chair       0.20      0.14      0.16       157
#         lamp       0.23      0.28      0.25       158
#      dresser       0.17      0.18      0.18       157
#         sofa       0.19      0.22      0.20       157
#
#     accuracy                           0.20       787
#    macro avg       0.20      0.20      0.20       787
# weighted avg       0.20      0.20      0.20       787
#
#
# -------- STARTING FOLD: 2 --------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [5], in <module>
#       2 layers = [
#       3     Conv1D(32, 3, padding='same', input_shape=(2048, 3)),
#       4     BatchNormalization(momentum=0.0),
#    (...)
#      18     Dense(5, activation='softmax')
#      19 ]
#      21 # train, validate and test
# ---> 22 pointclouds_kfold_validation("testing", 3, 0.20, True, layers, 0.001, 1e-6, 2048, 50, 32)
#
# Input In [4], in pointclouds_kfold_validation(model_name, n_splits, test_size, shuffle, layers, learning_rate, decay, target_size, epochs, batch_size, resample_data)
#      65 validation_data = pointclouds_train.iloc[validation_index]
#      67 for index, training_data_row in training_data.iterrows():
# ---> 68     train_pointclouds.append(trimesh.load(training_data_row['filename'], force='mesh').sample(target_size))
#      69     train_labels.append(class_labels_dict[training_data_row['class_label']])
#      70     train_string_labels[index] = training_data_row['class_label']
#
# File /run/media/rr/M2/DevOps/jupyter-lab/python39_venv/lib/python3.9/site-packages/trimesh/exchange/load.py:127, in load(file_obj, file_type, resolver, force, **kwargs)
#     122     loaded = load_path(file_obj,
#     123                        file_type=file_type,
#     124                        **kwargs)
#     125 elif file_type in mesh_loaders:
#     126     # mesh loaders use mesh loader
# --> 127     loaded = load_mesh(file_obj,
#     128                        file_type=file_type,
#     129                        resolver=resolver,
#     130                        **kwargs)
#     131 elif file_type in compressed_loaders:
#     132     # for archives, like ZIP files
#     133     loaded = load_compressed(file_obj,
#     134                              file_type=file_type,
#     135                              **kwargs)
#
# File /run/media/rr/M2/DevOps/jupyter-lab/python39_venv/lib/python3.9/site-packages/trimesh/constants.py:146, in log_time.<locals>.timed(*args, **kwargs)
#     144 def timed(*args, **kwargs):
#     145     tic = now()
# --> 146     result = method(*args, **kwargs)
#     147     log.debug('%s executed in %.4f seconds.',
#     148               method.__name__,
#     149               now() - tic)
#     150     return result
#
# File /run/media/rr/M2/DevOps/jupyter-lab/python39_venv/lib/python3.9/site-packages/trimesh/exchange/load.py:209, in load_mesh(file_obj, file_type, resolver, **kwargs)
#     197 (file_obj,  # file- like object
#     198  file_type,  # str, what kind of file
#     199  metadata,  # dict, any metadata from file name
#    (...)
#     203                      file_type=file_type,
#     204                      resolver=resolver)
#     206 try:
#     207     # make sure we keep passed kwargs to loader
#     208     # but also make sure loader keys override passed keys
# --> 209     results = mesh_loaders[file_type](file_obj,
#     210                                       file_type=file_type,
#     211                                       resolver=resolver,
#     212                                       **kwargs)
#     213     if not isinstance(results, list):
#     214         results = [results]
#
# File /run/media/rr/M2/DevOps/jupyter-lab/python39_venv/lib/python3.9/site-packages/trimesh/exchange/off.py:23, in load_off(file_obj, **kwargs)
#       8 def load_off(file_obj, **kwargs):
#       9     """
#      10     Load an OFF file into the kwargs for a Trimesh constructor
#      11
#    (...)
#      21       kwargs for Trimesh constructor
#      22     """
# ---> 23     text = file_obj.read()
#      24     # will magically survive weird encoding sometimes
#      25     # comment strip will handle all cases of commenting
#      26     text = util.comment_strip(
#      27         util.decode_text(text)).strip()
#
# KeyboardInterrupt:
