# %% [markdown]
# # **POINTNET WITH K-FOLD**

# %%
# necessary imports
import os
import numpy
import pandas
import random
import trimesh
import logging
import itertools
import tensorflow
from matplotlib import pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import models, layers, regularizers, optimizers
from sklearn.model_selection import train_test_split, StratifiedKFold
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Conv2D, MaxPooling2D
from tensorflow.keras.layers import Dense, Activation, Flatten, Dropout, BatchNormalization

# increase matplotlib plots font size
plt.rcParams.update({'font.size': 15})

# dataset root path
DATASET_ROOT = '/run/media/rr/M2/DevOps/jupyter-lab/CIDL/dataset/'

# final preprocessed dataset directory path
DATASET_PATH = os.path.join(DATASET_ROOT, 'Preprocessed')

# directory where to save the best model for each fold
images_models_save_dir = 'saved_models/images'
pointclouds_models_save_dir = 'saved_models/pointclouds'

# needed to create pointclouds dataset
class_labels_dict = {'table':0, 'chair':1, 'lamp':2, 'dresser':3, 'sofa':4}

# utility function
def get_model_name(model_name, fold_counter):
    return model_name + '-fold-' + str(fold_counter) + '.h5'

# utility function to augment pointclouds data
def augment(points, label):
    # jitter points
    points += tensorflow.random.uniform(points.shape, -0.005, 0.005, dtype=tensorflow.float64)
    # shuffle points
    points = tensorflow.random.shuffle(points)
    return points, label

# plot loss and acuracy for each epoch
def plot_train_loss_accuracy(save_path, train_loss, train_accuracy, val_loss, val_accuracy):
    #print('Training Set Loss: ', train_loss)
    #print('Validation Set Loss: ', val_loss)
    plt.figure(figsize=(10, 10))
    plt.plot(train_loss,'o-g', label="Training Set")
    plt.plot(val_loss,'o-r', label="Validation Set")
    plt.title('Training and Validation Sets Loss')
    plt.legend(loc="upper right")
    plt.savefig(save_path + '-train-val-loss.jpg', dpi=200)
    plt.show()
    #print('Training Set Accuracy: ', train_accuracy)
    #print('Validation Set Accuracy: ', val_accuracy)
    plt.figure(figsize=(10, 10))
    plt.plot(train_accuracy,'o-g', label="Training Set")
    plt.plot(val_accuracy,'o-r', label="Validation Set")
    plt.title('Training and Validation Sets Accuracy')
    plt.legend(loc="lower right")
    plt.savefig(save_path + '-train-val-accuracy.jpg', dpi=200)
    plt.show()

def plot_confusion_matrix(cm, classes, save_path, normalize=True, title='Confusion matrix', cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.figure(figsize=(10,10))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()

    tick_marks = numpy.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, numpy.newaxis]
        cm = numpy.around(cm, decimals=2)
        cm[numpy.isnan(cm)] = 0.0
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')
    
    thresh = cm.max() / 2.

    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j], horizontalalignment="center", color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.savefig(save_path + '-confusion-matrix.jpg', bbox_inches='tight', dpi=200)
    plt.show()

# %%
# only log critical messages
logger = logging.getLogger()
logger.setLevel(logging.CRITICAL)

# %%
# load images csv file
images_data = pandas.read_csv(os.path.join(DATASET_PATH, 'images.csv'))

# extract images path and class labels
images_X = images_data[['filename']]
images_Y = images_data[['class_label']]

# load pointclouds csv file
pointclouds_data = pandas.read_csv(os.path.join(DATASET_PATH, 'pointclouds.csv'))

# extract images path and class labels
pointclouds_X = pointclouds_data[['filename']]
pointclouds_Y = pointclouds_data[['class_label']]

# %% [markdown]
# ## **Stratified K-Fold Cross Validation for pointclouds**

# %%
def conv_bn(x, filters):
    x = layers.Conv1D(filters, kernel_size=1, padding="valid")(x)
    x = layers.BatchNormalization(momentum=0.0)(x)
    return layers.Activation("relu")(x)

def dense_bn(x, filters):
    x = layers.Dense(filters)(x)
    x = layers.BatchNormalization(momentum=0.0)(x)
    return layers.Activation("relu")(x)

# %%
class OrthogonalRegularizer(tensorflow.keras.regularizers.Regularizer):
    def __init__(self, num_features, l2reg=0.001):
        self.num_features = num_features
        self.l2reg = l2reg
        self.eye = tensorflow.eye(num_features)

    def __call__(self, x):
        x = tensorflow.reshape(x, (-1, self.num_features, self.num_features))
        xxt = tensorflow.tensordot(x, x, axes=(2, 2))
        xxt = tensorflow.reshape(xxt, (-1, self.num_features, self.num_features))
        return tensorflow.reduce_sum(self.l2reg * tensorflow.square(xxt - self.eye))

# %%
def tnet(inputs, num_features):

    # Initalise bias as the indentity matrix
    bias = tensorflow.keras.initializers.Constant(numpy.eye(num_features).flatten())
    reg = OrthogonalRegularizer(num_features)

    x = conv_bn(inputs, 32)
    x = conv_bn(x, 64)
    x = conv_bn(x, 512)
    x = layers.GlobalMaxPooling1D()(x)
    x = dense_bn(x, 256)
    x = dense_bn(x, 128)
    x = layers.Dense(
        num_features * num_features,
        kernel_initializer="zeros",
        bias_initializer=bias,
        activity_regularizer=reg,
    )(x)
    feat_T = layers.Reshape((num_features, num_features))(x)
    # Apply affine transformation to input features
    return layers.Dot(axes=(2, 1))([inputs, feat_T])

# %%
def pointclouds_kfold_validation(model_name, n_splits, test_size, shuffle, layers, learning_rate, decay, target_size, epochs, batch_size, resample_data=0):
    global pointclouds_data
    global pointclouds_X
    global pointclouds_Y
    if resample_data > 0:
        pointclouds_data = pointclouds_data.groupby('class_label', group_keys=False).apply(lambda x: x.sample(min(len(x), resample_data)))
        pointclouds_X = pointclouds_data[['filename']]
        pointclouds_Y = pointclouds_data[['class_label']]

    # fold counter
    fold_counter = 1
    
    # arrays to store test set loss and accuracy scores for each fold
    TEST_LOSS = []
    TEST_ACCURACY = []
    
    # split train and test dataset
    pointclouds_train, pointclouds_test = train_test_split(pointclouds_data, test_size=test_size, stratify=pointclouds_Y)
    pointclouds_train_X = pointclouds_train[['filename']]
    pointclouds_train_Y = pointclouds_train[['class_label']]

    # define stratified k fold cross validation parameters
    stratified_kfold = StratifiedKFold(n_splits=n_splits, shuffle=shuffle)

    # test data arrays
    test_pointclouds = []
    test_labels = []
    test_string_labels = {}

    # test split ready
    for index, test_data_row in pointclouds_test.iterrows():
        test_pointclouds.append(trimesh.load(test_data_row['filename'], force='mesh').sample(target_size))
        test_labels.append(class_labels_dict[test_data_row['class_label']])
        test_string_labels[index] = test_data_row['class_label']
    
    # convert to numpy array
    test_pointclouds = numpy.array(test_pointclouds)
    test_labels = numpy.array(test_labels)
    
    # debugging
    #print(len(test_pointclouds))
    #print(len(test_labels))
    #print(test_pointclouds)
    #print(test_labels)

    # create test tf.data.Dataset
    test_dataset = tensorflow.data.Dataset.from_tensor_slices((test_pointclouds, test_labels))
    test_dataset = test_dataset.shuffle(len(test_pointclouds)).batch(batch_size)
    print("Found " + str(len(pointclouds_test)) + " validated pointcloud filenames belonging to " + str(len(pointclouds_test['class_label'].unique())) + " classes.")


    # generate train and validation folds
    for train_index, validation_index in stratified_kfold.split(pointclouds_train_X, pointclouds_train_Y):
        print("\n-------- STARTING FOLD: " + str(fold_counter) + " --------")

        # best model save path
        if not os.path.isdir(os.path.join(pointclouds_models_save_dir, model_name)):
            os.mkdir(os.path.join(pointclouds_models_save_dir, model_name))
        pointclouds_model_save_path = os.path.join(pointclouds_models_save_dir, model_name, get_model_name(model_name, fold_counter))

        # train and validation data arrays
        train_pointclouds = []
        train_labels = []
        train_string_labels = {}
        validation_pointclouds = []
        validation_labels = []
        validation_string_labels = {}

        # training and test folds indices
        training_data = pointclouds_train.iloc[train_index]
        validation_data = pointclouds_train.iloc[validation_index]

        for index, training_data_row in training_data.iterrows():
            train_pointclouds.append(trimesh.load(training_data_row['filename'], force='mesh').sample(target_size))
            train_labels.append(class_labels_dict[training_data_row['class_label']])
            train_string_labels[index] = training_data_row['class_label']

        # convert to numpy array
        train_pointclouds = numpy.array(train_pointclouds)
        train_labels = numpy.array(train_labels)
    
        # debugging
        #print(len(train_pointclouds))
        #print(len(train_labels))
        #print(train_pointclouds)
        #print(train_labels)

        # create train tf.data.Dataset
        train_dataset = tensorflow.data.Dataset.from_tensor_slices((train_pointclouds, train_labels))
        train_dataset = train_dataset.shuffle(len(train_pointclouds)).map(augment).batch(batch_size)
        print("Found " + str(len(training_data)) + " validated pointcloud filenames belonging to " + str(len(training_data['class_label'].unique())) + " classes.")

        for index, validation_data_row in validation_data.iterrows():
            validation_pointclouds.append(trimesh.load(validation_data_row['filename'], force='mesh').sample(target_size))
            validation_labels.append(class_labels_dict[validation_data_row['class_label']])
            validation_string_labels[index] = validation_data_row['class_label']

        # convert to numpy array
        validation_pointclouds = numpy.array(validation_pointclouds)
        validation_labels = numpy.array(validation_labels)
    
        # debugging
        #print(len(validation_pointclouds))
        #print(len(validation_labels))
        #print(validation_pointclouds)
        #print(validation_labels)

        # create train tf.data.Dataset
        validation_dataset = tensorflow.data.Dataset.from_tensor_slices((validation_pointclouds, validation_labels))
        validation_dataset = validation_dataset.shuffle(len(validation_pointclouds)).map(augment).batch(batch_size)
        print("Found " + str(len(validation_data)) + " validated pointcloud filenames belonging to " + str(len(validation_data['class_label'].unique())) + " classes.")

        # create best model checkpoint
        best_model_checkpoint = tensorflow.keras.callbacks.ModelCheckpoint(pointclouds_model_save_path, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
        callbacks_list = [best_model_checkpoint]

        # define model to be trained and tested
        inputs = tensorflow.keras.Input(shape=(target_size, 3))

        x = tnet(inputs, 3)
        x = conv_bn(x, 32)
        x = conv_bn(x, 32)
        x = tnet(x, 32)
        x = conv_bn(x, 32)
        x = conv_bn(x, 64)
        x = conv_bn(x, 512)
        x = layers.GlobalMaxPooling1D()(x)
        x = dense_bn(x, 256)
        x = layers.Dropout(0.3)(x)
        x = dense_bn(x, 128)
        x = layers.Dropout(0.3)(x)

        outputs = layers.Dense(target_size, activation="softmax")(x)

        model = tensorflow.keras.Model(inputs=inputs, outputs=outputs, name="pointnet")
        model.summary()

        model.compile(
            loss="sparse_categorical_crossentropy",
            optimizer=tensorflow.keras.optimizers.RMSprop(learning_rate=learning_rate, decay=decay),
            metrics=["sparse_categorical_accuracy"],
        )

        history = model.fit(train_dataset, epochs=epochs, validation_data=validation_dataset)

        # plot loss and acuracy for each training/validation fold
        plot_train_loss_accuracy(pointclouds_model_save_path, history.history["loss"], history.history["sparse_categorical_accuracy"],
                                 history.history["val_loss"], history.history["val_sparse_categorical_accuracy"])

        # LOAD BEST MODEL to evaluate the performance of the model on the test set
        #model.load_weights(pointclouds_model_save_path)

        # evaluate the model on the test set
        test_loss, test_accuracy = model.evaluate(test_dataset, batch_size=batch_size)
        print("Best model Test Loss: " + str(test_loss))
        print("Best model Test Accuracy: " + str(test_accuracy))
        
        # store test set loss and accuracy scores for each fold
        TEST_LOSS.append(test_loss)
        TEST_ACCURACY.append(test_accuracy)

        # Confution Matrix 
        Y_pred = model.predict(test_dataset)
        y_pred = numpy.argmax(Y_pred, axis=1)
        print('Confusion Matrix')
        cm = confusion_matrix(test_labels, y_pred)
        plot_confusion_matrix(cm, class_labels_dict.keys(), pointclouds_model_save_path, title='Confusion Matrix')

        # print Classification Report
        print('Classification Report')
        print(classification_report(test_labels, y_pred, target_names=class_labels_dict.keys()))

        # clean up before next fold
        del model
        tensorflow.keras.backend.clear_session()
        fold_counter += 1

# %% [markdown]
# #### **Developer harness test for Stratified K-Fold Cross Validation for pointclouds**

# %%
# clean up before next test
tensorflow.keras.backend.clear_session()

# train, validate and test
pointclouds_kfold_validation("testing-2", 3, 0.10, True, layers, 0.00001, 1e-6, 4096, 800, 32)
# Out:
# Found 394 validated pointcloud filenames belonging to 5 classes.
#
# -------- STARTING FOLD: 1 --------
# Found 2358 validated pointcloud filenames belonging to 5 classes.
# Found 1179 validated pointcloud filenames belonging to 5 classes.
# Model: "pointnet"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 4096, 3)]    0           []
#
#  conv1d (Conv1D)                (None, 4096, 32)     128         ['input_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 4096, 32)    128         ['conv1d[0][0]']
#  alization)
#
#  activation (Activation)        (None, 4096, 32)     0           ['batch_normalization[0][0]']
#
#  conv1d_1 (Conv1D)              (None, 4096, 64)     2112        ['activation[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 4096, 64)    256         ['conv1d_1[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 4096, 64)     0           ['batch_normalization_1[0][0]']
#
#  conv1d_2 (Conv1D)              (None, 4096, 512)    33280       ['activation_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 4096, 512)   2048        ['conv1d_2[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 4096, 512)    0           ['batch_normalization_2[0][0]']
#
#  global_max_pooling1d (GlobalMa  (None, 512)         0           ['activation_2[0][0]']
#  xPooling1D)
#
#  dense (Dense)                  (None, 256)          131328      ['global_max_pooling1d[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 256)         1024        ['dense[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 256)          0           ['batch_normalization_3[0][0]']
#
#  dense_1 (Dense)                (None, 128)          32896       ['activation_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 128)         512         ['dense_1[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 128)          0           ['batch_normalization_4[0][0]']
#
#  dense_2 (Dense)                (None, 9)            1161        ['activation_4[0][0]']
#
#  reshape (Reshape)              (None, 3, 3)         0           ['dense_2[0][0]']
#
#  dot (Dot)                      (None, 4096, 3)      0           ['input_1[0][0]',
#                                                                   'reshape[0][0]']
#
#  conv1d_3 (Conv1D)              (None, 4096, 32)     128         ['dot[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 4096, 32)    128         ['conv1d_3[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 4096, 32)     0           ['batch_normalization_5[0][0]']
#
#  conv1d_4 (Conv1D)              (None, 4096, 32)     1056        ['activation_5[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 4096, 32)    128         ['conv1d_4[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 4096, 32)     0           ['batch_normalization_6[0][0]']
#
#  conv1d_5 (Conv1D)              (None, 4096, 32)     1056        ['activation_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 4096, 32)    128         ['conv1d_5[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 4096, 32)     0           ['batch_normalization_7[0][0]']
#
#  conv1d_6 (Conv1D)              (None, 4096, 64)     2112        ['activation_7[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 4096, 64)    256         ['conv1d_6[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 4096, 64)     0           ['batch_normalization_8[0][0]']
#
#  conv1d_7 (Conv1D)              (None, 4096, 512)    33280       ['activation_8[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 4096, 512)   2048        ['conv1d_7[0][0]']
#  rmalization)
#
#  activation_9 (Activation)      (None, 4096, 512)    0           ['batch_normalization_9[0][0]']
#
#  global_max_pooling1d_1 (Global  (None, 512)         0           ['activation_9[0][0]']
#  MaxPooling1D)
#
#  dense_3 (Dense)                (None, 256)          131328      ['global_max_pooling1d_1[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 256)         1024        ['dense_3[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 256)          0           ['batch_normalization_10[0][0]']
#
#  dense_4 (Dense)                (None, 128)          32896       ['activation_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 128)         512         ['dense_4[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 128)          0           ['batch_normalization_11[0][0]']
#
#  dense_5 (Dense)                (None, 1024)         132096      ['activation_11[0][0]']
#
#  reshape_1 (Reshape)            (None, 32, 32)       0           ['dense_5[0][0]']
#
#  dot_1 (Dot)                    (None, 4096, 32)     0           ['activation_6[0][0]',
#                                                                   'reshape_1[0][0]']
#
#  conv1d_8 (Conv1D)              (None, 4096, 32)     1056        ['dot_1[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 4096, 32)    128         ['conv1d_8[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 4096, 32)     0           ['batch_normalization_12[0][0]']
#
#  conv1d_9 (Conv1D)              (None, 4096, 64)     2112        ['activation_12[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 4096, 64)    256         ['conv1d_9[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 4096, 64)     0           ['batch_normalization_13[0][0]']
#
#  conv1d_10 (Conv1D)             (None, 4096, 512)    33280       ['activation_13[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 4096, 512)   2048        ['conv1d_10[0][0]']
#  ormalization)
#
#  activation_14 (Activation)     (None, 4096, 512)    0           ['batch_normalization_14[0][0]']
#
#  global_max_pooling1d_2 (Global  (None, 512)         0           ['activation_14[0][0]']
#  MaxPooling1D)
#
#  dense_6 (Dense)                (None, 256)          131328      ['global_max_pooling1d_2[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 256)         1024        ['dense_6[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 256)          0           ['batch_normalization_15[0][0]']
#
#  dropout (Dropout)              (None, 256)          0           ['activation_15[0][0]']
#
#  dense_7 (Dense)                (None, 128)          32896       ['dropout[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 128)         512         ['dense_7[0][0]']
#  ormalization)
#
#  activation_16 (Activation)     (None, 128)          0           ['batch_normalization_16[0][0]']
#
#  dropout_1 (Dropout)            (None, 128)          0           ['activation_16[0][0]']
#
#  dense_8 (Dense)                (None, 4096)         528384      ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 1,276,073
# Trainable params: 1,269,993
# Non-trainable params: 6,080
# __________________________________________________________________________________________________
# Epoch 1/800
# 74/74 [==============================] - 13s 132ms/step - loss: 10.4103 - sparse_categorical_accuracy: 0.0000e+00 - val_loss: 279457717813248.0000 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 2/800
# 74/74 [==============================] - 10s 129ms/step - loss: 10.2942 - sparse_categorical_accuracy: 4.2409e-04 - val_loss: 91626650449477632.0000 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 3/800
# 74/74 [==============================] - 10s 129ms/step - loss: 10.1894 - sparse_categorical_accuracy: 0.0013 - val_loss: 7978651.0000 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 4/800
# 74/74 [==============================] - 10s 130ms/step - loss: 10.0813 - sparse_categorical_accuracy: 0.0059 - val_loss: 32867467919360.0000 - val_sparse_categorical_accuracy: 0.0059
# Epoch 5/800
# 74/74 [==============================] - 10s 131ms/step - loss: 9.9707 - sparse_categorical_accuracy: 0.0140 - val_loss: 3709668748689408.0000 - val_sparse_categorical_accuracy: 0.0280
# Epoch 6/800
# 74/74 [==============================] - 10s 131ms/step - loss: 9.8767 - sparse_categorical_accuracy: 0.0314 - val_loss: 162611.0156 - val_sparse_categorical_accuracy: 0.0170
# Epoch 7/800
# 74/74 [==============================] - 10s 131ms/step - loss: 9.7865 - sparse_categorical_accuracy: 0.0581 - val_loss: 653580742688768.0000 - val_sparse_categorical_accuracy: 0.2137
# Epoch 8/800
# 74/74 [==============================] - 10s 131ms/step - loss: 9.7093 - sparse_categorical_accuracy: 0.1179 - val_loss: 60901600.0000 - val_sparse_categorical_accuracy: 0.1654
# Epoch 9/800
# 74/74 [==============================] - 10s 131ms/step - loss: 9.6125 - sparse_categorical_accuracy: 0.1675 - val_loss: 104749936.0000 - val_sparse_categorical_accuracy: 0.2299
# Epoch 10/800
# 74/74 [==============================] - 10s 131ms/step - loss: 9.5178 - sparse_categorical_accuracy: 0.2222 - val_loss: 187154256.0000 - val_sparse_categorical_accuracy: 0.2519
# Epoch 11/800
# 74/74 [==============================] - 10s 131ms/step - loss: 9.4265 - sparse_categorical_accuracy: 0.2307 - val_loss: 3584978827962482688.0000 - val_sparse_categorical_accuracy: 0.3198
# Epoch 12/800
# 74/74 [==============================] - 10s 131ms/step - loss: 9.3422 - sparse_categorical_accuracy: 0.2701 - val_loss: 3283141183668224.0000 - val_sparse_categorical_accuracy: 0.2892
# Epoch 13/800
# 74/74 [==============================] - 10s 131ms/step - loss: 9.2264 - sparse_categorical_accuracy: 0.3066 - val_loss: 217194434574417920.0000 - val_sparse_categorical_accuracy: 0.2816
# Epoch 14/800
# 74/74 [==============================] - 10s 131ms/step - loss: 9.1313 - sparse_categorical_accuracy: 0.3028 - val_loss: 20248727552.0000 - val_sparse_categorical_accuracy: 0.2672
# Epoch 15/800
# 74/74 [==============================] - 10s 131ms/step - loss: 9.0375 - sparse_categorical_accuracy: 0.3121 - val_loss: 633577082831503360.0000 - val_sparse_categorical_accuracy: 0.3885
# Epoch 16/800
# 74/74 [==============================] - 10s 131ms/step - loss: 8.9548 - sparse_categorical_accuracy: 0.3185 - val_loss: 2978288128.0000 - val_sparse_categorical_accuracy: 0.2909
# Epoch 17/800
# 74/74 [==============================] - 10s 132ms/step - loss: 8.8846 - sparse_categorical_accuracy: 0.2952 - val_loss: 96281524047693479936.0000 - val_sparse_categorical_accuracy: 0.4394
# Epoch 18/800
# 74/74 [==============================] - 10s 131ms/step - loss: 8.7803 - sparse_categorical_accuracy: 0.3291 - val_loss: 291821064468679360512.0000 - val_sparse_categorical_accuracy: 0.3859
# Epoch 19/800
# 74/74 [==============================] - 10s 131ms/step - loss: 8.6942 - sparse_categorical_accuracy: 0.3244 - val_loss: 90432855699619840.0000 - val_sparse_categorical_accuracy: 0.3902
# Epoch 20/800
# 74/74 [==============================] - 10s 131ms/step - loss: 8.6213 - sparse_categorical_accuracy: 0.3456 - val_loss: 15125760435088969957376.0000 - val_sparse_categorical_accuracy: 0.3384
# Epoch 21/800
# 74/74 [==============================] - 10s 131ms/step - loss: 8.4996 - sparse_categorical_accuracy: 0.3461 - val_loss: 5021315122669289472.0000 - val_sparse_categorical_accuracy: 0.4131
# Epoch 22/800
# 74/74 [==============================] - 10s 131ms/step - loss: 8.4276 - sparse_categorical_accuracy: 0.3452 - val_loss: 3174889303226449920.0000 - val_sparse_categorical_accuracy: 0.4207
# Epoch 23/800
# 74/74 [==============================] - 10s 131ms/step - loss: 8.3325 - sparse_categorical_accuracy: 0.3507 - val_loss: 71031591359538528256.0000 - val_sparse_categorical_accuracy: 0.4088
# Epoch 24/800
# 74/74 [==============================] - 10s 131ms/step - loss: 8.2119 - sparse_categorical_accuracy: 0.3550 - val_loss: 634962811079884800.0000 - val_sparse_categorical_accuracy: 0.2960
# Epoch 25/800
# 74/74 [==============================] - 10s 131ms/step - loss: 8.1121 - sparse_categorical_accuracy: 0.3656 - val_loss: 2140490432512.0000 - val_sparse_categorical_accuracy: 0.2299
# Epoch 26/800
# 74/74 [==============================] - 10s 131ms/step - loss: 8.0434 - sparse_categorical_accuracy: 0.3643 - val_loss: 93768155503001600.0000 - val_sparse_categorical_accuracy: 0.3342
# Epoch 27/800
# 74/74 [==============================] - 10s 131ms/step - loss: 7.9240 - sparse_categorical_accuracy: 0.3715 - val_loss: 10804811776.0000 - val_sparse_categorical_accuracy: 0.2468
# Epoch 28/800
# 74/74 [==============================] - 10s 131ms/step - loss: 7.8422 - sparse_categorical_accuracy: 0.3770 - val_loss: 16762293104381649747968.0000 - val_sparse_categorical_accuracy: 0.4182
# Epoch 29/800
# 74/74 [==============================] - 10s 132ms/step - loss: 7.7715 - sparse_categorical_accuracy: 0.3740 - val_loss: 89879981739474944.0000 - val_sparse_categorical_accuracy: 0.4309
# Epoch 30/800
# 74/74 [==============================] - 10s 131ms/step - loss: 7.6372 - sparse_categorical_accuracy: 0.3830 - val_loss: 361455267184257093599232.0000 - val_sparse_categorical_accuracy: 0.3986
# Epoch 31/800
# 74/74 [==============================] - 10s 132ms/step - loss: 7.5389 - sparse_categorical_accuracy: 0.3868 - val_loss: 197243288188817158176768.0000 - val_sparse_categorical_accuracy: 0.3936
# Epoch 32/800
# 74/74 [==============================] - 10s 132ms/step - loss: 7.4601 - sparse_categorical_accuracy: 0.3804 - val_loss: 479873466166673408.0000 - val_sparse_categorical_accuracy: 0.3944
# Epoch 33/800
# 74/74 [==============================] - 10s 132ms/step - loss: 7.3728 - sparse_categorical_accuracy: 0.3868 - val_loss: 197993615189809823744.0000 - val_sparse_categorical_accuracy: 0.4020
# Epoch 34/800
# 74/74 [==============================] - 10s 132ms/step - loss: 7.2740 - sparse_categorical_accuracy: 0.3821 - val_loss: 13242843500375965696.0000 - val_sparse_categorical_accuracy: 0.3562
# Epoch 35/800
# 74/74 [==============================] - 10s 132ms/step - loss: 7.1370 - sparse_categorical_accuracy: 0.3902 - val_loss: 46147029798177633992704.0000 - val_sparse_categorical_accuracy: 0.4207
# Epoch 36/800
# 74/74 [==============================] - 10s 132ms/step - loss: 7.0894 - sparse_categorical_accuracy: 0.3910 - val_loss: 3678364342681600.0000 - val_sparse_categorical_accuracy: 0.3299
# Epoch 37/800
# 74/74 [==============================] - 10s 131ms/step - loss: 6.9777 - sparse_categorical_accuracy: 0.3906 - val_loss: 46781886464.0000 - val_sparse_categorical_accuracy: 0.4148
# Epoch 38/800
# 74/74 [==============================] - 10s 131ms/step - loss: 6.8775 - sparse_categorical_accuracy: 0.3893 - val_loss: 5962383121973248.0000 - val_sparse_categorical_accuracy: 0.3808
# Epoch 39/800
# 74/74 [==============================] - 10s 131ms/step - loss: 6.7947 - sparse_categorical_accuracy: 0.3876 - val_loss: 1607273063988630388736.0000 - val_sparse_categorical_accuracy: 0.4114
# Epoch 40/800
# 74/74 [==============================] - 10s 131ms/step - loss: 6.7511 - sparse_categorical_accuracy: 0.3995 - val_loss: 153418630955008.0000 - val_sparse_categorical_accuracy: 0.4105
# Epoch 41/800
# 74/74 [==============================] - 10s 132ms/step - loss: 6.6321 - sparse_categorical_accuracy: 0.3830 - val_loss: 593126943398821888.0000 - val_sparse_categorical_accuracy: 0.4182
# Epoch 42/800
# 74/74 [==============================] - 10s 132ms/step - loss: 6.5245 - sparse_categorical_accuracy: 0.4067 - val_loss: 38543112011776.0000 - val_sparse_categorical_accuracy: 0.3554
# Epoch 43/800
# 74/74 [==============================] - 10s 132ms/step - loss: 6.4136 - sparse_categorical_accuracy: 0.4118 - val_loss: 2395418022505349120.0000 - val_sparse_categorical_accuracy: 0.4046
# Epoch 44/800
# 74/74 [==============================] - 10s 132ms/step - loss: 6.3807 - sparse_categorical_accuracy: 0.4029 - val_loss: 4014735360000.0000 - val_sparse_categorical_accuracy: 0.3155
# Epoch 45/800
# 74/74 [==============================] - 10s 132ms/step - loss: 6.2635 - sparse_categorical_accuracy: 0.3965 - val_loss: 330403244146688000000.0000 - val_sparse_categorical_accuracy: 0.4444
# Epoch 46/800
# 74/74 [==============================] - 10s 132ms/step - loss: 6.1710 - sparse_categorical_accuracy: 0.4084 - val_loss: 13760041320448.0000 - val_sparse_categorical_accuracy: 0.3418
# Epoch 47/800
# 74/74 [==============================] - 10s 132ms/step - loss: 6.0981 - sparse_categorical_accuracy: 0.3969 - val_loss: 318182726557818159104.0000 - val_sparse_categorical_accuracy: 0.3953
# Epoch 48/800
# 74/74 [==============================] - 10s 131ms/step - loss: 5.9846 - sparse_categorical_accuracy: 0.4012 - val_loss: 19248949248.0000 - val_sparse_categorical_accuracy: 0.4029
# Epoch 49/800
# 74/74 [==============================] - 10s 132ms/step - loss: 5.8856 - sparse_categorical_accuracy: 0.4067 - val_loss: 626183966646337536.0000 - val_sparse_categorical_accuracy: 0.3859
# Epoch 50/800
# 74/74 [==============================] - 10s 132ms/step - loss: 5.7858 - sparse_categorical_accuracy: 0.4080 - val_loss: 2140966226855660093440.0000 - val_sparse_categorical_accuracy: 0.3588
# Epoch 51/800
# 74/74 [==============================] - 10s 132ms/step - loss: 5.6996 - sparse_categorical_accuracy: 0.4080 - val_loss: 5446473808306736463872.0000 - val_sparse_categorical_accuracy: 0.4054
# Epoch 52/800
# 74/74 [==============================] - 10s 132ms/step - loss: 5.6184 - sparse_categorical_accuracy: 0.4075 - val_loss: 816190486216704.0000 - val_sparse_categorical_accuracy: 0.4165
# Epoch 53/800
# 74/74 [==============================] - 10s 132ms/step - loss: 5.5082 - sparse_categorical_accuracy: 0.3940 - val_loss: 13033616605893726568448.0000 - val_sparse_categorical_accuracy: 0.3800
# Epoch 54/800
# 74/74 [==============================] - 10s 132ms/step - loss: 5.4586 - sparse_categorical_accuracy: 0.3859 - val_loss: 65168621113966592.0000 - val_sparse_categorical_accuracy: 0.4292
# Epoch 55/800
# 74/74 [==============================] - 10s 132ms/step - loss: 5.3486 - sparse_categorical_accuracy: 0.4063 - val_loss: 522064587154182373376.0000 - val_sparse_categorical_accuracy: 0.4368
# Epoch 56/800
# 74/74 [==============================] - 10s 132ms/step - loss: 5.2304 - sparse_categorical_accuracy: 0.4075 - val_loss: 48448382718562839560192.0000 - val_sparse_categorical_accuracy: 0.3969
# Epoch 57/800
# 74/74 [==============================] - 10s 132ms/step - loss: 5.1494 - sparse_categorical_accuracy: 0.4012 - val_loss: 5454325248.0000 - val_sparse_categorical_accuracy: 0.3588
# Epoch 58/800
# 74/74 [==============================] - 10s 131ms/step - loss: 5.0563 - sparse_categorical_accuracy: 0.4059 - val_loss: 1535789298349023678169088.0000 - val_sparse_categorical_accuracy: 0.4266
# Epoch 59/800
# 74/74 [==============================] - 10s 131ms/step - loss: 4.9921 - sparse_categorical_accuracy: 0.4071 - val_loss: 68306107608596480.0000 - val_sparse_categorical_accuracy: 0.4029
# Epoch 60/800
# 74/74 [==============================] - 10s 131ms/step - loss: 4.9054 - sparse_categorical_accuracy: 0.3919 - val_loss: 1107399541785851068416.0000 - val_sparse_categorical_accuracy: 0.3851
# Epoch 61/800
# 74/74 [==============================] - 10s 131ms/step - loss: 4.8161 - sparse_categorical_accuracy: 0.3978 - val_loss: 898726091847069734010880.0000 - val_sparse_categorical_accuracy: 0.3885
# Epoch 62/800
# 74/74 [==============================] - 10s 131ms/step - loss: 4.7242 - sparse_categorical_accuracy: 0.4042 - val_loss: 20250338967448190976.0000 - val_sparse_categorical_accuracy: 0.4275
# Epoch 63/800
# 74/74 [==============================] - 10s 132ms/step - loss: 4.6493 - sparse_categorical_accuracy: 0.3974 - val_loss: 3332319302236766208.0000 - val_sparse_categorical_accuracy: 0.4461
# Epoch 64/800
# 74/74 [==============================] - 10s 131ms/step - loss: 4.5580 - sparse_categorical_accuracy: 0.3880 - val_loss: 14543987146752.0000 - val_sparse_categorical_accuracy: 0.3639
# Epoch 65/800
# 74/74 [==============================] - 10s 131ms/step - loss: 4.4764 - sparse_categorical_accuracy: 0.4131 - val_loss: 72362296197775360.0000 - val_sparse_categorical_accuracy: 0.4555
# Epoch 66/800
# 74/74 [==============================] - 10s 131ms/step - loss: 4.4263 - sparse_categorical_accuracy: 0.4135 - val_loss: 2594709176320.0000 - val_sparse_categorical_accuracy: 0.3791
# Epoch 67/800
# 74/74 [==============================] - 10s 131ms/step - loss: 4.3166 - sparse_categorical_accuracy: 0.4054 - val_loss: 159934398332928.0000 - val_sparse_categorical_accuracy: 0.2621
# Epoch 68/800
# 74/74 [==============================] - 10s 131ms/step - loss: 4.2478 - sparse_categorical_accuracy: 0.4148 - val_loss: 103721760903179272192.0000 - val_sparse_categorical_accuracy: 0.3910
# Epoch 69/800
# 74/74 [==============================] - 10s 131ms/step - loss: 4.1966 - sparse_categorical_accuracy: 0.3995 - val_loss: 395767292025267428524032.0000 - val_sparse_categorical_accuracy: 0.4300
# Epoch 70/800
# 74/74 [==============================] - 10s 131ms/step - loss: 4.1021 - sparse_categorical_accuracy: 0.4042 - val_loss: 449348341670751502336.0000 - val_sparse_categorical_accuracy: 0.4148
# Epoch 71/800
# 74/74 [==============================] - 10s 131ms/step - loss: 4.0450 - sparse_categorical_accuracy: 0.4029 - val_loss: 13196099725049813008384.0000 - val_sparse_categorical_accuracy: 0.4461
# Epoch 72/800
# 74/74 [==============================] - 10s 131ms/step - loss: 3.9677 - sparse_categorical_accuracy: 0.4143 - val_loss: 1787626466466122956800.0000 - val_sparse_categorical_accuracy: 0.4198
# Epoch 73/800
# 74/74 [==============================] - 10s 131ms/step - loss: 3.9087 - sparse_categorical_accuracy: 0.3995 - val_loss: 10445607424491520.0000 - val_sparse_categorical_accuracy: 0.3919
# Epoch 74/800
# 74/74 [==============================] - 10s 131ms/step - loss: 3.8416 - sparse_categorical_accuracy: 0.3986 - val_loss: 73903889741164744540160.0000 - val_sparse_categorical_accuracy: 0.3944
# Epoch 75/800
# 74/74 [==============================] - 10s 131ms/step - loss: 3.7893 - sparse_categorical_accuracy: 0.4059 - val_loss: 4021786485253472256.0000 - val_sparse_categorical_accuracy: 0.3885
# Epoch 76/800
# 74/74 [==============================] - 10s 131ms/step - loss: 3.7189 - sparse_categorical_accuracy: 0.4177 - val_loss: 163061435391436340068352.0000 - val_sparse_categorical_accuracy: 0.4071
# Epoch 77/800
# 74/74 [==============================] - 10s 131ms/step - loss: 3.6434 - sparse_categorical_accuracy: 0.4042 - val_loss: 272701964636538273792.0000 - val_sparse_categorical_accuracy: 0.3639
# Epoch 78/800
# 74/74 [==============================] - 10s 131ms/step - loss: 3.5929 - sparse_categorical_accuracy: 0.4012 - val_loss: 251087017939566592.0000 - val_sparse_categorical_accuracy: 0.4165
# Epoch 79/800
# 74/74 [==============================] - 10s 131ms/step - loss: 3.5394 - sparse_categorical_accuracy: 0.4037 - val_loss: 175425138886443008.0000 - val_sparse_categorical_accuracy: 0.3571
# Epoch 80/800
# 74/74 [==============================] - 10s 131ms/step - loss: 3.4846 - sparse_categorical_accuracy: 0.4080 - val_loss: 2915174409297387847680.0000 - val_sparse_categorical_accuracy: 0.4198
# Epoch 81/800
# 74/74 [==============================] - 10s 131ms/step - loss: 3.4269 - sparse_categorical_accuracy: 0.4063 - val_loss: 29500556680206745600.0000 - val_sparse_categorical_accuracy: 0.4427
# Epoch 82/800
# 74/74 [==============================] - 10s 131ms/step - loss: 3.3713 - sparse_categorical_accuracy: 0.4105 - val_loss: 606280634674515357466624.0000 - val_sparse_categorical_accuracy: 0.4156
# Epoch 83/800
# 74/74 [==============================] - 10s 131ms/step - loss: 3.3670 - sparse_categorical_accuracy: 0.4067 - val_loss: 559957999616.0000 - val_sparse_categorical_accuracy: 0.3690
# Epoch 84/800
# 74/74 [==============================] - 10s 131ms/step - loss: 3.3201 - sparse_categorical_accuracy: 0.4075 - val_loss: 438878179688448.0000 - val_sparse_categorical_accuracy: 0.3384
# Epoch 85/800
# 74/74 [==============================] - 10s 131ms/step - loss: 3.2537 - sparse_categorical_accuracy: 0.3999 - val_loss: 6709414874110524129280.0000 - val_sparse_categorical_accuracy: 0.3707
# Epoch 86/800
# 74/74 [==============================] - 10s 131ms/step - loss: 3.2159 - sparse_categorical_accuracy: 0.4114 - val_loss: 33877454342848512.0000 - val_sparse_categorical_accuracy: 0.3232
# Epoch 87/800
# 74/74 [==============================] - 10s 131ms/step - loss: 3.1744 - sparse_categorical_accuracy: 0.4029 - val_loss: 1592300002602507042816.0000 - val_sparse_categorical_accuracy: 0.4292
# Epoch 88/800
# 74/74 [==============================] - 10s 131ms/step - loss: 3.1298 - sparse_categorical_accuracy: 0.4173 - val_loss: 275595131080356608868352.0000 - val_sparse_categorical_accuracy: 0.4148
# Epoch 89/800
# 74/74 [==============================] - 10s 131ms/step - loss: 3.1125 - sparse_categorical_accuracy: 0.4169 - val_loss: 422536513132922142720.0000 - val_sparse_categorical_accuracy: 0.3885
# Epoch 90/800
# 74/74 [==============================] - 10s 131ms/step - loss: 3.0832 - sparse_categorical_accuracy: 0.4131 - val_loss: 744761004302270464.0000 - val_sparse_categorical_accuracy: 0.4097
# Epoch 91/800
# 74/74 [==============================] - 10s 131ms/step - loss: 3.0160 - sparse_categorical_accuracy: 0.4207 - val_loss: 688743704365629440.0000 - val_sparse_categorical_accuracy: 0.4258
# Epoch 92/800
# 74/74 [==============================] - 10s 131ms/step - loss: 3.0380 - sparse_categorical_accuracy: 0.4059 - val_loss: 35117430583970764947456.0000 - val_sparse_categorical_accuracy: 0.4580
# Epoch 93/800
# 74/74 [==============================] - 10s 131ms/step - loss: 2.9942 - sparse_categorical_accuracy: 0.4169 - val_loss: 5372258990047298060288.0000 - val_sparse_categorical_accuracy: 0.3986
# Epoch 94/800
# 74/74 [==============================] - 10s 131ms/step - loss: 2.9573 - sparse_categorical_accuracy: 0.4228 - val_loss: 1953785025069502173282304.0000 - val_sparse_categorical_accuracy: 0.4300
# Epoch 95/800
# 74/74 [==============================] - 10s 131ms/step - loss: 2.8903 - sparse_categorical_accuracy: 0.4296 - val_loss: 208412288307452444672.0000 - val_sparse_categorical_accuracy: 0.4046
# Epoch 96/800
# 74/74 [==============================] - 10s 131ms/step - loss: 2.8717 - sparse_categorical_accuracy: 0.4326 - val_loss: 5995611784620856573952.0000 - val_sparse_categorical_accuracy: 0.4131
# Epoch 97/800
# 74/74 [==============================] - 10s 131ms/step - loss: 2.8726 - sparse_categorical_accuracy: 0.4309 - val_loss: 42685945930548997259264.0000 - val_sparse_categorical_accuracy: 0.4266
# Epoch 98/800
# 74/74 [==============================] - 10s 133ms/step - loss: 2.8406 - sparse_categorical_accuracy: 0.4355 - val_loss: 10078618575175680.0000 - val_sparse_categorical_accuracy: 0.3961
# Epoch 99/800
# 74/74 [==============================] - 10s 135ms/step - loss: 2.8326 - sparse_categorical_accuracy: 0.4283 - val_loss: 4238025162752.0000 - val_sparse_categorical_accuracy: 0.3969
# Epoch 100/800
# 74/74 [==============================] - 10s 141ms/step - loss: 2.7800 - sparse_categorical_accuracy: 0.4440 - val_loss: 6320845987110857998336.0000 - val_sparse_categorical_accuracy: 0.4572
# Epoch 101/800
# 74/74 [==============================] - 10s 136ms/step - loss: 2.8063 - sparse_categorical_accuracy: 0.4355 - val_loss: 61982439139128115200.0000 - val_sparse_categorical_accuracy: 0.4741
# Epoch 102/800
# 74/74 [==============================] - 10s 141ms/step - loss: 2.7733 - sparse_categorical_accuracy: 0.4432 - val_loss: 3522695342539669504.0000 - val_sparse_categorical_accuracy: 0.4589
# Epoch 103/800
# 74/74 [==============================] - 10s 142ms/step - loss: 2.7260 - sparse_categorical_accuracy: 0.4504 - val_loss: 515406753976928960512.0000 - val_sparse_categorical_accuracy: 0.4529
# Epoch 104/800
# 74/74 [==============================] - 10s 135ms/step - loss: 2.7561 - sparse_categorical_accuracy: 0.4453 - val_loss: 618037959874052096.0000 - val_sparse_categorical_accuracy: 0.4894
# Epoch 105/800
# 74/74 [==============================] - 10s 131ms/step - loss: 2.6976 - sparse_categorical_accuracy: 0.4491 - val_loss: 14143699870845025386496.0000 - val_sparse_categorical_accuracy: 0.4478
# Epoch 106/800
# 74/74 [==============================] - 10s 136ms/step - loss: 2.6768 - sparse_categorical_accuracy: 0.4610 - val_loss: 50181032086863872.0000 - val_sparse_categorical_accuracy: 0.4292
# Epoch 107/800
# 74/74 [==============================] - 10s 134ms/step - loss: 2.6781 - sparse_categorical_accuracy: 0.4487 - val_loss: 1332147122614566912.0000 - val_sparse_categorical_accuracy: 0.4436
# Epoch 108/800
# 74/74 [==============================] - 10s 133ms/step - loss: 2.6370 - sparse_categorical_accuracy: 0.4580 - val_loss: 17545663508421541888.0000 - val_sparse_categorical_accuracy: 0.4572
# Epoch 109/800
# 74/74 [==============================] - 10s 133ms/step - loss: 2.6497 - sparse_categorical_accuracy: 0.4550 - val_loss: 6792613810676613251072.0000 - val_sparse_categorical_accuracy: 0.4377
# Epoch 110/800
# 74/74 [==============================] - 10s 132ms/step - loss: 2.6351 - sparse_categorical_accuracy: 0.4652 - val_loss: 22334683160223154176.0000 - val_sparse_categorical_accuracy: 0.4648
# Epoch 111/800
# 74/74 [==============================] - 10s 132ms/step - loss: 2.6002 - sparse_categorical_accuracy: 0.4830 - val_loss: 10315870421123072.0000 - val_sparse_categorical_accuracy: 0.4122
# Epoch 112/800
# 74/74 [==============================] - 10s 132ms/step - loss: 2.6012 - sparse_categorical_accuracy: 0.4546 - val_loss: 32614017368300978176.0000 - val_sparse_categorical_accuracy: 0.4801
# Epoch 113/800
# 74/74 [==============================] - 10s 132ms/step - loss: 2.5625 - sparse_categorical_accuracy: 0.4627 - val_loss: 529857397806277328896.0000 - val_sparse_categorical_accuracy: 0.4741
# Epoch 114/800
# 74/74 [==============================] - 10s 132ms/step - loss: 2.5635 - sparse_categorical_accuracy: 0.4656 - val_loss: 202554264780800.0000 - val_sparse_categorical_accuracy: 0.3257
# Epoch 115/800
# 74/74 [==============================] - 10s 132ms/step - loss: 2.5657 - sparse_categorical_accuracy: 0.4758 - val_loss: 4264524633776649666560.0000 - val_sparse_categorical_accuracy: 0.4436
# Epoch 116/800
# 74/74 [==============================] - 10s 132ms/step - loss: 2.5216 - sparse_categorical_accuracy: 0.4902 - val_loss: 144111657253748013531136.0000 - val_sparse_categorical_accuracy: 0.5072
# Epoch 117/800
# 74/74 [==============================] - 10s 132ms/step - loss: 2.5492 - sparse_categorical_accuracy: 0.4712 - val_loss: 231108968972288.0000 - val_sparse_categorical_accuracy: 0.2765
# Epoch 118/800
# 74/74 [==============================] - 10s 132ms/step - loss: 2.5381 - sparse_categorical_accuracy: 0.4707 - val_loss: 4227105163455758336.0000 - val_sparse_categorical_accuracy: 0.4572
# Epoch 119/800
# 74/74 [==============================] - 10s 132ms/step - loss: 2.5132 - sparse_categorical_accuracy: 0.4733 - val_loss: 130847099788506169344.0000 - val_sparse_categorical_accuracy: 0.4818
# Epoch 120/800
# 74/74 [==============================] - 10s 132ms/step - loss: 2.5024 - sparse_categorical_accuracy: 0.4928 - val_loss: 229259702198967184916480.0000 - val_sparse_categorical_accuracy: 0.5352
# Epoch 121/800
# 74/74 [==============================] - 10s 132ms/step - loss: 2.4663 - sparse_categorical_accuracy: 0.5064 - val_loss: 6122266516941397032960.0000 - val_sparse_categorical_accuracy: 0.4724
# Epoch 122/800
# 74/74 [==============================] - 10s 132ms/step - loss: 2.4780 - sparse_categorical_accuracy: 0.4894 - val_loss: 545785168162455552.0000 - val_sparse_categorical_accuracy: 0.4614
# Epoch 123/800
# 74/74 [==============================] - 10s 132ms/step - loss: 2.4669 - sparse_categorical_accuracy: 0.5008 - val_loss: 32574878378342477725696.0000 - val_sparse_categorical_accuracy: 0.4792
# Epoch 124/800
# 74/74 [==============================] - 10s 133ms/step - loss: 2.4804 - sparse_categorical_accuracy: 0.4881 - val_loss: 546364990396682993664.0000 - val_sparse_categorical_accuracy: 0.4953
# Epoch 125/800
# 74/74 [==============================] - 10s 132ms/step - loss: 2.4850 - sparse_categorical_accuracy: 0.4750 - val_loss: 4819862096452821975040.0000 - val_sparse_categorical_accuracy: 0.4784
# Epoch 126/800
# 74/74 [==============================] - 10s 132ms/step - loss: 2.4649 - sparse_categorical_accuracy: 0.4775 - val_loss: 117732957343531430576128.0000 - val_sparse_categorical_accuracy: 0.5021
# Epoch 127/800
# 74/74 [==============================] - 10s 132ms/step - loss: 2.4572 - sparse_categorical_accuracy: 0.4894 - val_loss: 3889351409199480832.0000 - val_sparse_categorical_accuracy: 0.4690
# Epoch 128/800
# 74/74 [==============================] - 10s 132ms/step - loss: 2.4486 - sparse_categorical_accuracy: 0.4873 - val_loss: 8584155648.0000 - val_sparse_categorical_accuracy: 0.4495
# Epoch 129/800
# 74/74 [==============================] - 10s 132ms/step - loss: 2.4256 - sparse_categorical_accuracy: 0.4932 - val_loss: 367103992303804481536.0000 - val_sparse_categorical_accuracy: 0.4606
# Epoch 130/800
# 74/74 [==============================] - 10s 133ms/step - loss: 2.4321 - sparse_categorical_accuracy: 0.4919 - val_loss: 24670049974190912569344.0000 - val_sparse_categorical_accuracy: 0.4970
# Epoch 131/800
# 74/74 [==============================] - 10s 132ms/step - loss: 2.4264 - sparse_categorical_accuracy: 0.4979 - val_loss: 102425084850310479872.0000 - val_sparse_categorical_accuracy: 0.4741
# Epoch 132/800
# 74/74 [==============================] - 10s 131ms/step - loss: 2.4137 - sparse_categorical_accuracy: 0.4953 - val_loss: 7980312569002852352.0000 - val_sparse_categorical_accuracy: 0.5369
# Epoch 133/800
# 74/74 [==============================] - 10s 131ms/step - loss: 2.4166 - sparse_categorical_accuracy: 0.4907 - val_loss: 20948750371892622262272.0000 - val_sparse_categorical_accuracy: 0.5556
# Epoch 134/800
# 74/74 [==============================] - 10s 131ms/step - loss: 2.3858 - sparse_categorical_accuracy: 0.5148 - val_loss: 89868609284550426624.0000 - val_sparse_categorical_accuracy: 0.4996
# Epoch 135/800
# 74/74 [==============================] - 10s 131ms/step - loss: 2.3891 - sparse_categorical_accuracy: 0.5123 - val_loss: 13212162048.0000 - val_sparse_categorical_accuracy: 0.4767
# Epoch 136/800
# 74/74 [==============================] - 10s 130ms/step - loss: 2.4159 - sparse_categorical_accuracy: 0.5072 - val_loss: 66170083281062760284160.0000 - val_sparse_categorical_accuracy: 0.4945
# Epoch 137/800
# 74/74 [==============================] - 10s 130ms/step - loss: 2.4101 - sparse_categorical_accuracy: 0.5102 - val_loss: 23245089783137959936.0000 - val_sparse_categorical_accuracy: 0.4555
# Epoch 138/800
# 74/74 [==============================] - 10s 130ms/step - loss: 2.3829 - sparse_categorical_accuracy: 0.5153 - val_loss: 299733344219151898509312.0000 - val_sparse_categorical_accuracy: 0.5556
# Epoch 139/800
# 74/74 [==============================] - 10s 131ms/step - loss: 2.3978 - sparse_categorical_accuracy: 0.4983 - val_loss: 1681195007534801354752.0000 - val_sparse_categorical_accuracy: 0.4970
# Epoch 140/800
# 74/74 [==============================] - 10s 130ms/step - loss: 2.3732 - sparse_categorical_accuracy: 0.5242 - val_loss: 690587385254293536768.0000 - val_sparse_categorical_accuracy: 0.5615
# Epoch 141/800
# 74/74 [==============================] - 10s 130ms/step - loss: 2.3831 - sparse_categorical_accuracy: 0.5161 - val_loss: 69436230773961129984.0000 - val_sparse_categorical_accuracy: 0.5276
# Epoch 142/800
# 74/74 [==============================] - 10s 131ms/step - loss: 2.3480 - sparse_categorical_accuracy: 0.5314 - val_loss: 3222561378627747840.0000 - val_sparse_categorical_accuracy: 0.5250
# Epoch 143/800
# 74/74 [==============================] - 10s 130ms/step - loss: 2.3521 - sparse_categorical_accuracy: 0.5301 - val_loss: 366518348430385872896.0000 - val_sparse_categorical_accuracy: 0.4495
# Epoch 144/800
# 74/74 [==============================] - 10s 131ms/step - loss: 2.3581 - sparse_categorical_accuracy: 0.5204 - val_loss: 11083222449070062698496.0000 - val_sparse_categorical_accuracy: 0.5115
# Epoch 145/800
# 74/74 [==============================] - 10s 130ms/step - loss: 2.3457 - sparse_categorical_accuracy: 0.5204 - val_loss: 95283007648169984.0000 - val_sparse_categorical_accuracy: 0.4377
# Epoch 146/800
# 74/74 [==============================] - 10s 130ms/step - loss: 2.3205 - sparse_categorical_accuracy: 0.5344 - val_loss: 28163778183718544343040.0000 - val_sparse_categorical_accuracy: 0.5216
# Epoch 147/800
# 74/74 [==============================] - 10s 131ms/step - loss: 2.3356 - sparse_categorical_accuracy: 0.5229 - val_loss: 2507579074805760.0000 - val_sparse_categorical_accuracy: 0.3766
# Epoch 148/800
# 74/74 [==============================] - 10s 130ms/step - loss: 2.3434 - sparse_categorical_accuracy: 0.5216 - val_loss: 25484093480499150848.0000 - val_sparse_categorical_accuracy: 0.5276
# Epoch 149/800
# 74/74 [==============================] - 10s 131ms/step - loss: 2.3343 - sparse_categorical_accuracy: 0.5246 - val_loss: 127837224460300620660736.0000 - val_sparse_categorical_accuracy: 0.4818
# Epoch 150/800
# 74/74 [==============================] - 10s 130ms/step - loss: 2.3510 - sparse_categorical_accuracy: 0.5148 - val_loss: 18940984859415885643776.0000 - val_sparse_categorical_accuracy: 0.5437
# Epoch 151/800
# 74/74 [==============================] - 10s 131ms/step - loss: 2.3119 - sparse_categorical_accuracy: 0.5352 - val_loss: 1622151296.0000 - val_sparse_categorical_accuracy: 0.4767
# Epoch 152/800
# 74/74 [==============================] - 10s 131ms/step - loss: 2.2999 - sparse_categorical_accuracy: 0.5399 - val_loss: 215515472740969829367808.0000 - val_sparse_categorical_accuracy: 0.4860
# Epoch 153/800
# 74/74 [==============================] - 10s 132ms/step - loss: 2.3220 - sparse_categorical_accuracy: 0.5237 - val_loss: 46288438322877440196608.0000 - val_sparse_categorical_accuracy: 0.5352
# Epoch 154/800
# 74/74 [==============================] - 10s 132ms/step - loss: 2.2947 - sparse_categorical_accuracy: 0.5403 - val_loss: 16441562501519018819584.0000 - val_sparse_categorical_accuracy: 0.5081
# Epoch 155/800
# 74/74 [==============================] - 10s 132ms/step - loss: 2.3055 - sparse_categorical_accuracy: 0.5471 - val_loss: 578554673928571635892224.0000 - val_sparse_categorical_accuracy: 0.5369
# Epoch 156/800
# 74/74 [==============================] - 10s 131ms/step - loss: 2.3029 - sparse_categorical_accuracy: 0.5327 - val_loss: 7577726386492669952.0000 - val_sparse_categorical_accuracy: 0.4809
# Epoch 157/800
# 74/74 [==============================] - 10s 131ms/step - loss: 2.3087 - sparse_categorical_accuracy: 0.5250 - val_loss: 235392579618843131904.0000 - val_sparse_categorical_accuracy: 0.4682
# Epoch 158/800
# 74/74 [==============================] - 10s 131ms/step - loss: 2.2944 - sparse_categorical_accuracy: 0.5356 - val_loss: 184729680740352.0000 - val_sparse_categorical_accuracy: 0.3486
# Epoch 159/800
# 74/74 [==============================] - 10s 134ms/step - loss: 2.2879 - sparse_categorical_accuracy: 0.5450 - val_loss: 427168478297521626546176.0000 - val_sparse_categorical_accuracy: 0.5055
# Epoch 160/800
# 74/74 [==============================] - 10s 131ms/step - loss: 2.2713 - sparse_categorical_accuracy: 0.5560 - val_loss: 14096146016239616.0000 - val_sparse_categorical_accuracy: 0.4928
# Epoch 161/800
# ...
# Epoch 747/800
# 74/74 [==============================] - 10s 135ms/step - loss: 1.9063 - sparse_categorical_accuracy: 0.6908 - val_loss: 9443880390885376.0000 - val_sparse_categorical_accuracy: 0.4326
# Epoch 748/800
# 74/74 [==============================] - 10s 136ms/step - loss: 1.9112 - sparse_categorical_accuracy: 0.6874 - val_loss: 190139214294373367808.0000 - val_sparse_categorical_accuracy: 0.6497
# Epoch 749/800
# 74/74 [==============================] - 10s 135ms/step - loss: 1.8522 - sparse_categorical_accuracy: 0.7120 - val_loss: 5514075002552451072.0000 - val_sparse_categorical_accuracy: 0.5674
# Epoch 750/800
# 74/74 [==============================] - 10s 135ms/step - loss: 1.8759 - sparse_categorical_accuracy: 0.7010 - val_loss: 19970543763029799993344.0000 - val_sparse_categorical_accuracy: 0.6387
# Epoch 751/800
# 74/74 [==============================] - 10s 135ms/step - loss: 1.8828 - sparse_categorical_accuracy: 0.6980 - val_loss: 31272007680.0000 - val_sparse_categorical_accuracy: 0.4555
# Epoch 752/800
# 74/74 [==============================] - 10s 137ms/step - loss: 1.8758 - sparse_categorical_accuracy: 0.6968 - val_loss: 8690640111033212993536.0000 - val_sparse_categorical_accuracy: 0.6158
# Epoch 753/800
# 74/74 [==============================] - 10s 136ms/step - loss: 1.8822 - sparse_categorical_accuracy: 0.6985 - val_loss: 764252834727936917504.0000 - val_sparse_categorical_accuracy: 0.7142
# Epoch 754/800
# 74/74 [==============================] - 10s 135ms/step - loss: 1.8917 - sparse_categorical_accuracy: 0.6870 - val_loss: 228330663639036180037632.0000 - val_sparse_categorical_accuracy: 0.6938
# Epoch 755/800
# 74/74 [==============================] - 10s 135ms/step - loss: 1.8642 - sparse_categorical_accuracy: 0.7019 - val_loss: 66513843216541810688.0000 - val_sparse_categorical_accuracy: 0.6200
# Epoch 756/800
# 74/74 [==============================] - 10s 136ms/step - loss: 1.8607 - sparse_categorical_accuracy: 0.7040 - val_loss: 6262849567893487616.0000 - val_sparse_categorical_accuracy: 0.6590
# Epoch 757/800
# 74/74 [==============================] - 10s 135ms/step - loss: 1.8535 - sparse_categorical_accuracy: 0.6980 - val_loss: 55248691281046536192.0000 - val_sparse_categorical_accuracy: 0.4801
# Epoch 758/800
# 74/74 [==============================] - 10s 135ms/step - loss: 1.8703 - sparse_categorical_accuracy: 0.6930 - val_loss: 1723359396096104202240.0000 - val_sparse_categorical_accuracy: 0.6718
# Epoch 759/800
# 74/74 [==============================] - 10s 135ms/step - loss: 1.8481 - sparse_categorical_accuracy: 0.7133 - val_loss: 231744452814440497152.0000 - val_sparse_categorical_accuracy: 0.6539
# Epoch 760/800
# 74/74 [==============================] - 10s 137ms/step - loss: 1.8451 - sparse_categorical_accuracy: 0.7074 - val_loss: 633506582145930362880.0000 - val_sparse_categorical_accuracy: 0.7184
# Epoch 761/800
# 74/74 [==============================] - 10s 136ms/step - loss: 1.8846 - sparse_categorical_accuracy: 0.6891 - val_loss: 60506410749536501760.0000 - val_sparse_categorical_accuracy: 0.5869
# Epoch 762/800
# 74/74 [==============================] - 10s 138ms/step - loss: 1.8950 - sparse_categorical_accuracy: 0.6862 - val_loss: 682264863184352100483072.0000 - val_sparse_categorical_accuracy: 0.6573
# Epoch 763/800
# 74/74 [==============================] - 10s 140ms/step - loss: 1.9007 - sparse_categorical_accuracy: 0.6883 - val_loss: 6398310715451397636096.0000 - val_sparse_categorical_accuracy: 0.7125
# Epoch 764/800
# 74/74 [==============================] - 10s 139ms/step - loss: 1.8425 - sparse_categorical_accuracy: 0.7218 - val_loss: 6421381552432742400.0000 - val_sparse_categorical_accuracy: 0.6556
# Epoch 765/800
# 74/74 [==============================] - 10s 140ms/step - loss: 1.8538 - sparse_categorical_accuracy: 0.7133 - val_loss: 268716206908721346904064.0000 - val_sparse_categorical_accuracy: 0.6633
# Epoch 766/800
# 74/74 [==============================] - 10s 137ms/step - loss: 1.8523 - sparse_categorical_accuracy: 0.7027 - val_loss: 1078330292181139456.0000 - val_sparse_categorical_accuracy: 0.4852
# Epoch 767/800
# 74/74 [==============================] - 10s 136ms/step - loss: 1.8799 - sparse_categorical_accuracy: 0.6925 - val_loss: 431684309138530107392.0000 - val_sparse_categorical_accuracy: 0.6650
# Epoch 768/800
# 74/74 [==============================] - 10s 134ms/step - loss: 1.8637 - sparse_categorical_accuracy: 0.7125 - val_loss: 323204803092289683456.0000 - val_sparse_categorical_accuracy: 0.6921
# Epoch 769/800
# 74/74 [==============================] - 10s 131ms/step - loss: 1.8769 - sparse_categorical_accuracy: 0.6985 - val_loss: 66564873327997685334016.0000 - val_sparse_categorical_accuracy: 0.6590
# Epoch 770/800
# 74/74 [==============================] - 10s 130ms/step - loss: 1.8627 - sparse_categorical_accuracy: 0.7014 - val_loss: 2681280974028800.0000 - val_sparse_categorical_accuracy: 0.6489
# Epoch 771/800
# 74/74 [==============================] - 10s 131ms/step - loss: 1.8815 - sparse_categorical_accuracy: 0.6955 - val_loss: 94184130850920071168.0000 - val_sparse_categorical_accuracy: 0.5971
# Epoch 772/800
# 74/74 [==============================] - 10s 130ms/step - loss: 1.8446 - sparse_categorical_accuracy: 0.7087 - val_loss: 569890754789376.0000 - val_sparse_categorical_accuracy: 0.5937
# Epoch 773/800
# 74/74 [==============================] - 10s 130ms/step - loss: 1.8993 - sparse_categorical_accuracy: 0.6790 - val_loss: 128597729314976166838272.0000 - val_sparse_categorical_accuracy: 0.6175
# Epoch 774/800
# 74/74 [==============================] - 10s 130ms/step - loss: 1.8245 - sparse_categorical_accuracy: 0.7142 - val_loss: 6284956925952.0000 - val_sparse_categorical_accuracy: 0.4266
# Epoch 775/800
# 74/74 [==============================] - 10s 130ms/step - loss: 1.8780 - sparse_categorical_accuracy: 0.7010 - val_loss: 5867228795943312687104.0000 - val_sparse_categorical_accuracy: 0.6548
# Epoch 776/800
# 74/74 [==============================] - 10s 130ms/step - loss: 1.8489 - sparse_categorical_accuracy: 0.7061 - val_loss: 38451958798470663372800.0000 - val_sparse_categorical_accuracy: 0.6658
# Epoch 777/800
# 74/74 [==============================] - 10s 130ms/step - loss: 1.8730 - sparse_categorical_accuracy: 0.7074 - val_loss: 56463372320768.0000 - val_sparse_categorical_accuracy: 0.6073
# Epoch 778/800
# 74/74 [==============================] - 10s 130ms/step - loss: 1.8527 - sparse_categorical_accuracy: 0.7108 - val_loss: 4582520707240536571904.0000 - val_sparse_categorical_accuracy: 0.6590
# Epoch 779/800
# 74/74 [==============================] - 10s 130ms/step - loss: 1.8988 - sparse_categorical_accuracy: 0.6896 - val_loss: 24430145473840699932672.0000 - val_sparse_categorical_accuracy: 0.6701
# Epoch 780/800
# 74/74 [==============================] - 10s 130ms/step - loss: 1.8726 - sparse_categorical_accuracy: 0.7006 - val_loss: 7960530613192743714816.0000 - val_sparse_categorical_accuracy: 0.6794
# Epoch 781/800
# 74/74 [==============================] - 10s 130ms/step - loss: 1.8914 - sparse_categorical_accuracy: 0.6968 - val_loss: 34538319872.0000 - val_sparse_categorical_accuracy: 0.4750
# Epoch 782/800
# 74/74 [==============================] - 10s 130ms/step - loss: 1.8510 - sparse_categorical_accuracy: 0.7065 - val_loss: 189976662495322963968.0000 - val_sparse_categorical_accuracy: 0.6828
# Epoch 783/800
# 74/74 [==============================] - 10s 130ms/step - loss: 1.8470 - sparse_categorical_accuracy: 0.7205 - val_loss: 742964741501821648896.0000 - val_sparse_categorical_accuracy: 0.6022
# Epoch 784/800
# 74/74 [==============================] - 10s 130ms/step - loss: 1.8902 - sparse_categorical_accuracy: 0.6964 - val_loss: 1883469639540223258918912.0000 - val_sparse_categorical_accuracy: 0.6344
# Epoch 785/800
# 74/74 [==============================] - 10s 131ms/step - loss: 1.8666 - sparse_categorical_accuracy: 0.7057 - val_loss: 14994067300685308755968.0000 - val_sparse_categorical_accuracy: 0.6599
# Epoch 786/800
# 74/74 [==============================] - 10s 130ms/step - loss: 1.8858 - sparse_categorical_accuracy: 0.7002 - val_loss: 318261096722989056.0000 - val_sparse_categorical_accuracy: 0.6192
# Epoch 787/800
# 74/74 [==============================] - 10s 130ms/step - loss: 1.8487 - sparse_categorical_accuracy: 0.6942 - val_loss: 5270786135043199729664.0000 - val_sparse_categorical_accuracy: 0.6955
# Epoch 788/800
# 74/74 [==============================] - 10s 130ms/step - loss: 1.8777 - sparse_categorical_accuracy: 0.7010 - val_loss: 548704923684751045296128.0000 - val_sparse_categorical_accuracy: 0.6404
# Epoch 789/800
# 74/74 [==============================] - 10s 130ms/step - loss: 1.8581 - sparse_categorical_accuracy: 0.6989 - val_loss: 3025277287087434891264.0000 - val_sparse_categorical_accuracy: 0.6862
# Epoch 790/800
# 74/74 [==============================] - 10s 130ms/step - loss: 1.8298 - sparse_categorical_accuracy: 0.7150 - val_loss: 23477508051862273654784.0000 - val_sparse_categorical_accuracy: 0.6785
# Epoch 791/800
# 74/74 [==============================] - 10s 130ms/step - loss: 1.8491 - sparse_categorical_accuracy: 0.7087 - val_loss: 35323731475701352628224.0000 - val_sparse_categorical_accuracy: 0.6845
# Epoch 792/800
# 74/74 [==============================] - 10s 131ms/step - loss: 1.8715 - sparse_categorical_accuracy: 0.6947 - val_loss: 328604340044431360.0000 - val_sparse_categorical_accuracy: 0.5827
# Epoch 793/800
# 74/74 [==============================] - 10s 130ms/step - loss: 1.8699 - sparse_categorical_accuracy: 0.7061 - val_loss: 1728899296427769856.0000 - val_sparse_categorical_accuracy: 0.6913
# Epoch 794/800
# 74/74 [==============================] - 10s 131ms/step - loss: 1.8532 - sparse_categorical_accuracy: 0.7065 - val_loss: 119634530228594584584192.0000 - val_sparse_categorical_accuracy: 0.7252
# Epoch 795/800
# 74/74 [==============================] - 10s 130ms/step - loss: 1.8469 - sparse_categorical_accuracy: 0.7142 - val_loss: 992305479680.0000 - val_sparse_categorical_accuracy: 0.5522
# Epoch 796/800
# 74/74 [==============================] - 10s 130ms/step - loss: 1.8633 - sparse_categorical_accuracy: 0.7044 - val_loss: 7851062828518548831207424.0000 - val_sparse_categorical_accuracy: 0.6506
# Epoch 797/800
# 74/74 [==============================] - 10s 131ms/step - loss: 1.8389 - sparse_categorical_accuracy: 0.7184 - val_loss: 5274177345562609713152.0000 - val_sparse_categorical_accuracy: 0.5878
# Epoch 798/800
# 74/74 [==============================] - 10s 130ms/step - loss: 1.8812 - sparse_categorical_accuracy: 0.7053 - val_loss: 2566674380234948608.0000 - val_sparse_categorical_accuracy: 0.7371
# Epoch 799/800
# 74/74 [==============================] - 10s 130ms/step - loss: 1.8530 - sparse_categorical_accuracy: 0.7053 - val_loss: 816424767019024384.0000 - val_sparse_categorical_accuracy: 0.5903
# Epoch 800/800
# 74/74 [==============================] - 10s 130ms/step - loss: 1.8848 - sparse_categorical_accuracy: 0.7002 - val_loss: 5746312388138381128761344.0000 - val_sparse_categorical_accuracy: 0.6344
# 13/13 [==============================] - 0s 24ms/step - loss: 2489664401881734003476895105024.0000 - sparse_categorical_accuracy: 0.6497
# Best model Test Loss: 2.489664401881734e+30
# Best model Test Accuracy: 0.6497461795806885
# Confusion Matrix
# Normalized confusion matrix
# Classification Report
#               precision    recall  f1-score   support
#
#        table       0.17      0.14      0.15        79
#        chair       0.19      0.17      0.18        78
#         lamp       0.19      0.27      0.22        79
#      dresser       0.22      0.24      0.23        79
#         sofa       0.20      0.15      0.17        79
#
#     accuracy                           0.19       394
#    macro avg       0.19      0.19      0.19       394
# weighted avg       0.19      0.19      0.19       394
#
#
# -------- STARTING FOLD: 2 --------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [32], in <module>
#       2 tensorflow.keras.backend.clear_session()
#       4 # train, validate and test
# ----> 5 pointclouds_kfold_validation("testing-2", 3, 0.10, True, layers, 0.00001, 1e-6, 4096, 800, 32)
#
# Input In [31], in pointclouds_kfold_validation(model_name, n_splits, test_size, shuffle, layers, learning_rate, decay, target_size, epochs, batch_size, resample_data)
#      71 validation_data = pointclouds_train.iloc[validation_index]
#      73 for index, training_data_row in training_data.iterrows():
# ---> 74     train_pointclouds.append(trimesh.load(training_data_row['filename'], force='mesh').sample(target_size))
#      75     train_labels.append(class_labels_dict[training_data_row['class_label']])
#      76     train_string_labels[index] = training_data_row['class_label']
#
# File /run/media/rr/M2/DevOps/jupyter-lab/python39_venv/lib/python3.9/site-packages/trimesh/exchange/load.py:127, in load(file_obj, file_type, resolver, force, **kwargs)
#     122     loaded = load_path(file_obj,
#     123                        file_type=file_type,
#     124                        **kwargs)
#     125 elif file_type in mesh_loaders:
#     126     # mesh loaders use mesh loader
# --> 127     loaded = load_mesh(file_obj,
#     128                        file_type=file_type,
#     129                        resolver=resolver,
#     130                        **kwargs)
#     131 elif file_type in compressed_loaders:
#     132     # for archives, like ZIP files
#     133     loaded = load_compressed(file_obj,
#     134                              file_type=file_type,
#     135                              **kwargs)
#
# File /run/media/rr/M2/DevOps/jupyter-lab/python39_venv/lib/python3.9/site-packages/trimesh/constants.py:146, in log_time.<locals>.timed(*args, **kwargs)
#     144 def timed(*args, **kwargs):
#     145     tic = now()
# --> 146     result = method(*args, **kwargs)
#     147     log.debug('%s executed in %.4f seconds.',
#     148               method.__name__,
#     149               now() - tic)
#     150     return result
#
# File /run/media/rr/M2/DevOps/jupyter-lab/python39_venv/lib/python3.9/site-packages/trimesh/exchange/load.py:209, in load_mesh(file_obj, file_type, resolver, **kwargs)
#     197 (file_obj,  # file- like object
#     198  file_type,  # str, what kind of file
#     199  metadata,  # dict, any metadata from file name
#    (...)
#     203                      file_type=file_type,
#     204                      resolver=resolver)
#     206 try:
#     207     # make sure we keep passed kwargs to loader
#     208     # but also make sure loader keys override passed keys
# --> 209     results = mesh_loaders[file_type](file_obj,
#     210                                       file_type=file_type,
#     211                                       resolver=resolver,
#     212                                       **kwargs)
#     213     if not isinstance(results, list):
#     214         results = [results]
#
# File /run/media/rr/M2/DevOps/jupyter-lab/python39_venv/lib/python3.9/site-packages/trimesh/exchange/off.py:44, in load_off(file_obj, **kwargs)
#      41 header = np.array(splits[0].split(), dtype=np.int64)
#      42 vertex_count, face_count = header[:2]
# ---> 44 vertices = np.array([
#      45     i.split()[:3] for i in
#      46     splits[1: vertex_count + 1]],
#      47     dtype=np.float64)
#      49 # will fail if incorrect number of vertices loaded
#      50 vertices = vertices.reshape((vertex_count, 3))
#
# File /run/media/rr/M2/DevOps/jupyter-lab/python39_venv/lib/python3.9/site-packages/trimesh/exchange/off.py:45, in <listcomp>(.0)
#      41 header = np.array(splits[0].split(), dtype=np.int64)
#      42 vertex_count, face_count = header[:2]
#      44 vertices = np.array([
# ---> 45     i.split()[:3] for i in
#      46     splits[1: vertex_count + 1]],
#      47     dtype=np.float64)
#      49 # will fail if incorrect number of vertices loaded
#      50 vertices = vertices.reshape((vertex_count, 3))
#
# KeyboardInterrupt:
