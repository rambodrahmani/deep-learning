# %% [markdown]
# # **POINTNET WITH K-FOLD**

# %%
# necessary imports
import os
import numpy
import pandas
import random
import trimesh
import logging
import itertools
import tensorflow
from matplotlib import pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import models, layers, regularizers, optimizers
from sklearn.model_selection import train_test_split, StratifiedKFold
from tensorflow.keras.layers import Dense, Activation, Flatten, Dropout, BatchNormalization
from tensorflow.keras.layers import Conv1D, MaxPooling1D, GlobalMaxPooling1D, Conv2D, MaxPooling2D

# increase matplotlib plots font size
plt.rcParams.update({'font.size': 15})

# The below is necessary for reproducible results of certain Python hash-based operations.
os.environ["PYTHONHASHSEED"] = "0"

# The below is necessary for starting Numpy generated random numbers in a well-defined initial state.
numpy.random.seed(31)

# The below is necessary for starting core Python generated random numbers in a well-defined state.
random.seed(14)

# The below tf.random.set_seed will make random number generation in TensorFlow have a well-defined initial state.
tensorflow.random.set_seed(1234)

# dataset root path
DATASET_ROOT = '/run/media/rr/M2/DevOps/jupyter-lab/CIDL/dataset/'

# final preprocessed dataset directory path
DATASET_PATH = os.path.join(DATASET_ROOT, 'Preprocessed')

# directory where to save the best model for each fold
images_models_save_dir = 'saved_models/images'
pointclouds_models_save_dir = 'saved_models/pointclouds'

# needed to create pointclouds dataset
class_labels_dict = {'table':0, 'chair':1, 'lamp':2, 'dresser':3, 'sofa':4}

# utility function
def get_model_name(model_name, fold_counter):
    return model_name + '-fold-' + str(fold_counter) + '.h5'

# utility function to augment pointclouds data
def augment(points, label):
    # jitter points
    points += tensorflow.random.uniform(points.shape, -0.005, 0.005, dtype=tensorflow.float64)
    # shuffle points
    points = tensorflow.random.shuffle(points)
    return points, label

# plot loss and acuracy for each epoch
def plot_train_loss_accuracy(save_path, train_loss, train_accuracy, val_loss, val_accuracy):
    #print('Training Set Loss: ', train_loss)
    #print('Validation Set Loss: ', val_loss)
    plt.figure(figsize=(10, 10))
    plt.plot(train_loss,'o-g', label="Training Set")
    plt.plot(val_loss,'o-r', label="Validation Set")
    plt.title('Training and Validation Sets Loss')
    plt.legend(loc="upper right")
    plt.savefig(save_path + '-train-val-loss.jpg', dpi=200)
    plt.show()
    #print('Training Set Accuracy: ', train_accuracy)
    #print('Validation Set Accuracy: ', val_accuracy)
    plt.figure(figsize=(10, 10))
    plt.plot(train_accuracy,'o-g', label="Training Set")
    plt.plot(val_accuracy,'o-r', label="Validation Set")
    plt.title('Training and Validation Sets Accuracy')
    plt.legend(loc="lower right")
    plt.savefig(save_path + '-train-val-accuracy.jpg', dpi=200)
    plt.show()

def plot_confusion_matrix(cm, classes, save_path, normalize=True, title='Confusion matrix', cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.figure(figsize=(10,10))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()

    tick_marks = numpy.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, numpy.newaxis]
        cm = numpy.around(cm, decimals=2)
        cm[numpy.isnan(cm)] = 0.0
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')
    
    thresh = cm.max() / 2.

    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j], horizontalalignment="center", color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.savefig(save_path + '-confusion-matrix.jpg', bbox_inches='tight', dpi=200)
    plt.show()

# %%
# only log critical messages
logger = logging.getLogger()
logger.setLevel(logging.CRITICAL)

# %%
# load images csv file
images_data = pandas.read_csv(os.path.join(DATASET_PATH, 'images.csv'))

# extract images path and class labels
images_X = images_data[['filename']]
images_Y = images_data[['class_label']]

# load pointclouds csv file
pointclouds_data = pandas.read_csv(os.path.join(DATASET_PATH, 'pointclouds.csv'))

# extract images path and class labels
pointclouds_X = pointclouds_data[['filename']]
pointclouds_Y = pointclouds_data[['class_label']]

# %% [markdown]
# ## **Stratified K-Fold Cross Validation for pointclouds**

# %%
def pointclouds_kfold_validation(model_name, n_splits, test_size, shuffle, layers, learning_rate, decay, target_size, epochs, batch_size, resample_data=0):
    global pointclouds_data
    global pointclouds_X
    global pointclouds_Y
    if resample_data > 0:
        pointclouds_data = pointclouds_data.groupby('class_label', group_keys=False).apply(lambda x: x.sample(min(len(x), resample_data), random_state=42))
        pointclouds_X = pointclouds_data[['filename']]
        pointclouds_Y = pointclouds_data[['class_label']]

    # fold counter
    fold_counter = 1
    
    # arrays to store test set loss and accuracy scores for each fold
    TEST_LOSS = []
    TEST_ACCURACY = []
    
    # split train and test dataset
    pointclouds_train, pointclouds_test = train_test_split(pointclouds_data, test_size=test_size, stratify=pointclouds_Y, random_state=42)
    pointclouds_train_X = pointclouds_train[['filename']]
    pointclouds_train_Y = pointclouds_train[['class_label']]

    # define stratified k fold cross validation parameters
    stratified_kfold = StratifiedKFold(n_splits=n_splits, random_state=7, shuffle=shuffle)

    # test data arrays
    test_pointclouds = []
    test_labels = []
    test_string_labels = {}

    # test split ready
    for index, test_data_row in pointclouds_test.iterrows():
        test_pointclouds.append(trimesh.load(test_data_row['filename'], force='mesh').sample(target_size))
        test_labels.append(class_labels_dict[test_data_row['class_label']])
        test_string_labels[index] = test_data_row['class_label']
    
    # convert to numpy array
    test_pointclouds = numpy.array(test_pointclouds)
    test_labels = numpy.array(test_labels)

    # create test tf.data.Dataset
    test_dataset = tensorflow.data.Dataset.from_tensor_slices((test_pointclouds, test_labels))
    test_dataset = test_dataset.shuffle(len(test_pointclouds)).batch(batch_size)
    print("Found " + str(len(pointclouds_test)) + " validated pointcloud filenames belonging to " + str(len(pointclouds_test['class_label'].unique())) + " classes.")


    # generate train and validation folds
    for train_index, validation_index in stratified_kfold.split(pointclouds_train_X, pointclouds_train_Y):
        print("\n-------- STARTING FOLD: " + str(fold_counter) + " --------")

        # best model save path
        if not os.path.isdir(os.path.join(pointclouds_models_save_dir, model_name)):
            os.mkdir(os.path.join(pointclouds_models_save_dir, model_name))
        pointclouds_model_save_path = os.path.join(pointclouds_models_save_dir, model_name, get_model_name(model_name, fold_counter))

        # train and validation data arrays
        train_pointclouds = []
        train_labels = []
        train_string_labels = {}
        validation_pointclouds = []
        validation_labels = []
        validation_string_labels = {}

        # training and test folds indices
        training_data = pointclouds_train.iloc[train_index]
        validation_data = pointclouds_train.iloc[validation_index]

        for index, training_data_row in training_data.iterrows():
            train_pointclouds.append(trimesh.load(training_data_row['filename'], force='mesh').sample(target_size))
            train_labels.append(class_labels_dict[training_data_row['class_label']])
            train_string_labels[index] = training_data_row['class_label']

        # convert to numpy array
        train_pointclouds = numpy.array(train_pointclouds)
        train_labels = numpy.array(train_labels)

        # create train tf.data.Dataset
        train_dataset = tensorflow.data.Dataset.from_tensor_slices((train_pointclouds, train_labels))
        train_dataset = train_dataset.shuffle(len(train_pointclouds)).map(augment).batch(batch_size)
        print("Found " + str(len(training_data)) + " validated pointcloud filenames belonging to " + str(len(training_data['class_label'].unique())) + " classes.")

        for index, validation_data_row in validation_data.iterrows():
            validation_pointclouds.append(trimesh.load(validation_data_row['filename'], force='mesh').sample(target_size))
            validation_labels.append(class_labels_dict[validation_data_row['class_label']])
            validation_string_labels[index] = validation_data_row['class_label']

        # convert to numpy array
        validation_pointclouds = numpy.array(validation_pointclouds)
        validation_labels = numpy.array(validation_labels)

        # create train tf.data.Dataset
        validation_dataset = tensorflow.data.Dataset.from_tensor_slices((validation_pointclouds, validation_labels))
        validation_dataset = validation_dataset.shuffle(len(validation_pointclouds)).map(augment).batch(batch_size)
        print("Found " + str(len(validation_data)) + " validated pointcloud filenames belonging to " + str(len(validation_data['class_label'].unique())) + " classes.")

        # create best model checkpoint
        best_model_checkpoint = tensorflow.keras.callbacks.ModelCheckpoint(pointclouds_model_save_path, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
        callbacks_list = [best_model_checkpoint]

        # define model to be trained and tested
        model = models.Sequential(name=model_name + "-" + str(fold_counter))
        for layer in layers:
            model.add(layer)
        model.summary()

        model.compile(
            loss="sparse_categorical_crossentropy",
            optimizer=tensorflow.keras.optimizers.Adam(learning_rate=learning_rate, decay=decay),
            metrics=["sparse_categorical_accuracy"],
        )

        # train model
        history = model.fit(train_dataset,
                            epochs=epochs,
                            callbacks=callbacks_list,
                            validation_data=validation_dataset)

        # plot loss and acuracy for each training/validation fold
        plot_train_loss_accuracy(pointclouds_model_save_path, history.history["loss"], history.history["sparse_categorical_accuracy"],
                                 history.history["val_loss"], history.history["val_sparse_categorical_accuracy"])

        # LOAD BEST MODEL to evaluate the performance of the model on the test set
        model.load_weights(pointclouds_model_save_path)

        # evaluate the model on the test set
        test_loss, test_accuracy = model.evaluate(test_dataset, batch_size=batch_size)
        print("Best model Test Loss: " + str(test_loss))
        print("Best model Test Accuracy: " + str(test_accuracy))
        
        # store test set loss and accuracy scores for each fold
        TEST_LOSS.append(test_loss)
        TEST_ACCURACY.append(test_accuracy)

        # Confution Matrix 
        Y_pred = model.predict(test_dataset)
        y_pred = numpy.argmax(Y_pred, axis=1)
        print('Confusion Matrix')
        cm = confusion_matrix(test_labels, y_pred)
        plot_confusion_matrix(cm, class_labels_dict.keys(), pointclouds_model_save_path, title='Confusion Matrix')

        # print Classification Report
        print('Classification Report')
        print(classification_report(test_labels, y_pred, target_names=class_labels_dict.keys()))

        # clean up before next fold
        del model
        tensorflow.keras.backend.clear_session()
        fold_counter += 1

# %% [markdown]
# #### **Developer harness test for Stratified K-Fold Cross Validation for pointclouds**

# %%
# testing
layers = [
    Conv1D(32, 3, padding='same', input_shape=(2048, 3)),
    BatchNormalization(momentum=0.0),
    Activation('relu'),
    Conv1D(64, 3, padding='same', input_shape=(2048, 3)),
    BatchNormalization(momentum=0.0),
    Activation('relu'),
    Conv1D(512, 3, padding='same', input_shape=(2048, 3)),
    BatchNormalization(momentum=0.0),
    Activation('relu'),
    GlobalMaxPooling1D(),
    Dense(512),
    BatchNormalization(momentum=0.0),
    Flatten(),
    Dense(1024),
    Activation('relu'),
    Dense(5, activation='softmax')
]

# train, validate and test
pointclouds_kfold_validation("testing", 3, 0.20, True, layers, 0.001, 1e-6, 2048, 50, 32)
# Out:
# 2022-02-06 21:11:59.747926: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-06 21:11:59.766110: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-06 21:11:59.766256: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-06 21:11:59.766860: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-02-06 21:11:59.767754: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-06 21:11:59.767896: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-06 21:11:59.768018: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-06 21:12:00.014586: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-06 21:12:00.014736: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-06 21:12:00.014850: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-06 21:12:00.014954: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 21923 MB memory:  -> device: 0, name: NVIDIA RTX A5000, pci bus id: 0000:0b:00.0, compute capability: 8.6
# Found 787 validated pointcloud filenames belonging to 5 classes.
#
# -------- STARTING FOLD: 1 --------
# Found 2096 validated pointcloud filenames belonging to 5 classes.
# Found 1048 validated pointcloud filenames belonging to 5 classes.
# Model: "testing-1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 2048, 32)          320
#
#  batch_normalization (BatchN  (None, 2048, 32)         128
#  ormalization)
#
#  activation (Activation)     (None, 2048, 32)          0
#
#  conv1d_1 (Conv1D)           (None, 2048, 64)          6208
#
#  batch_normalization_1 (Batc  (None, 2048, 64)         256
#  hNormalization)
#
#  activation_1 (Activation)   (None, 2048, 64)          0
#
#  conv1d_2 (Conv1D)           (None, 2048, 512)         98816
#
#  batch_normalization_2 (Batc  (None, 2048, 512)        2048
#  hNormalization)
#
#  activation_2 (Activation)   (None, 2048, 512)         0
#
#  global_max_pooling1d (Globa  (None, 512)              0
#  lMaxPooling1D)
#
#  dense (Dense)               (None, 512)               262656
#
#  batch_normalization_3 (Batc  (None, 512)              2048
#  hNormalization)
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 1024)              525312
#
#  activation_3 (Activation)   (None, 1024)              0
#
#  dense_2 (Dense)             (None, 5)                 5125
#
# =================================================================
# Total params: 902,917
# Trainable params: 900,677
# Non-trainable params: 2,240
# _________________________________________________________________
# Epoch 1/50
# 2022-02-06 21:14:13.732912: I tensorflow/stream_executor/cuda/cuda_dnn.cc:366] Loaded cuDNN version 8300
#  1/66 [..............................] - ETA: 1:59 - loss: 1.7248 - sparse_categorical_accuracy: 0.2812
# 2022-02-06 21:14:14.414562: I tensorflow/stream_executor/cuda/cuda_blas.cc:1774] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 66/66 [==============================] - ETA: 0s - loss: 2.0425 - sparse_categorical_accuracy: 0.2858
# Epoch 00001: val_loss improved from inf to 4.32524, saving model to saved_models/pointclouds/testing/testing-fold-1.h5
# 66/66 [==============================] - 4s 27ms/step - loss: 2.0425 - sparse_categorical_accuracy: 0.2858 - val_loss: 4.3252 - val_sparse_categorical_accuracy: 0.1889
# Epoch 2/50
# 64/66 [============================>.] - ETA: 0s - loss: 1.7683 - sparse_categorical_accuracy: 0.3535
# Epoch 00002: val_loss improved from 4.32524 to 1.84529, saving model to saved_models/pointclouds/testing/testing-fold-1.h5
# 66/66 [==============================] - 2s 25ms/step - loss: 1.7641 - sparse_categorical_accuracy: 0.3531 - val_loss: 1.8453 - val_sparse_categorical_accuracy: 0.2195
# Epoch 3/50
# 64/66 [============================>.] - ETA: 0s - loss: 1.5711 - sparse_categorical_accuracy: 0.3843
# Epoch 00003: val_loss did not improve from 1.84529
# 66/66 [==============================] - 2s 24ms/step - loss: 1.5728 - sparse_categorical_accuracy: 0.3831 - val_loss: 2.4694 - val_sparse_categorical_accuracy: 0.2490
# Epoch 4/50
# 64/66 [============================>.] - ETA: 0s - loss: 1.5442 - sparse_categorical_accuracy: 0.3989
# Epoch 00004: val_loss did not improve from 1.84529
# 66/66 [==============================] - 2s 24ms/step - loss: 1.5468 - sparse_categorical_accuracy: 0.3955 - val_loss: 2.1113 - val_sparse_categorical_accuracy: 0.2395
# Epoch 5/50
# 64/66 [============================>.] - ETA: 0s - loss: 1.5283 - sparse_categorical_accuracy: 0.4365
# Epoch 00005: val_loss did not improve from 1.84529
# 66/66 [==============================] - 2s 24ms/step - loss: 1.5233 - sparse_categorical_accuracy: 0.4385 - val_loss: 10.8180 - val_sparse_categorical_accuracy: 0.5496
# Epoch 6/50
# 64/66 [============================>.] - ETA: 0s - loss: 1.2954 - sparse_categorical_accuracy: 0.4614
# Epoch 00006: val_loss did not improve from 1.84529
# 66/66 [==============================] - 2s 24ms/step - loss: 1.3000 - sparse_categorical_accuracy: 0.4585 - val_loss: 2.3524 - val_sparse_categorical_accuracy: 0.3521
# Epoch 7/50
# 64/66 [============================>.] - ETA: 0s - loss: 1.3304 - sparse_categorical_accuracy: 0.4482
# Epoch 00007: val_loss improved from 1.84529 to 1.55116, saving model to saved_models/pointclouds/testing/testing-fold-1.h5
# 66/66 [==============================] - 2s 25ms/step - loss: 1.3349 - sparse_categorical_accuracy: 0.4447 - val_loss: 1.5512 - val_sparse_categorical_accuracy: 0.3225
# Epoch 8/50
# 64/66 [============================>.] - ETA: 0s - loss: 1.2978 - sparse_categorical_accuracy: 0.4858
# Epoch 00008: val_loss did not improve from 1.55116
# 66/66 [==============================] - 2s 24ms/step - loss: 1.2885 - sparse_categorical_accuracy: 0.4900 - val_loss: 22.4471 - val_sparse_categorical_accuracy: 0.5868
# Epoch 9/50
# 64/66 [============================>.] - ETA: 0s - loss: 1.2576 - sparse_categorical_accuracy: 0.5161
# Epoch 00009: val_loss did not improve from 1.55116
# 66/66 [==============================] - 2s 24ms/step - loss: 1.2531 - sparse_categorical_accuracy: 0.5186 - val_loss: 1.9280 - val_sparse_categorical_accuracy: 0.4914
# Epoch 10/50
# 64/66 [============================>.] - ETA: 0s - loss: 1.1938 - sparse_categorical_accuracy: 0.5195
# Epoch 00010: val_loss did not improve from 1.55116
# 66/66 [==============================] - 2s 24ms/step - loss: 1.2025 - sparse_categorical_accuracy: 0.5138 - val_loss: 3.6598 - val_sparse_categorical_accuracy: 0.6097
# Epoch 11/50
# 64/66 [============================>.] - ETA: 0s - loss: 1.1581 - sparse_categorical_accuracy: 0.5352
# Epoch 00011: val_loss improved from 1.55116 to 1.36210, saving model to saved_models/pointclouds/testing/testing-fold-1.h5
# 66/66 [==============================] - 2s 25ms/step - loss: 1.1560 - sparse_categorical_accuracy: 0.5348 - val_loss: 1.3621 - val_sparse_categorical_accuracy: 0.4179
# Epoch 12/50
# 66/66 [==============================] - ETA: 0s - loss: 1.1359 - sparse_categorical_accuracy: 0.5286
# Epoch 00012: val_loss did not improve from 1.36210
# 66/66 [==============================] - 2s 24ms/step - loss: 1.1359 - sparse_categorical_accuracy: 0.5286 - val_loss: 14.1172 - val_sparse_categorical_accuracy: 0.6737
# Epoch 13/50
# 64/66 [============================>.] - ETA: 0s - loss: 1.0856 - sparse_categorical_accuracy: 0.5723
# Epoch 00013: val_loss did not improve from 1.36210
# 66/66 [==============================] - 2s 24ms/step - loss: 1.0898 - sparse_categorical_accuracy: 0.5701 - val_loss: 7.3411 - val_sparse_categorical_accuracy: 0.6450
# Epoch 14/50
# 64/66 [============================>.] - ETA: 0s - loss: 1.1347 - sparse_categorical_accuracy: 0.5757
# Epoch 00014: val_loss did not improve from 1.36210
# 66/66 [==============================] - 2s 24ms/step - loss: 1.1384 - sparse_categorical_accuracy: 0.5725 - val_loss: 18.7922 - val_sparse_categorical_accuracy: 0.7013
# Epoch 15/50
# 64/66 [============================>.] - ETA: 0s - loss: 1.0709 - sparse_categorical_accuracy: 0.5625
# Epoch 00015: val_loss did not improve from 1.36210
# 66/66 [==============================] - 2s 24ms/step - loss: 1.0697 - sparse_categorical_accuracy: 0.5644 - val_loss: 1.9601 - val_sparse_categorical_accuracy: 0.7223
# Epoch 16/50
# 64/66 [============================>.] - ETA: 0s - loss: 1.0490 - sparse_categorical_accuracy: 0.5928
# Epoch 00016: val_loss did not improve from 1.36210
# 66/66 [==============================] - 2s 24ms/step - loss: 1.0479 - sparse_categorical_accuracy: 0.5949 - val_loss: 25.7307 - val_sparse_categorical_accuracy: 0.6088
# Epoch 17/50
# 64/66 [============================>.] - ETA: 0s - loss: 0.9923 - sparse_categorical_accuracy: 0.6074
# Epoch 00017: val_loss did not improve from 1.36210
# 66/66 [==============================] - 2s 24ms/step - loss: 0.9818 - sparse_categorical_accuracy: 0.6116 - val_loss: 53.1932 - val_sparse_categorical_accuracy: 0.7013
# Epoch 18/50
# 64/66 [============================>.] - ETA: 0s - loss: 0.9918 - sparse_categorical_accuracy: 0.6304
# Epoch 00018: val_loss did not improve from 1.36210
# 66/66 [==============================] - 2s 24ms/step - loss: 0.9894 - sparse_categorical_accuracy: 0.6298 - val_loss: 1.8206 - val_sparse_categorical_accuracy: 0.3273
# Epoch 19/50
# 64/66 [============================>.] - ETA: 0s - loss: 0.9831 - sparse_categorical_accuracy: 0.6089
# Epoch 00019: val_loss did not improve from 1.36210
# 66/66 [==============================] - 2s 24ms/step - loss: 0.9776 - sparse_categorical_accuracy: 0.6107 - val_loss: 17.0371 - val_sparse_categorical_accuracy: 0.6813
# Epoch 20/50
# 64/66 [============================>.] - ETA: 0s - loss: 0.9792 - sparse_categorical_accuracy: 0.6216
# Epoch 00020: val_loss did not improve from 1.36210
# 66/66 [==============================] - 2s 24ms/step - loss: 0.9894 - sparse_categorical_accuracy: 0.6193 - val_loss: 12.4935 - val_sparse_categorical_accuracy: 0.6412
# Epoch 21/50
# 64/66 [============================>.] - ETA: 0s - loss: 0.9685 - sparse_categorical_accuracy: 0.6216
# Epoch 00021: val_loss did not improve from 1.36210
# 66/66 [==============================] - 2s 24ms/step - loss: 0.9684 - sparse_categorical_accuracy: 0.6231 - val_loss: 3.1343 - val_sparse_categorical_accuracy: 0.6651
# Epoch 22/50
# 64/66 [============================>.] - ETA: 0s - loss: 0.9538 - sparse_categorical_accuracy: 0.6450
# Epoch 00022: val_loss did not improve from 1.36210
# 66/66 [==============================] - 2s 24ms/step - loss: 0.9529 - sparse_categorical_accuracy: 0.6450 - val_loss: 1.5679 - val_sparse_categorical_accuracy: 0.3578
# Epoch 23/50
# 64/66 [============================>.] - ETA: 0s - loss: 0.9105 - sparse_categorical_accuracy: 0.6636
# Epoch 00023: val_loss did not improve from 1.36210
# 66/66 [==============================] - 2s 24ms/step - loss: 0.9160 - sparse_categorical_accuracy: 0.6646 - val_loss: 4.8442 - val_sparse_categorical_accuracy: 0.7347
# Epoch 24/50
# 64/66 [============================>.] - ETA: 0s - loss: 0.9237 - sparse_categorical_accuracy: 0.6558
# Epoch 00024: val_loss did not improve from 1.36210
# 66/66 [==============================] - 2s 24ms/step - loss: 0.9204 - sparse_categorical_accuracy: 0.6594 - val_loss: 1.4944 - val_sparse_categorical_accuracy: 0.7166
# Epoch 25/50
# 64/66 [============================>.] - ETA: 0s - loss: 0.8907 - sparse_categorical_accuracy: 0.6685
# Epoch 00025: val_loss did not improve from 1.36210
# 66/66 [==============================] - 2s 24ms/step - loss: 0.8938 - sparse_categorical_accuracy: 0.6679 - val_loss: 1.4250 - val_sparse_categorical_accuracy: 0.5134
# Epoch 26/50
# 64/66 [============================>.] - ETA: 0s - loss: 0.9276 - sparse_categorical_accuracy: 0.6465
# Epoch 00026: val_loss improved from 1.36210 to 1.31920, saving model to saved_models/pointclouds/testing/testing-fold-1.h5
# 66/66 [==============================] - 2s 25ms/step - loss: 0.9248 - sparse_categorical_accuracy: 0.6479 - val_loss: 1.3192 - val_sparse_categorical_accuracy: 0.7576
# Epoch 27/50
# 64/66 [============================>.] - ETA: 0s - loss: 0.8790 - sparse_categorical_accuracy: 0.6733
# Epoch 00027: val_loss did not improve from 1.31920
# 66/66 [==============================] - 2s 24ms/step - loss: 0.8737 - sparse_categorical_accuracy: 0.6751 - val_loss: 9.2698 - val_sparse_categorical_accuracy: 0.7462
# Epoch 28/50
# 64/66 [============================>.] - ETA: 0s - loss: 0.8657 - sparse_categorical_accuracy: 0.6660
# Epoch 00028: val_loss did not improve from 1.31920
# 66/66 [==============================] - 2s 24ms/step - loss: 0.8788 - sparse_categorical_accuracy: 0.6632 - val_loss: 43.7397 - val_sparse_categorical_accuracy: 0.6670
# Epoch 29/50
# 64/66 [============================>.] - ETA: 0s - loss: 0.8702 - sparse_categorical_accuracy: 0.6831
# Epoch 00029: val_loss did not improve from 1.31920
# 66/66 [==============================] - 2s 24ms/step - loss: 0.8753 - sparse_categorical_accuracy: 0.6803 - val_loss: 111.1605 - val_sparse_categorical_accuracy: 0.5658
# Epoch 30/50
# 64/66 [============================>.] - ETA: 0s - loss: 0.8792 - sparse_categorical_accuracy: 0.6646
# Epoch 00030: val_loss did not improve from 1.31920
# 66/66 [==============================] - 2s 25ms/step - loss: 0.8760 - sparse_categorical_accuracy: 0.6665 - val_loss: 12.2984 - val_sparse_categorical_accuracy: 0.7567
# Epoch 31/50
# 64/66 [============================>.] - ETA: 0s - loss: 0.8961 - sparse_categorical_accuracy: 0.6646
# Epoch 00031: val_loss did not improve from 1.31920
# 66/66 [==============================] - 2s 24ms/step - loss: 0.8941 - sparse_categorical_accuracy: 0.6636 - val_loss: 8.0386 - val_sparse_categorical_accuracy: 0.7595
# Epoch 32/50
# 64/66 [============================>.] - ETA: 0s - loss: 0.8658 - sparse_categorical_accuracy: 0.6841
# Epoch 00032: val_loss did not improve from 1.31920
# 66/66 [==============================] - 2s 24ms/step - loss: 0.8646 - sparse_categorical_accuracy: 0.6837 - val_loss: 3.8019 - val_sparse_categorical_accuracy: 0.7824
# Epoch 33/50
# 64/66 [============================>.] - ETA: 0s - loss: 0.8738 - sparse_categorical_accuracy: 0.6831
# Epoch 00033: val_loss improved from 1.31920 to 1.01871, saving model to saved_models/pointclouds/testing/testing-fold-1.h5
# 66/66 [==============================] - 2s 26ms/step - loss: 0.8719 - sparse_categorical_accuracy: 0.6846 - val_loss: 1.0187 - val_sparse_categorical_accuracy: 0.7882
# Epoch 34/50
# 64/66 [============================>.] - ETA: 0s - loss: 0.7926 - sparse_categorical_accuracy: 0.7090
# Epoch 00034: val_loss did not improve from 1.01871
# 66/66 [==============================] - 2s 25ms/step - loss: 0.7943 - sparse_categorical_accuracy: 0.7099 - val_loss: 3.4681 - val_sparse_categorical_accuracy: 0.7595
# Epoch 35/50
# 64/66 [============================>.] - ETA: 0s - loss: 0.8322 - sparse_categorical_accuracy: 0.6870
# Epoch 00035: val_loss did not improve from 1.01871
# 66/66 [==============================] - 2s 24ms/step - loss: 0.8254 - sparse_categorical_accuracy: 0.6908 - val_loss: 6.9904 - val_sparse_categorical_accuracy: 0.7653
# Epoch 36/50
# 64/66 [============================>.] - ETA: 0s - loss: 0.8619 - sparse_categorical_accuracy: 0.6714
# Epoch 00036: val_loss did not improve from 1.01871
# 66/66 [==============================] - 2s 24ms/step - loss: 0.8594 - sparse_categorical_accuracy: 0.6746 - val_loss: 8.1013 - val_sparse_categorical_accuracy: 0.7681
# Epoch 37/50
# 64/66 [============================>.] - ETA: 0s - loss: 0.8268 - sparse_categorical_accuracy: 0.6978
# Epoch 00037: val_loss did not improve from 1.01871
# 66/66 [==============================] - 2s 25ms/step - loss: 0.8286 - sparse_categorical_accuracy: 0.6990 - val_loss: 2.8300 - val_sparse_categorical_accuracy: 0.7261
# Epoch 38/50
# 64/66 [============================>.] - ETA: 0s - loss: 0.8341 - sparse_categorical_accuracy: 0.6914
# Epoch 00038: val_loss improved from 1.01871 to 0.99922, saving model to saved_models/pointclouds/testing/testing-fold-1.h5
# 66/66 [==============================] - 2s 25ms/step - loss: 0.8349 - sparse_categorical_accuracy: 0.6908 - val_loss: 0.9992 - val_sparse_categorical_accuracy: 0.7347
# Epoch 39/50
# 64/66 [============================>.] - ETA: 0s - loss: 0.8061 - sparse_categorical_accuracy: 0.6997
# Epoch 00039: val_loss did not improve from 0.99922
# 66/66 [==============================] - 2s 24ms/step - loss: 0.8076 - sparse_categorical_accuracy: 0.7013 - val_loss: 64.0884 - val_sparse_categorical_accuracy: 0.6708
# Epoch 40/50
# 64/66 [============================>.] - ETA: 0s - loss: 0.7855 - sparse_categorical_accuracy: 0.7134
# Epoch 00040: val_loss did not improve from 0.99922
# 66/66 [==============================] - 2s 24ms/step - loss: 0.7919 - sparse_categorical_accuracy: 0.7109 - val_loss: 1.2489 - val_sparse_categorical_accuracy: 0.5582
# Epoch 41/50
# 64/66 [============================>.] - ETA: 0s - loss: 0.7956 - sparse_categorical_accuracy: 0.7056
# Epoch 00041: val_loss did not improve from 0.99922
# 66/66 [==============================] - 2s 24ms/step - loss: 0.7946 - sparse_categorical_accuracy: 0.7061 - val_loss: 65.8502 - val_sparse_categorical_accuracy: 0.6975
# Epoch 42/50
# 64/66 [============================>.] - ETA: 0s - loss: 0.8207 - sparse_categorical_accuracy: 0.6841
# Epoch 00042: val_loss improved from 0.99922 to 0.74584, saving model to saved_models/pointclouds/testing/testing-fold-1.h5
# 66/66 [==============================] - 2s 25ms/step - loss: 0.8176 - sparse_categorical_accuracy: 0.6861 - val_loss: 0.7458 - val_sparse_categorical_accuracy: 0.7872
# Epoch 43/50
# 64/66 [============================>.] - ETA: 0s - loss: 0.8290 - sparse_categorical_accuracy: 0.7090
# Epoch 00043: val_loss did not improve from 0.74584
# 66/66 [==============================] - 2s 25ms/step - loss: 0.8329 - sparse_categorical_accuracy: 0.7085 - val_loss: 0.8142 - val_sparse_categorical_accuracy: 0.7042
# Epoch 44/50
# 64/66 [============================>.] - ETA: 0s - loss: 0.7809 - sparse_categorical_accuracy: 0.7075
# Epoch 00044: val_loss did not improve from 0.74584
# 66/66 [==============================] - 2s 24ms/step - loss: 0.7855 - sparse_categorical_accuracy: 0.7066 - val_loss: 32.0113 - val_sparse_categorical_accuracy: 0.7471
# Epoch 45/50
# 64/66 [============================>.] - ETA: 0s - loss: 0.7533 - sparse_categorical_accuracy: 0.7119
# Epoch 00045: val_loss did not improve from 0.74584
# 66/66 [==============================] - 2s 24ms/step - loss: 0.7499 - sparse_categorical_accuracy: 0.7133 - val_loss: 1.1611 - val_sparse_categorical_accuracy: 0.7137
# Epoch 46/50
# 64/66 [============================>.] - ETA: 0s - loss: 0.7968 - sparse_categorical_accuracy: 0.7124
# Epoch 00046: val_loss did not improve from 0.74584
# 66/66 [==============================] - 2s 24ms/step - loss: 0.7961 - sparse_categorical_accuracy: 0.7123 - val_loss: 8.6231 - val_sparse_categorical_accuracy: 0.7605
# Epoch 47/50
# 64/66 [============================>.] - ETA: 0s - loss: 0.7625 - sparse_categorical_accuracy: 0.7095
# Epoch 00047: val_loss did not improve from 0.74584
# 66/66 [==============================] - 2s 24ms/step - loss: 0.7576 - sparse_categorical_accuracy: 0.7128 - val_loss: 2.6031 - val_sparse_categorical_accuracy: 0.7834
# Epoch 48/50
# 64/66 [============================>.] - ETA: 0s - loss: 0.7422 - sparse_categorical_accuracy: 0.7241
# Epoch 00048: val_loss did not improve from 0.74584
# 66/66 [==============================] - 2s 24ms/step - loss: 0.7489 - sparse_categorical_accuracy: 0.7228 - val_loss: 1.0623 - val_sparse_categorical_accuracy: 0.6288
# Epoch 49/50
# 64/66 [============================>.] - ETA: 0s - loss: 0.7395 - sparse_categorical_accuracy: 0.7090
# Epoch 00049: val_loss did not improve from 0.74584
# 66/66 [==============================] - 2s 24ms/step - loss: 0.7354 - sparse_categorical_accuracy: 0.7104 - val_loss: 1.6798 - val_sparse_categorical_accuracy: 0.5983
# Epoch 50/50
# 64/66 [============================>.] - ETA: 0s - loss: 0.7304 - sparse_categorical_accuracy: 0.7236
# Epoch 00050: val_loss did not improve from 0.74584
# 66/66 [==============================] - 2s 24ms/step - loss: 0.7308 - sparse_categorical_accuracy: 0.7233 - val_loss: 33.6830 - val_sparse_categorical_accuracy: 0.7376
# 25/25 [==============================] - 0s 6ms/step - loss: 0.8572 - sparse_categorical_accuracy: 0.7637
# Best model Test Loss: 0.8571895956993103
# Best model Test Accuracy: 0.7636594772338867
# Confusion Matrix
# Normalized confusion matrix
# Classification Report
#               precision    recall  f1-score   support
#
#        table       0.26      0.20      0.22       158
#        chair       0.18      0.11      0.14       157
#         lamp       0.20      0.27      0.23       158
#      dresser       0.19      0.21      0.20       157
#         sofa       0.21      0.24      0.22       157
#
#     accuracy                           0.21       787
#    macro avg       0.21      0.21      0.20       787
# weighted avg       0.21      0.21      0.20       787
#
#
# -------- STARTING FOLD: 2 --------
# Found 2096 validated pointcloud filenames belonging to 5 classes.
# Found 1048 validated pointcloud filenames belonging to 5 classes.
# Model: "testing-2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 2048, 32)          320
#
#  batch_normalization (BatchN  (None, 2048, 32)         128
#  ormalization)
#
#  activation (Activation)     (None, 2048, 32)          0
#
#  conv1d_1 (Conv1D)           (None, 2048, 64)          6208
#
#  batch_normalization_1 (Batc  (None, 2048, 64)         256
#  hNormalization)
#
#  activation_1 (Activation)   (None, 2048, 64)          0
#
#  conv1d_2 (Conv1D)           (None, 2048, 512)         98816
#
#  batch_normalization_2 (Batc  (None, 2048, 512)        2048
#  hNormalization)
#
#  activation_2 (Activation)   (None, 2048, 512)         0
#
#  global_max_pooling1d (Globa  (None, 512)              0
#  lMaxPooling1D)
#
#  dense (Dense)               (None, 512)               262656
#
#  batch_normalization_3 (Batc  (None, 512)              2048
#  hNormalization)
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 1024)              525312
#
#  activation_3 (Activation)   (None, 1024)              0
#
#  dense_2 (Dense)             (None, 5)                 5125
#
# =================================================================
# Total params: 902,917
# Trainable params: 900,677
# Non-trainable params: 2,240
# _________________________________________________________________
# Epoch 1/50
# 64/66 [============================>.] - ETA: 0s - loss: 0.8607 - sparse_categorical_accuracy: 0.6924
# Epoch 00001: val_loss improved from inf to 35.10989, saving model to saved_models/pointclouds/testing/testing-fold-2.h5
# 66/66 [==============================] - 2s 27ms/step - loss: 0.8541 - sparse_categorical_accuracy: 0.6942 - val_loss: 35.1099 - val_sparse_categorical_accuracy: 0.6622
# Epoch 2/50
# 64/66 [============================>.] - ETA: 0s - loss: 0.8128 - sparse_categorical_accuracy: 0.7046
# Epoch 00002: val_loss improved from 35.10989 to 1.48281, saving model to saved_models/pointclouds/testing/testing-fold-2.h5
# 66/66 [==============================] - 2s 25ms/step - loss: 0.8114 - sparse_categorical_accuracy: 0.7075 - val_loss: 1.4828 - val_sparse_categorical_accuracy: 0.7615
# Epoch 3/50
# 64/66 [============================>.] - ETA: 0s - loss: 0.7458 - sparse_categorical_accuracy: 0.7222
# Epoch 00003: val_loss did not improve from 1.48281
# 66/66 [==============================] - 2s 25ms/step - loss: 0.7486 - sparse_categorical_accuracy: 0.7223 - val_loss: 21.5877 - val_sparse_categorical_accuracy: 0.7242
# Epoch 4/50
# 64/66 [============================>.] - ETA: 0s - loss: 0.7688 - sparse_categorical_accuracy: 0.7251
# Epoch 00004: val_loss did not improve from 1.48281
# 66/66 [==============================] - 2s 25ms/step - loss: 0.7659 - sparse_categorical_accuracy: 0.7271 - val_loss: 176.9685 - val_sparse_categorical_accuracy: 0.7223
# Epoch 5/50
# 64/66 [============================>.] - ETA: 0s - loss: 0.7468 - sparse_categorical_accuracy: 0.7192
# Epoch 00005: val_loss did not improve from 1.48281
# 66/66 [==============================] - 2s 24ms/step - loss: 0.7549 - sparse_categorical_accuracy: 0.7209 - val_loss: 1.6579 - val_sparse_categorical_accuracy: 0.7576
# Epoch 6/50
# 64/66 [============================>.] - ETA: 0s - loss: 0.7777 - sparse_categorical_accuracy: 0.7012
# Epoch 00006: val_loss improved from 1.48281 to 0.89064, saving model to saved_models/pointclouds/testing/testing-fold-2.h5
# 66/66 [==============================] - 2s 24ms/step - loss: 0.7759 - sparse_categorical_accuracy: 0.7013 - val_loss: 0.8906 - val_sparse_categorical_accuracy: 0.7052
# Epoch 7/50
# 64/66 [============================>.] - ETA: 0s - loss: 0.7628 - sparse_categorical_accuracy: 0.7241
# Epoch 00007: val_loss did not improve from 0.89064
# 66/66 [==============================] - 2s 24ms/step - loss: 0.7652 - sparse_categorical_accuracy: 0.7247 - val_loss: 55.4984 - val_sparse_categorical_accuracy: 0.7605
# Epoch 8/50
# 64/66 [============================>.] - ETA: 0s - loss: 0.7682 - sparse_categorical_accuracy: 0.7324
# Epoch 00008: val_loss improved from 0.89064 to 0.88422, saving model to saved_models/pointclouds/testing/testing-fold-2.h5
# 66/66 [==============================] - 2s 26ms/step - loss: 0.7629 - sparse_categorical_accuracy: 0.7347 - val_loss: 0.8842 - val_sparse_categorical_accuracy: 0.7376
# Epoch 9/50
# 64/66 [============================>.] - ETA: 0s - loss: 0.7166 - sparse_categorical_accuracy: 0.7339
# Epoch 00009: val_loss did not improve from 0.88422
# 66/66 [==============================] - 2s 24ms/step - loss: 0.7102 - sparse_categorical_accuracy: 0.7357 - val_loss: 14.8954 - val_sparse_categorical_accuracy: 0.7252
# Epoch 10/50
# 64/66 [============================>.] - ETA: 0s - loss: 0.7337 - sparse_categorical_accuracy: 0.7324
# Epoch 00010: val_loss did not improve from 0.88422
# 66/66 [==============================] - 2s 24ms/step - loss: 0.7363 - sparse_categorical_accuracy: 0.7309 - val_loss: 4.6796 - val_sparse_categorical_accuracy: 0.7901
# Epoch 11/50
# 64/66 [============================>.] - ETA: 0s - loss: 0.7142 - sparse_categorical_accuracy: 0.7417- ETA: 0s - loss: 0.7323 - sparse_categorical_accuracy: 0
# Epoch 00011: val_loss did not improve from 0.88422
# 66/66 [==============================] - 2s 24ms/step - loss: 0.7161 - sparse_categorical_accuracy: 0.7405 - val_loss: 3.4495 - val_sparse_categorical_accuracy: 0.7758
# Epoch 12/50
# 64/66 [============================>.] - ETA: 0s - loss: 0.7001 - sparse_categorical_accuracy: 0.7451
# Epoch 00012: val_loss did not improve from 0.88422
# 66/66 [==============================] - 2s 24ms/step - loss: 0.7031 - sparse_categorical_accuracy: 0.7443 - val_loss: 2.3577 - val_sparse_categorical_accuracy: 0.7510
# Epoch 13/50
# 64/66 [============================>.] - ETA: 0s - loss: 0.7095 - sparse_categorical_accuracy: 0.7427
# Epoch 00013: val_loss did not improve from 0.88422
# 66/66 [==============================] - 2s 24ms/step - loss: 0.7106 - sparse_categorical_accuracy: 0.7428 - val_loss: 2.7346 - val_sparse_categorical_accuracy: 0.7137
# Epoch 14/50
# 64/66 [============================>.] - ETA: 0s - loss: 0.7171 - sparse_categorical_accuracy: 0.7295
# Epoch 00014: val_loss did not improve from 0.88422
# 66/66 [==============================] - 2s 24ms/step - loss: 0.7095 - sparse_categorical_accuracy: 0.7323 - val_loss: 6.0213 - val_sparse_categorical_accuracy: 0.7548
# Epoch 15/50
# 64/66 [============================>.] - ETA: 0s - loss: 0.7099 - sparse_categorical_accuracy: 0.7271
# Epoch 00015: val_loss did not improve from 0.88422
# 66/66 [==============================] - 2s 24ms/step - loss: 0.7072 - sparse_categorical_accuracy: 0.7290 - val_loss: 4.2754 - val_sparse_categorical_accuracy: 0.7557
# Epoch 16/50
# 64/66 [============================>.] - ETA: 0s - loss: 0.7227 - sparse_categorical_accuracy: 0.7261
# Epoch 00016: val_loss did not improve from 0.88422
# 66/66 [==============================] - 2s 24ms/step - loss: 0.7102 - sparse_categorical_accuracy: 0.7309 - val_loss: 83.5529 - val_sparse_categorical_accuracy: 0.6889
# Epoch 17/50
# 64/66 [============================>.] - ETA: 0s - loss: 0.6783 - sparse_categorical_accuracy: 0.7573
# Epoch 00017: val_loss improved from 0.88422 to 0.88332, saving model to saved_models/pointclouds/testing/testing-fold-2.h5
# 66/66 [==============================] - 2s 25ms/step - loss: 0.6778 - sparse_categorical_accuracy: 0.7567 - val_loss: 0.8833 - val_sparse_categorical_accuracy: 0.7481
# Epoch 18/50
# 64/66 [============================>.] - ETA: 0s - loss: 0.6765 - sparse_categorical_accuracy: 0.7505
# Epoch 00018: val_loss did not improve from 0.88332
# 66/66 [==============================] - 2s 24ms/step - loss: 0.6766 - sparse_categorical_accuracy: 0.7510 - val_loss: 40.1499 - val_sparse_categorical_accuracy: 0.7147
# Epoch 19/50
# 64/66 [============================>.] - ETA: 0s - loss: 0.6504 - sparse_categorical_accuracy: 0.7568
# Epoch 00019: val_loss did not improve from 0.88332
# 66/66 [==============================] - 2s 24ms/step - loss: 0.6517 - sparse_categorical_accuracy: 0.7567 - val_loss: 1.1537 - val_sparse_categorical_accuracy: 0.6527
# Epoch 20/50
# 28/66 [===========>..................] - ETA: 0s - loss: 0.6733 - sparse_categorical_accuracy: 0.7444
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [5], in <module>
#       2 layers = [
#       3     Conv1D(32, 3, padding='same', input_shape=(2048, 3)),
#       4     BatchNormalization(momentum=0.0),
#    (...)
#      18     Dense(5, activation='softmax')
#      19 ]
#      21 # train, validate and test
# ---> 22 pointclouds_kfold_validation("testing", 3, 0.20, True, layers, 0.001, 1e-6, 2048, 50, 32)
#
# Input In [4], in pointclouds_kfold_validation(model_name, n_splits, test_size, shuffle, layers, learning_rate, decay, target_size, epochs, batch_size, resample_data)
#     105 model.compile(
#     106     loss="sparse_categorical_crossentropy",
#     107     optimizer=tensorflow.keras.optimizers.Adam(learning_rate=learning_rate, decay=decay),
#     108     metrics=["sparse_categorical_accuracy"],
#     109 )
#     111 # train model
# --> 112 history = model.fit(train_dataset,
#     113                     epochs=epochs,
#     114                     callbacks=callbacks_list,
#     115                     validation_data=validation_dataset)
#     117 # plot loss and acuracy for each training/validation fold
#     118 plot_train_loss_accuracy(pointclouds_model_save_path, history.history["loss"], history.history["sparse_categorical_accuracy"],
#     119                          history.history["val_loss"], history.history["val_sparse_categorical_accuracy"])
#
# File /run/media/rr/M2/DevOps/jupyter-lab/python39_venv/lib/python3.9/site-packages/keras/utils/traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /run/media/rr/M2/DevOps/jupyter-lab/python39_venv/lib/python3.9/site-packages/keras/engine/training.py:1221, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1219 logs = tmp_logs  # No error, now safe to assign to logs.
#    1220 end_step = step + data_handler.step_increment
# -> 1221 callbacks.on_train_batch_end(end_step, logs)
#    1222 if self.stop_training:
#    1223   break
#
# File /run/media/rr/M2/DevOps/jupyter-lab/python39_venv/lib/python3.9/site-packages/keras/callbacks.py:436, in CallbackList.on_train_batch_end(self, batch, logs)
#     429 """Calls the `on_train_batch_end` methods of its callbacks.
#     430
#     431 Args:
#     432     batch: Integer, index of batch within the current epoch.
#     433     logs: Dict. Aggregated metric results up until this batch.
#     434 """
#     435 if self._should_call_train_batch_hooks:
# --> 436   self._call_batch_hook(ModeKeys.TRAIN, 'end', batch, logs=logs)
#
# File /run/media/rr/M2/DevOps/jupyter-lab/python39_venv/lib/python3.9/site-packages/keras/callbacks.py:295, in CallbackList._call_batch_hook(self, mode, hook, batch, logs)
#     293   self._call_batch_begin_hook(mode, batch, logs)
#     294 elif hook == 'end':
# --> 295   self._call_batch_end_hook(mode, batch, logs)
#     296 else:
#     297   raise ValueError(
#     298       f'Unrecognized hook: {hook}. Expected values are ["begin", "end"]')
#
# File /run/media/rr/M2/DevOps/jupyter-lab/python39_venv/lib/python3.9/site-packages/keras/callbacks.py:316, in CallbackList._call_batch_end_hook(self, mode, batch, logs)
#     313   batch_time = time.time() - self._batch_start_time
#     314   self._batch_times.append(batch_time)
# --> 316 self._call_batch_hook_helper(hook_name, batch, logs)
#     318 if len(self._batch_times) >= self._num_batches_for_timing_check:
#     319   end_hook_name = hook_name
#
# File /run/media/rr/M2/DevOps/jupyter-lab/python39_venv/lib/python3.9/site-packages/keras/callbacks.py:354, in CallbackList._call_batch_hook_helper(self, hook_name, batch, logs)
#     352 for callback in self.callbacks:
#     353   hook = getattr(callback, hook_name)
# --> 354   hook(batch, logs)
#     356 if self._check_timing:
#     357   if hook_name not in self._hook_times:
#
# File /run/media/rr/M2/DevOps/jupyter-lab/python39_venv/lib/python3.9/site-packages/keras/callbacks.py:1032, in ProgbarLogger.on_train_batch_end(self, batch, logs)
#    1031 def on_train_batch_end(self, batch, logs=None):
# -> 1032   self._batch_update_progbar(batch, logs)
#
# File /run/media/rr/M2/DevOps/jupyter-lab/python39_venv/lib/python3.9/site-packages/keras/callbacks.py:1104, in ProgbarLogger._batch_update_progbar(self, batch, logs)
#    1100   self.seen += add_seen
#    1102 if self.verbose == 1:
#    1103   # Only block async when verbose = 1.
# -> 1104   logs = tf_utils.sync_to_numpy_or_python_type(logs)
#    1105   self.progbar.update(self.seen, list(logs.items()), finalize=False)
#
# File /run/media/rr/M2/DevOps/jupyter-lab/python39_venv/lib/python3.9/site-packages/keras/utils/tf_utils.py:554, in sync_to_numpy_or_python_type(tensors)
#     551     return x.item() if np.ndim(x) == 0 else x
#     552   return t  # Don't turn ragged or sparse tensors to NumPy.
# --> 554 return tf.nest.map_structure(_to_single_numpy_or_python_type, tensors)
#
# File /run/media/rr/M2/DevOps/jupyter-lab/python39_venv/lib/python3.9/site-packages/tensorflow/python/util/nest.py:869, in map_structure(func, *structure, **kwargs)
#     865 flat_structure = (flatten(s, expand_composites) for s in structure)
#     866 entries = zip(*flat_structure)
#     868 return pack_sequence_as(
# --> 869     structure[0], [func(*x) for x in entries],
#     870     expand_composites=expand_composites)
#
# File /run/media/rr/M2/DevOps/jupyter-lab/python39_venv/lib/python3.9/site-packages/tensorflow/python/util/nest.py:869, in <listcomp>(.0)
#     865 flat_structure = (flatten(s, expand_composites) for s in structure)
#     866 entries = zip(*flat_structure)
#     868 return pack_sequence_as(
# --> 869     structure[0], [func(*x) for x in entries],
#     870     expand_composites=expand_composites)
#
# File /run/media/rr/M2/DevOps/jupyter-lab/python39_venv/lib/python3.9/site-packages/keras/utils/tf_utils.py:550, in sync_to_numpy_or_python_type.<locals>._to_single_numpy_or_python_type(t)
#     548 def _to_single_numpy_or_python_type(t):
#     549   if isinstance(t, tf.Tensor):
# --> 550     x = t.numpy()
#     551     return x.item() if np.ndim(x) == 0 else x
#     552   return t
#
# File /run/media/rr/M2/DevOps/jupyter-lab/python39_venv/lib/python3.9/site-packages/tensorflow/python/framework/ops.py:1149, in _EagerTensorBase.numpy(self)
#    1126 """Copy of the contents of this Tensor into a NumPy array or scalar.
#    1127
#    1128 Unlike NumPy arrays, Tensors are immutable, so this method has to copy
#    (...)
#    1146     NumPy dtype.
#    1147 """
#    1148 # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1149 maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1150 return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#
# File /run/media/rr/M2/DevOps/jupyter-lab/python39_venv/lib/python3.9/site-packages/tensorflow/python/framework/ops.py:1115, in _EagerTensorBase._numpy(self)
#    1113 def _numpy(self):
#    1114   try:
# -> 1115     return self._numpy_internal()
#    1116   except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1117     raise core._status_to_exception(e) from None
#
# KeyboardInterrupt:
