# %% [markdown]
# # **POINTNET WITH K-FOLD**

# %%
# necessary imports
import os
import numpy
import pandas
import random
import trimesh
import logging
import itertools
import tensorflow
from matplotlib import pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import models, layers, regularizers, optimizers
from sklearn.model_selection import train_test_split, StratifiedKFold
from tensorflow.keras.layers import Dense, Activation, Flatten, Dropout, BatchNormalization
from tensorflow.keras.layers import Conv1D, MaxPooling1D, GlobalMaxPooling1D, Conv2D, MaxPooling2D

# increase matplotlib plots font size
plt.rcParams.update({'font.size': 15})

# The below is necessary for reproducible results of certain Python hash-based operations.
os.environ["PYTHONHASHSEED"] = "0"

# The below is necessary for starting Numpy generated random numbers in a well-defined initial state.
numpy.random.seed(31)

# The below is necessary for starting core Python generated random numbers in a well-defined state.
random.seed(14)

# The below tf.random.set_seed will make random number generation in TensorFlow have a well-defined initial state.
tensorflow.random.set_seed(1234)

# dataset root path
DATASET_ROOT = '/run/media/rr/M2/DevOps/jupyter-lab/CIDL/dataset/'

# final preprocessed dataset directory path
DATASET_PATH = os.path.join(DATASET_ROOT, 'Preprocessed')

# directory where to save the best model for each fold
images_models_save_dir = 'saved_models/images'
pointclouds_models_save_dir = 'saved_models/pointclouds'

# needed to create pointclouds dataset
class_labels_dict = {'table':0, 'chair':1, 'lamp':2, 'dresser':3, 'sofa':4}

# utility function
def get_model_name(model_name, fold_counter):
    return model_name + '-fold-' + str(fold_counter) + '.h5'

# utility function to augment pointclouds data
def augment(points, label):
    # jitter points
    points += tensorflow.random.uniform(points.shape, -0.005, 0.005, dtype=tensorflow.float64)
    # shuffle points
    points = tensorflow.random.shuffle(points)
    return points, label

# plot loss and acuracy for each epoch
def plot_train_loss_accuracy(save_path, train_loss, train_accuracy, val_loss, val_accuracy):
    #print('Training Set Loss: ', train_loss)
    #print('Validation Set Loss: ', val_loss)
    plt.figure(figsize=(10, 10))
    plt.plot(train_loss,'o-g', label="Training Set")
    plt.plot(val_loss,'o-r', label="Validation Set")
    plt.title('Training and Validation Sets Loss')
    plt.legend(loc="upper right")
    plt.savefig(save_path + '-train-val-loss.jpg', dpi=200)
    plt.show()
    #print('Training Set Accuracy: ', train_accuracy)
    #print('Validation Set Accuracy: ', val_accuracy)
    plt.figure(figsize=(10, 10))
    plt.plot(train_accuracy,'o-g', label="Training Set")
    plt.plot(val_accuracy,'o-r', label="Validation Set")
    plt.title('Training and Validation Sets Accuracy')
    plt.legend(loc="lower right")
    plt.savefig(save_path + '-train-val-accuracy.jpg', dpi=200)
    plt.show()

def plot_confusion_matrix(cm, classes, save_path, normalize=True, title='Confusion matrix', cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.figure(figsize=(10,10))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()

    tick_marks = numpy.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, numpy.newaxis]
        cm = numpy.around(cm, decimals=2)
        cm[numpy.isnan(cm)] = 0.0
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')
    
    thresh = cm.max() / 2.

    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j], horizontalalignment="center", color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.savefig(save_path + '-confusion-matrix.jpg', bbox_inches='tight', dpi=200)
    plt.show()

# %%
# only log critical messages
logger = logging.getLogger()
logger.setLevel(logging.CRITICAL)

# %%
# load images csv file
images_data = pandas.read_csv(os.path.join(DATASET_PATH, 'images.csv'))

# extract images path and class labels
images_X = images_data[['filename']]
images_Y = images_data[['class_label']]

# load pointclouds csv file
pointclouds_data = pandas.read_csv(os.path.join(DATASET_PATH, 'pointclouds.csv'))

# extract images path and class labels
pointclouds_X = pointclouds_data[['filename']]
pointclouds_Y = pointclouds_data[['class_label']]

# %% [markdown]
# ## **Stratified K-Fold Cross Validation for pointclouds**

# %%
def pointclouds_kfold_validation(model_name, n_splits, test_size, shuffle, layers, learning_rate, decay, target_size, epochs, batch_size, resample_data=0):
    global pointclouds_data
    global pointclouds_X
    global pointclouds_Y
    if resample_data > 0:
        pointclouds_data = pointclouds_data.groupby('class_label', group_keys=False).apply(lambda x: x.sample(min(len(x), resample_data), random_state=42))
        pointclouds_X = pointclouds_data[['filename']]
        pointclouds_Y = pointclouds_data[['class_label']]

    # fold counter
    fold_counter = 1
    
    # arrays to store test set loss and accuracy scores for each fold
    TEST_LOSS = []
    TEST_ACCURACY = []
    
    # split train and test dataset
    pointclouds_train, pointclouds_test = train_test_split(pointclouds_data, test_size=test_size, stratify=pointclouds_Y, random_state=42)
    pointclouds_train_X = pointclouds_train[['filename']]
    pointclouds_train_Y = pointclouds_train[['class_label']]

    # define stratified k fold cross validation parameters
    stratified_kfold = StratifiedKFold(n_splits=n_splits, random_state=7, shuffle=shuffle)

    # test data arrays
    test_pointclouds = []
    test_labels = []
    test_string_labels = {}

    # test split ready
    for index, test_data_row in pointclouds_test.iterrows():
        test_pointclouds.append(trimesh.load(test_data_row['filename'], force='mesh').sample(target_size))
        test_labels.append(class_labels_dict[test_data_row['class_label']])
        test_string_labels[index] = test_data_row['class_label']
    
    # convert to numpy array
    test_pointclouds = numpy.array(test_pointclouds)
    test_labels = numpy.array(test_labels)
    
    # debugging
    print(len(test_pointclouds))
    print(len(test_labels))
    print(test_pointclouds)
    print(test_labels)

    # create test tf.data.Dataset
    test_dataset = tensorflow.data.Dataset.from_tensor_slices((test_pointclouds, test_labels))
    test_dataset = test_dataset.shuffle(len(test_pointclouds)).batch(batch_size)
    print("Found " + str(len(pointclouds_test)) + " validated pointcloud filenames belonging to " + str(len(pointclouds_test['class_label'].unique())) + " classes.")


    # generate train and validation folds
    for train_index, validation_index in stratified_kfold.split(pointclouds_train_X, pointclouds_train_Y):
        print("\n-------- STARTING FOLD: " + str(fold_counter) + " --------")

        # best model save path
        if not os.path.isdir(os.path.join(pointclouds_models_save_dir, model_name)):
            os.mkdir(os.path.join(pointclouds_models_save_dir, model_name))
        pointclouds_model_save_path = os.path.join(pointclouds_models_save_dir, model_name, get_model_name(model_name, fold_counter))

        # train and validation data arrays
        train_pointclouds = []
        train_labels = []
        train_string_labels = {}
        validation_pointclouds = []
        validation_labels = []
        validation_string_labels = {}

        # training and test folds indices
        training_data = pointclouds_train.iloc[train_index]
        validation_data = pointclouds_train.iloc[validation_index]

        for index, training_data_row in training_data.iterrows():
            train_pointclouds.append(trimesh.load(training_data_row['filename'], force='mesh').sample(target_size))
            train_labels.append(class_labels_dict[training_data_row['class_label']])
            train_string_labels[index] = training_data_row['class_label']

        # convert to numpy array
        train_pointclouds = numpy.array(train_pointclouds)
        train_labels = numpy.array(train_labels)
    
        # debugging
        print(len(train_pointclouds))
        print(len(train_labels))
        print(train_pointclouds)
        print(train_labels)

        # create train tf.data.Dataset
        train_dataset = tensorflow.data.Dataset.from_tensor_slices((train_pointclouds, train_labels))
        train_dataset = train_dataset.shuffle(len(train_pointclouds)).map(augment).batch(batch_size)
        print("Found " + str(len(training_data)) + " validated pointcloud filenames belonging to " + str(len(training_data['class_label'].unique())) + " classes.")

        for index, validation_data_row in validation_data.iterrows():
            validation_pointclouds.append(trimesh.load(validation_data_row['filename'], force='mesh').sample(target_size))
            validation_labels.append(class_labels_dict[validation_data_row['class_label']])
            validation_string_labels[index] = validation_data_row['class_label']

        # convert to numpy array
        validation_pointclouds = numpy.array(validation_pointclouds)
        validation_labels = numpy.array(validation_labels)
    
        # debugging
        print(len(validation_pointclouds))
        print(len(validation_labels))
        print(validation_pointclouds)
        print(validation_labels)

        # create train tf.data.Dataset
        validation_dataset = tensorflow.data.Dataset.from_tensor_slices((validation_pointclouds, validation_labels))
        validation_dataset = validation_dataset.shuffle(len(validation_pointclouds)).map(augment).batch(batch_size)
        print("Found " + str(len(validation_data)) + " validated pointcloud filenames belonging to " + str(len(validation_data['class_label'].unique())) + " classes.")

        # create best model checkpoint
        best_model_checkpoint = tensorflow.keras.callbacks.ModelCheckpoint(pointclouds_model_save_path, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
        callbacks_list = [best_model_checkpoint]

        # define model to be trained and tested
        model = models.Sequential(name=model_name + "-" + str(fold_counter))
        for layer in layers:
            model.add(layer)
        model.summary()

        model.compile(
            loss="sparse_categorical_crossentropy",
            optimizer=tensorflow.keras.optimizers.Adam(learning_rate=0.001),
            metrics=["sparse_categorical_accuracy"],
        )

        history = model.fit(train_dataset, epochs=50, validation_data=validation_dataset)

        # plot loss and acuracy for each training/validation fold
        plot_train_loss_accuracy(pointclouds_model_save_path, history.history["loss"], history.history["sparse_categorical_accuracy"],
                                 history.history["val_loss"], history.history["val_sparse_categorical_accuracy"])

        # LOAD BEST MODEL to evaluate the performance of the model on the test set
        model.load_weights(pointclouds_model_save_path)

        # evaluate the model on the test set
        test_loss, test_accuracy = model.evaluate(test_dataset, batch_size=batch_size)
        print("Best model Test Loss: " + str(test_loss))
        print("Best model Test Accuracy: " + str(test_accuracy))
        
        # store test set loss and accuracy scores for each fold
        TEST_LOSS.append(test_loss)
        TEST_ACCURACY.append(test_accuracy)

        # Confution Matrix 
        Y_pred = model.predict(test_dataset)
        y_pred = numpy.argmax(Y_pred, axis=1)
        print('Confusion Matrix')
        cm = confusion_matrix(test_labels, y_pred)
        plot_confusion_matrix(cm, class_labels_dict.keys(), pointclouds_model_save_path, title='Confusion Matrix')

        # print Classification Report
        print('Classification Report')
        print(classification_report(test_labels, y_pred, target_names=class_labels_dict.keys()))

        # clean up before next fold
        del model
        tensorflow.keras.backend.clear_session()
        fold_counter += 1

# %% [markdown]
# #### **Developer harness test for Stratified K-Fold Cross Validation for pointclouds**

# %%
# testing
layers = [
    Conv1D(32, 3, padding='same', input_shape=(2048, 3)),
    BatchNormalization(momentum=0.0),
    Activation('relu'),
    Conv1D(64, 3, padding='same', input_shape=(2048, 3)),
    BatchNormalization(momentum=0.0),
    Activation('relu'),
    Conv1D(512, 3, padding='same', input_shape=(2048, 3)),
    BatchNormalization(momentum=0.0),
    Activation('relu'),
    GlobalMaxPooling1D(),
    Dense(512),
    BatchNormalization(momentum=0.0),
    Flatten(),
    Dense(1024),
    Activation('relu'),
    Dense(5, activation='softmax')
]

# train, validate and test
pointclouds_kfold_validation("testing", 3, 0.20, True, layers, 0.001, 1e-6, 2048, 50, 32)
# Out:
# 787
# 787
# [[[ 8.72601320e+00  7.06684342e+01  3.77094486e+01]
#   [ 4.44456045e+01  3.51317389e+01  3.34566294e+01]
#   [ 4.29052135e+01  5.91907861e+01  3.16800439e+01]
#   ...
#   [ 1.63290465e+01  4.17134925e+01  2.72525178e+01]
#   [ 1.47377267e+01  3.22413536e+01  2.62282723e+01]
#   [ 2.06499115e+01  4.93711875e+01  2.71548533e+01]]
#
#  [[ 2.38091590e+01  2.48204934e+01  2.84224180e+01]
#   [ 3.37989553e+01  2.79584380e+01 -1.83539906e-01]
#   [ 3.35649253e+01  1.20055101e+01  1.38608343e+01]
#   ...
#   [ 2.20465474e+01  2.12726384e+01  2.05569936e+01]
#   [ 2.79949154e+01  1.93362448e+01  1.63422000e+01]
#   [ 2.43413838e+01  2.42486291e+01  2.64491090e+01]]
#
#  [[-4.00425566e-01  1.33374407e+01 -8.73656000e+00]
#   [ 8.07085000e+00  1.11206188e+01  5.79783351e+00]
#   [ 6.06073099e+00  3.24338438e-01 -8.00087000e+00]
#   ...
#   [-5.44410968e+00  5.55236729e+00  1.43701000e+01]
#   [ 1.03155280e-01  4.90731996e+00 -8.73656000e+00]
#   [-7.67714900e+00 -4.00995877e+00 -8.02614429e+00]]
#
#  ...
#
#  [[ 9.78590558e+01  5.67912423e+01  6.67995052e+01]
#   [ 9.59266254e+01  6.46350036e+01  0.00000000e+00]
#   [ 9.26613155e+01  6.88253261e+01  2.40733245e+01]
#   ...
#   [ 1.03213144e+02  6.36837751e+01  6.18550000e+01]
#   [ 9.15074208e+01  5.85371550e+01  7.24003652e+01]
#   [ 9.95883497e+01  5.93401929e+01  6.18550000e+01]]
#
#  [[-4.33899000e+01  5.86495132e+01  2.54104220e+01]
#   [-4.33899000e+01  6.47511765e+01  1.92589887e+01]
#   [-2.69392883e+01  3.03303740e+01  4.40000000e+01]
#   ...
#   [-2.54150000e+00  1.35206032e+01  2.98433257e+01]
#   [-1.51970555e+01  1.91794191e+01  4.40000000e+01]
#   [-5.29150000e+00  1.51488322e+01  1.19970202e+01]]
#
#  [[ 3.65067998e+01  3.43520820e+01  3.42546010e+01]
#   [ 4.06419310e+00  2.38732703e+01  3.42546010e+01]
#   [ 1.35732719e+01  2.73543571e+01  3.42546010e+01]
#   ...
#   [ 4.36147942e+00  4.28983000e+01  3.09019892e+01]
#   [ 1.38654042e+01  4.29084955e+01  3.16534245e+01]
#   [ 8.76418555e-01  6.74586445e+00  3.39626010e+01]]]
# [4 1 3 1 2 2 3 1 4 4 2 1 2 4 3 3 3 4 2 2 0 4 2 4 4 1 0 3 4 1 1 0 2 0 0 3 2
#  3 4 0 3 4 4 0 1 4 4 1 4 4 1 3 0 3 2 4 1 1 4 0 3 4 1 1 3 2 3 2 4 0 1 4 4 2
#  1 4 2 2 4 1 3 2 2 0 4 3 1 1 1 1 1 3 4 2 2 1 3 4 4 2 3 4 0 1 4 3 2 3 2 1 0
#  4 4 0 1 0 4 2 0 2 0 2 3 4 1 2 4 2 0 1 2 0 2 3 2 3 1 4 4 3 4 0 4 3 4 4 2 3
#  1 2 1 3 2 4 2 4 4 0 0 3 4 3 4 2 3 1 1 4 3 2 3 4 0 3 2 2 0 2 2 0 2 1 2 2 0
#  0 0 0 4 2 1 3 3 4 0 4 3 0 4 1 3 4 4 0 0 4 2 4 4 3 3 4 3 1 3 4 3 0 2 2 2 3
#  3 2 0 0 1 0 0 4 2 1 0 0 2 0 1 1 1 0 0 2 0 1 2 3 3 4 0 1 4 4 3 2 0 4 0 4 3
#  3 1 4 4 1 4 3 2 0 2 3 3 1 3 4 3 3 2 1 3 0 3 0 2 3 0 0 4 0 4 1 4 3 3 2 0 2
#  1 0 1 3 2 1 3 2 4 0 1 0 0 1 3 4 2 1 1 3 2 1 3 1 0 1 2 1 3 4 0 1 3 1 0 1 1
#  3 2 2 0 3 1 4 0 4 4 3 3 1 3 4 0 0 4 0 3 2 1 0 1 3 0 4 1 3 1 4 0 4 1 3 1 4
#  2 3 3 4 2 2 3 4 3 0 3 3 4 0 0 1 2 0 4 4 1 2 4 1 3 2 0 1 2 4 2 0 0 0 3 2 3
#  1 0 1 4 4 0 1 1 4 1 4 1 2 0 0 0 4 2 1 3 1 4 4 1 3 0 2 2 1 4 2 1 0 3 3 3 0
#  1 1 4 0 0 3 2 2 0 0 0 2 1 0 1 0 2 3 1 3 1 3 0 2 2 3 3 0 3 0 1 1 2 3 4 0 0
#  4 4 1 4 3 3 3 3 4 2 3 4 2 1 4 4 1 0 0 3 0 4 2 4 0 4 1 1 4 0 0 1 4 2 3 1 2
#  0 1 0 4 2 2 2 0 2 0 3 0 0 4 1 0 0 4 2 2 4 0 1 1 0 2 0 0 3 1 1 2 1 1 3 1 2
#  1 0 2 0 3 1 3 3 0 2 2 0 3 1 3 2 2 4 3 3 3 4 2 4 1 4 0 3 0 4 0 1 0 1 4 1 1
#  2 1 0 0 2 2 1 0 0 2 3 3 3 3 2 3 3 2 0 3 0 1 1 3 4 3 3 3 2 2 2 4 4 1 0 2 2
#  4 0 4 0 0 3 3 1 2 2 0 4 1 4 3 3 2 4 3 4 4 2 2 3 2 3 1 2 0 0 0 1 2 4 3 3 2
#  2 3 0 2 0 4 1 4 0 4 1 1 4 2 3 0 1 1 4 3 1 3 1 3 4 2 4 3 2 4 0 0 3 4 1 4 3
#  0 3 2 4 4 0 1 1 0 1 1 1 1 4 3 2 2 0 1 2 2 4 2 2 3 3 1 1 2 0 4 4 4 1 2 1 3
#  2 1 2 0 1 3 2 1 2 2 2 1 1 3 4 0 1 3 1 3 0 2 1 0 2 3 4 0 4 0 1 2 3 0 2 4 2
#  2 4 2 2 0 1 4 2 0 0]
# 2022-02-06 20:56:49.077519: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-06 20:56:49.113799: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-06 20:56:49.113974: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-06 20:56:49.114939: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-02-06 20:56:49.115863: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-06 20:56:49.116005: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-06 20:56:49.116129: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-06 20:56:49.472072: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-06 20:56:49.472218: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-06 20:56:49.472330: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-06 20:56:49.472434: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 21932 MB memory:  -> device: 0, name: NVIDIA RTX A5000, pci bus id: 0000:0b:00.0, compute capability: 8.6
# Found 787 validated pointcloud filenames belonging to 5 classes.
#
# -------- STARTING FOLD: 1 --------
# 2096
# 2096
# [[[ 3.20772181e+00 -1.47638000e+01 -1.67969448e+00]
#   [-5.83435104e+00  5.30155104e+00 -8.73656000e+00]
#   [-2.84187355e+00 -1.47638000e+01 -3.48785482e+00]
#   ...
#   [-1.77060547e+00 -8.98647050e+00  1.51575000e+01]
#   [-7.67714900e+00  2.00729957e+00  1.06152572e+00]
#   [ 5.03841469e+00  1.47638000e+01 -6.20737533e+00]]
#
#  [[ 1.40800037e+01  7.00289000e+01  1.08634266e+00]
#   [ 2.65942597e+01  8.95792925e+01  3.60000000e+01]
#   [ 3.39323002e+01  7.00289000e+01  7.72218026e+00]
#   ...
#   [ 3.00124364e+01  9.10289000e+01  1.57327330e+01]
#   [ 3.53492413e+01  7.99648669e+01  0.00000000e+00]
#   [ 5.18211157e+01  9.10289000e+01  2.45506164e+00]]
#
#  [[-6.60885443e-01  2.13209927e+01  2.26378000e+01]
#   [ 4.70612405e+00 -2.12987038e+01  2.26378000e+01]
#   [-9.96255000e+00  1.97416847e+01  5.24003423e+00]
#   ...
#   [-1.02062453e+01  8.03722213e+00 -3.23085722e+00]
#   [ 1.12972500e+01  1.43046526e+01  1.63512868e+00]
#   [-1.03562500e+01 -1.81433163e+01  4.58343433e+00]]
#
#  ...
#
#  [[ 1.56682999e+02  4.20326155e+01  1.77584249e+00]
#   [ 1.58858994e+02  4.23719436e+01  5.26672436e-01]
#   [ 1.57779099e+02  4.21297990e+01  2.11441353e+00]
#   ...
#   [ 1.58637546e+02  4.19528632e+01  5.99734640e-03]
#   [ 1.58521918e+02  4.27354010e+01  8.08345339e-01]
#   [ 1.57684635e+02  4.16473010e+01  1.64880171e+00]]
#
#  [[ 4.02319092e+01 -2.10654618e+01 -1.35198814e+01]
#   [ 3.68868574e+01  3.45032901e+01 -1.34896271e+01]
#   [-3.79592896e+01 -2.27892000e+01 -1.60091045e+01]
#   ...
#   [ 7.57049288e+00 -2.98626339e+01 -1.34016527e+01]
#   [ 4.18547391e+01  5.90006477e+01 -1.33546844e+01]
#   [ 4.45259996e+01 -6.14048075e+01  3.24521611e+00]]
#
#  [[-9.32437263e-01 -9.57561447e+00  4.32475571e+01]
#   [ 1.03911795e+01  6.40265663e+00  1.20700830e+01]
#   [-1.60145755e+01 -7.52873620e+00  1.88192264e+01]
#   ...
#   [-9.40616128e+00 -2.63086236e+00  4.29394251e+01]
#   [-1.43451229e+01  8.81972988e+00  2.53472988e+01]
#   [-1.15185986e+01 -1.29817212e+01  3.92523583e+01]]]
# [3 3 3 ... 0 4 1]
# Found 2096 validated pointcloud filenames belonging to 5 classes.
# 1048
# 1048
# [[[  9.99242298   5.70369775  40.59052237]
#   [  7.28335182  18.697001    68.92337406]
#   [  0.193106     7.81578448  70.59813104]
#   ...
#   [ 18.697001     1.09057144  68.88287086]
#   [ 13.76729566  18.697001    66.29230455]
#   [ 18.697001    18.36950972  66.21266769]]
#
#  [[ 10.85662819  16.63087533  16.36376853]
#   [  4.68885544  20.06510747  16.71552926]
#   [  8.84216533   1.33951827  12.7027    ]
#   ...
#   [  0.36690217   0.49371523  13.65420756]
#   [ 12.0618011   14.28527636   7.15523927]
#   [  2.79615232   9.22546684   9.07670212]]
#
#  [[ -3.82080576  23.625       -5.53492281]
#   [  0.72495876  23.625      -27.21622205]
#   [-14.23603783  -9.57520896  -3.63070715]
#   ...
#   [-14.49323732   0.38645388  -8.65504126]
#   [  2.5473992   23.625       25.48148718]
#   [ 14.76729739   5.32912429  30.65217125]]
#
#  ...
#
#  [[ -5.8639395  -12.25        -2.07337217]
#   [ -7.09091444  13.25         6.66761441]
#   [ -1.59731079 -10.07636297 -17.000025  ]
#   ...
#   [  0.23919637 -11.5        -10.62636555]
#   [  4.05290385  12.5         11.90075885]
#   [  2.25390944   2.09644563  -4.750025  ]]
#
#  [[ 16.34869256  16.27601346   0.5       ]
#   [ 21.7327      18.97843856   2.78107628]
#   [ 18.45288323  19.060699    15.69054938]
#   ...
#   [ 15.53528894  12.87797855  20.00721445]
#   [ 20.0026435   17.29564686   0.5       ]
#   [ 15.62217547  21.50799872   0.        ]]
#
#  [[ 68.3793327   53.00748161   2.95      ]
#   [ 50.63188211  54.4362469    6.04004476]
#   [ 68.90494534  61.33253211   6.142     ]
#   ...
#   [ 69.62125245  54.36003411   6.34181411]
#   [ 70.13373065  56.55526237   0.09      ]
#   [ 68.2264686   52.38769169   3.51605851]]]
# [2 1 3 ... 3 2 2]
# Found 1048 validated pointcloud filenames belonging to 5 classes.
# Model: "testing-1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_3 (Conv1D)           (None, 2048, 32)          320
#
#  batch_normalization_3 (Batc  (None, 2048, 32)         128
#  hNormalization)
#
#  activation_3 (Activation)   (None, 2048, 32)          0
#
#  conv1d_4 (Conv1D)           (None, 2048, 64)          6208
#
#  batch_normalization_4 (Batc  (None, 2048, 64)         256
#  hNormalization)
#
#  activation_4 (Activation)   (None, 2048, 64)          0
#
#  conv1d_5 (Conv1D)           (None, 2048, 512)         98816
#
#  batch_normalization_5 (Batc  (None, 2048, 512)        2048
#  hNormalization)
#
#  activation_5 (Activation)   (None, 2048, 512)         0
#
#  global_max_pooling1d (Globa  (None, 512)              0
#  lMaxPooling1D)
#
#  dense (Dense)               (None, 512)               262656
#
#  batch_normalization_6 (Batc  (None, 512)              2048
#  hNormalization)
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 1024)              525312
#
#  activation_6 (Activation)   (None, 1024)              0
#
#  dense_2 (Dense)             (None, 5)                 5125
#
# =================================================================
# Total params: 902,917
# Trainable params: 900,677
# Non-trainable params: 2,240
# _________________________________________________________________
# Epoch 1/50
# 2022-02-06 20:59:08.064277: I tensorflow/stream_executor/cuda/cuda_dnn.cc:366] Loaded cuDNN version 8300
# 2022-02-06 20:59:08.935839: I tensorflow/stream_executor/cuda/cuda_blas.cc:1774] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 66/66 [==============================] - 4s 27ms/step - loss: 2.0184 - sparse_categorical_accuracy: 0.2815 - val_loss: 2.7671 - val_sparse_categorical_accuracy: 0.2128
# Epoch 2/50
# 66/66 [==============================] - 2s 24ms/step - loss: 1.7828 - sparse_categorical_accuracy: 0.3554 - val_loss: 1.8212 - val_sparse_categorical_accuracy: 0.2128
# Epoch 3/50
# 66/66 [==============================] - 2s 24ms/step - loss: 1.6051 - sparse_categorical_accuracy: 0.3812 - val_loss: 1.6602 - val_sparse_categorical_accuracy: 0.2462
# Epoch 4/50
# 66/66 [==============================] - 2s 24ms/step - loss: 1.4664 - sparse_categorical_accuracy: 0.4070 - val_loss: 2.0916 - val_sparse_categorical_accuracy: 0.2137
# Epoch 5/50
# 66/66 [==============================] - 2s 24ms/step - loss: 1.5007 - sparse_categorical_accuracy: 0.4241 - val_loss: 6.1641 - val_sparse_categorical_accuracy: 0.5534
# Epoch 6/50
# 66/66 [==============================] - 2s 24ms/step - loss: 1.3463 - sparse_categorical_accuracy: 0.4552 - val_loss: 2.3470 - val_sparse_categorical_accuracy: 0.3540
# Epoch 7/50
# 66/66 [==============================] - 2s 24ms/step - loss: 1.3432 - sparse_categorical_accuracy: 0.4447 - val_loss: 1.5962 - val_sparse_categorical_accuracy: 0.3635
# Epoch 8/50
# 66/66 [==============================] - 2s 24ms/step - loss: 1.2973 - sparse_categorical_accuracy: 0.4847 - val_loss: 32.0831 - val_sparse_categorical_accuracy: 0.5849
# Epoch 9/50
# 66/66 [==============================] - 2s 24ms/step - loss: 1.2505 - sparse_categorical_accuracy: 0.5229 - val_loss: 1.6207 - val_sparse_categorical_accuracy: 0.4933
# Epoch 10/50
# 66/66 [==============================] - 2s 24ms/step - loss: 1.2091 - sparse_categorical_accuracy: 0.5024 - val_loss: 3.8651 - val_sparse_categorical_accuracy: 0.6221
# Epoch 11/50
# 66/66 [==============================] - 2s 24ms/step - loss: 1.1672 - sparse_categorical_accuracy: 0.5281 - val_loss: 1.4736 - val_sparse_categorical_accuracy: 0.4408
# Epoch 12/50
# 66/66 [==============================] - 2s 24ms/step - loss: 1.1214 - sparse_categorical_accuracy: 0.5615 - val_loss: 12.4766 - val_sparse_categorical_accuracy: 0.7090
# Epoch 13/50
# 66/66 [==============================] - 2s 24ms/step - loss: 1.0811 - sparse_categorical_accuracy: 0.5716 - val_loss: 5.3516 - val_sparse_categorical_accuracy: 0.6317
# Epoch 14/50
# 66/66 [==============================] - 2s 24ms/step - loss: 1.1141 - sparse_categorical_accuracy: 0.5577 - val_loss: 30.2553 - val_sparse_categorical_accuracy: 0.6803
# Epoch 15/50
# 66/66 [==============================] - 2s 24ms/step - loss: 1.0529 - sparse_categorical_accuracy: 0.5763 - val_loss: 2.0998 - val_sparse_categorical_accuracy: 0.7395
# Epoch 16/50
# 66/66 [==============================] - 2s 24ms/step - loss: 1.0272 - sparse_categorical_accuracy: 0.6011 - val_loss: 16.9473 - val_sparse_categorical_accuracy: 0.6622
# Epoch 17/50
# 66/66 [==============================] - 2s 24ms/step - loss: 0.9875 - sparse_categorical_accuracy: 0.6016 - val_loss: 33.8802 - val_sparse_categorical_accuracy: 0.6994
# Epoch 18/50
# 66/66 [==============================] - 2s 24ms/step - loss: 1.0028 - sparse_categorical_accuracy: 0.6131 - val_loss: 1.4864 - val_sparse_categorical_accuracy: 0.3922
# Epoch 19/50
# 66/66 [==============================] - 2s 24ms/step - loss: 0.9845 - sparse_categorical_accuracy: 0.6164 - val_loss: 10.7331 - val_sparse_categorical_accuracy: 0.7128
# Epoch 20/50
# 66/66 [==============================] - 2s 24ms/step - loss: 1.0091 - sparse_categorical_accuracy: 0.6135 - val_loss: 14.0210 - val_sparse_categorical_accuracy: 0.6431
# Epoch 21/50
# 66/66 [==============================] - 2s 24ms/step - loss: 0.9759 - sparse_categorical_accuracy: 0.6317 - val_loss: 6.9666 - val_sparse_categorical_accuracy: 0.6183
# Epoch 22/50
# 66/66 [==============================] - 2s 24ms/step - loss: 0.9465 - sparse_categorical_accuracy: 0.6446 - val_loss: 1.5281 - val_sparse_categorical_accuracy: 0.4208
# Epoch 23/50
# 66/66 [==============================] - 2s 24ms/step - loss: 0.9178 - sparse_categorical_accuracy: 0.6541 - val_loss: 4.0153 - val_sparse_categorical_accuracy: 0.7615
# Epoch 24/50
# 66/66 [==============================] - 2s 24ms/step - loss: 0.9260 - sparse_categorical_accuracy: 0.6579 - val_loss: 1.2380 - val_sparse_categorical_accuracy: 0.6870
# Epoch 25/50
# 66/66 [==============================] - 2s 24ms/step - loss: 0.9204 - sparse_categorical_accuracy: 0.6527 - val_loss: 1.6843 - val_sparse_categorical_accuracy: 0.3426
# Epoch 26/50
# 66/66 [==============================] - 2s 24ms/step - loss: 0.9312 - sparse_categorical_accuracy: 0.6450 - val_loss: 2.4289 - val_sparse_categorical_accuracy: 0.7519
# Epoch 27/50
# 66/66 [==============================] - 2s 25ms/step - loss: 0.8756 - sparse_categorical_accuracy: 0.6627 - val_loss: 6.5045 - val_sparse_categorical_accuracy: 0.7615
# Epoch 28/50
# 66/66 [==============================] - 2s 24ms/step - loss: 0.8847 - sparse_categorical_accuracy: 0.6646 - val_loss: 17.7756 - val_sparse_categorical_accuracy: 0.6727
# Epoch 29/50
# 66/66 [==============================] - 2s 25ms/step - loss: 0.8783 - sparse_categorical_accuracy: 0.6813 - val_loss: 56.5185 - val_sparse_categorical_accuracy: 0.5983
# Epoch 30/50
# 66/66 [==============================] - 2s 24ms/step - loss: 0.8713 - sparse_categorical_accuracy: 0.6636 - val_loss: 9.7538 - val_sparse_categorical_accuracy: 0.7653
# Epoch 31/50
# 66/66 [==============================] - 2s 24ms/step - loss: 0.9019 - sparse_categorical_accuracy: 0.6627 - val_loss: 5.5516 - val_sparse_categorical_accuracy: 0.7863
# Epoch 32/50
# 66/66 [==============================] - 2s 24ms/step - loss: 0.8761 - sparse_categorical_accuracy: 0.6808 - val_loss: 0.8731 - val_sparse_categorical_accuracy: 0.7653
# Epoch 33/50
# 66/66 [==============================] - 2s 24ms/step - loss: 0.8796 - sparse_categorical_accuracy: 0.6827 - val_loss: 2.0492 - val_sparse_categorical_accuracy: 0.7490
# Epoch 34/50
# 66/66 [==============================] - 2s 25ms/step - loss: 0.7929 - sparse_categorical_accuracy: 0.7023 - val_loss: 12.3609 - val_sparse_categorical_accuracy: 0.7538
# Epoch 35/50
# 66/66 [==============================] - 2s 25ms/step - loss: 0.8086 - sparse_categorical_accuracy: 0.7009 - val_loss: 3.1048 - val_sparse_categorical_accuracy: 0.7471
# Epoch 36/50
# 66/66 [==============================] - 2s 25ms/step - loss: 0.8764 - sparse_categorical_accuracy: 0.6718 - val_loss: 7.3705 - val_sparse_categorical_accuracy: 0.7643
# Epoch 37/50
# 66/66 [==============================] - 2s 24ms/step - loss: 0.8218 - sparse_categorical_accuracy: 0.7090 - val_loss: 5.3752 - val_sparse_categorical_accuracy: 0.7691
# Epoch 38/50
# 66/66 [==============================] - 2s 24ms/step - loss: 0.8420 - sparse_categorical_accuracy: 0.6975 - val_loss: 0.9772 - val_sparse_categorical_accuracy: 0.7519
# Epoch 39/50
# 66/66 [==============================] - 2s 24ms/step - loss: 0.7899 - sparse_categorical_accuracy: 0.7071 - val_loss: 42.0336 - val_sparse_categorical_accuracy: 0.7023
# Epoch 40/50
# 66/66 [==============================] - 2s 24ms/step - loss: 0.7972 - sparse_categorical_accuracy: 0.6927 - val_loss: 1.2613 - val_sparse_categorical_accuracy: 0.5000
# Epoch 41/50
# 66/66 [==============================] - 2s 24ms/step - loss: 0.7899 - sparse_categorical_accuracy: 0.6999 - val_loss: 6.2272 - val_sparse_categorical_accuracy: 0.7071
# Epoch 42/50
# 66/66 [==============================] - 2s 25ms/step - loss: 0.8085 - sparse_categorical_accuracy: 0.7109 - val_loss: 0.7971 - val_sparse_categorical_accuracy: 0.7872
# Epoch 43/50
# 66/66 [==============================] - 2s 24ms/step - loss: 0.8048 - sparse_categorical_accuracy: 0.7066 - val_loss: 0.9072 - val_sparse_categorical_accuracy: 0.6966
# Epoch 44/50
# 66/66 [==============================] - 2s 25ms/step - loss: 0.7803 - sparse_categorical_accuracy: 0.7047 - val_loss: 2.1051 - val_sparse_categorical_accuracy: 0.7672
# Epoch 45/50
# 66/66 [==============================] - 2s 25ms/step - loss: 0.7616 - sparse_categorical_accuracy: 0.7118 - val_loss: 1.5219 - val_sparse_categorical_accuracy: 0.6469
# Epoch 46/50
# 66/66 [==============================] - 2s 24ms/step - loss: 0.7695 - sparse_categorical_accuracy: 0.7252 - val_loss: 3.4753 - val_sparse_categorical_accuracy: 0.7710
# Epoch 47/50
# 66/66 [==============================] - 2s 24ms/step - loss: 0.7813 - sparse_categorical_accuracy: 0.7180 - val_loss: 2.3489 - val_sparse_categorical_accuracy: 0.7681
# Epoch 48/50
# 66/66 [==============================] - 2s 24ms/step - loss: 0.7751 - sparse_categorical_accuracy: 0.7128 - val_loss: 1.1248 - val_sparse_categorical_accuracy: 0.5248
# Epoch 49/50
# 66/66 [==============================] - 2s 24ms/step - loss: 0.7251 - sparse_categorical_accuracy: 0.7185 - val_loss: 1.7584 - val_sparse_categorical_accuracy: 0.6336
# Epoch 50/50
# 66/66 [==============================] - 2s 24ms/step - loss: 0.7444 - sparse_categorical_accuracy: 0.7166 - val_loss: 15.5859 - val_sparse_categorical_accuracy: 0.7691
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [10], in <module>
#       2 layers = [
#       3     Conv1D(32, 3, padding='same', input_shape=(2048, 3)),
#       4     BatchNormalization(momentum=0.0),
#    (...)
#      18     Dense(5, activation='softmax')
#      19 ]
#      21 # train, validate and test
# ---> 22 pointclouds_kfold_validation("testing", 3, 0.20, True, layers, 0.001, 1e-6, 2048, 50, 32)
#
# Input In [9], in pointclouds_kfold_validation(model_name, n_splits, test_size, shuffle, layers, learning_rate, decay, target_size, epochs, batch_size, resample_data)
#     132 plot_train_loss_accuracy(pointclouds_model_save_path, history.history["loss"], history.history["sparse_categorical_accuracy"],
#     133                          history.history["val_loss"], history.history["val_sparse_categorical_accuracy"])
#     135 # LOAD BEST MODEL to evaluate the performance of the model on the test set
# --> 136 model.load_weights(pointclouds_model_save_path)
#     138 # evaluate the model on the test set
#     139 test_loss, test_accuracy = model.evaluate(test_dataset, batch_size=batch_size)
#
# File /run/media/rr/M2/DevOps/jupyter-lab/python39_venv/lib/python3.9/site-packages/keras/utils/traceback_utils.py:67, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67   raise e.with_traceback(filtered_tb) from None
#      68 finally:
#      69   del filtered_tb
#
# File /run/media/rr/M2/DevOps/jupyter-lab/python39_venv/lib/python3.9/site-packages/keras/saving/hdf5_format.py:719, in load_weights_from_hdf5_group(f, model)
#     717 layer_names = filtered_layer_names
#     718 if len(layer_names) != len(filtered_layers):
# --> 719   raise ValueError(
#     720       f'Layer count mismatch when loading weights from file. '
#     721       f'Model expected {len(filtered_layers)} layers, found '
#     722       f'{len(layer_names)} saved layers.')
#     724 # We batch weight value assignments in a single backend call
#     725 # which provides a speedup in TensorFlow.
#     726 weight_value_tuples = []
#
# ValueError: Layer count mismatch when loading weights from file. Model expected 10 layers, found 0 saved layers.
